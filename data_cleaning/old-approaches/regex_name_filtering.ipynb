# %%
import re
import pandas as pd
from cleaning import domain, filter_vvo_tags
from files import list_to_file, file_to_list
from regex import regex_filter, apply_regexs, generate_regex

# %%
def category_tags_to_file(terms_list, tag_search_domain, category_file_name):
    regexs = generate_regex(terms_list)
    tags = apply_regexs(regexs, tag_search_domain)
    list_to_file(category_file_name, tags)
    return tags

def print_stats(total, sub, description):
    print(f"{description} {round(100*sub/total, 2)}% or {sub}")
    
    
def tag_categorization_meassure(omniv_set, veg_set, vgn_set, vgn_veg_set, df, column):
    vegan = vegetarian = meat = vegan_and_vegetarian = empty = 0
    total = len(df)
    not_classified_ids = []
    
    for index, meal in df.iterrows():
        
        tag_list = meal[column]
        
        tag_set = set(tag_list)
        if bool(omniv_set & tag_set):
            meat += 1
            continue
            
        if bool(vgn_veg_set & tag_set):
            vegan_and_vegetarian += 1
            continue
            
        if bool(veg_set & tag_set):
            vegetarian += 1
            continue

        if bool(vgn_set & tag_set):
            vegan += 1
            continue
            
        if tag_list == []:
            empty += 1
            
        not_classified_ids.append(index)
        
    
    print(f"Total: {total}")
    print_stats(total, vegan, "Vegan:")
    print_stats(total, vegetarian, "Vegetarian: ")
    print_stats(total, vegan_and_vegetarian, "Vegan & Veg.:")
    print_stats(total, meat, "Meat:")
    print_stats(total, empty, "Empty:")
    print_stats(total, total-(empty+vegetarian+vegan+meat+vegan_and_vegetarian), "Could not be classified: ")

    not_classified = df.loc[not_classified_ids]
    
    return vegan, vegetarian, meat, not_classified

# %%
data = pd.read_csv("Data/SH_Canteens/meals_SH_canteens_merged_filtered_.csv", sep="@", infer_datetime_format=True, index_col=0) # german-canteens(filtered).csv
data.index.rename("index", inplace=True)
# evaluates tag_list as list (from string)
data["tags"] = list(map(eval, data["tags"]))
data["meal_name"] = list(map(lambda x : x.replace("\n", " ").lower(), data["meal_name"]))
data["tags"] = list(map(lambda x : [t.lower() for t in x], data["tags"]))

# %%
vgn_set = set(file_to_list("Data/tags/vgn_tags.txt"))
veg_set = set(file_to_list("Data/tags/veg_tags.txt"))
meat_set = set(file_to_list("Data/tags/meat_tags.txt"))
vgn_veg_set  = set(file_to_list("Data/tags/vgn_veg_tags.txt"))

#list_to_file("Data/tags/vgn_tags.txt", vgn_set)
#list_to_file("Data/tags/veg_tags.txt", veg_set)
#list_to_file("Data/tags/vgn_veg_tags.txt", vgn_veg_set)
#list_to_file("Data/tags/meat_tags.txt", meat_set)

# %%
_,_,_, nc_data = tag_categorization_meassure(vgn_set, veg_set, meat_set, vgn_veg_set, data, "tags")
# Out:
# Total: 700958
# Vegan: 5.99% or 41972
# Vegetarian:  50.73% or 355586
# Vegan & Veg.: 1.16% or 8104
# Meat: 15.44% or 108219
# Empty: 14.99% or 105084
# Could not be classified:  11.7% or 81993

# %%
nc_data = data

# %%
nc_names = nc_data["meal_name"]
print(len(nc_names))
print(len(set(nc_names)))
# Out:
# 23271
# 4301

# %%
veg = apply_regexs([".*vegetarisch.*"], nc_names)
nc_names = set(nc_names)-set(veg)
print(len(veg))

vgn = apply_regexs([".*vegan.*"], nc_names)
print(len(vgn))
nc_names = set(nc_names)-set(vgn)
# Out:
# 189
# 306

# %%
terms_meat = ["lachs", "rind", "meat", "beef", "poultry", "pork", "fish", "chicken", "hähnchen", "geflügel", "fisch" ,"krebs", "hack", "tier", "speck", "wild", "fleisch", "schwein", "shrimp", "lamm", "schinken"]

meat_regexs = generate_regex(terms_meat)
meat = apply_regexs(meat_regexs, nc_names )
meat +=  regex_filter(r"\bri\b", nc_names)
meat +=  regex_filter(r"\bsch\b", nc_names)
meat +=  regex_filter(r"\bkr\b", nc_names)
meat +=  regex_filter(r"\bwt\b", nc_names)

print(len(meat))

nc_names = set(nc_names)-set(meat)
meat
# Out:
# 1622
# ['ocean burger - mit kross paniertem seelachs, (glw, fi, mi, sf, se) zitronendip (mi) und pommes frites',
#  'seelachsfilet in kräutereihülle, dijon- senf- soße, karotten, kartoffelstampf',
#  'seelachs, blattspinat, mozzarella, mandeln, tomaten-vollkornreis currysoße',
#  'gebratener seelachs, karotten-kürbis-püree, lauch- mais- salat, sesamöl',
#  'seelachsfilet , tomate, zucchini, kräuterkartoffeln, himbeerjoghurt',
#  'seelachs im backteig remouladensoße kartoffelspalten',
#  'seelachsfilet, kräuter- rührei, dijon- senf- soße, karotten, kräuterkartoffeln (ei, fi, glw, mi, sf)',
#  'seelachs gebraten, karotten- kürbis- püree, sesam, kürbiskerne (fi, mi, se)',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) salzkartoffeln',
#  'seelachsfilet im backteig (fi, glw) erbsen-gurken-dip (3, ei, glw, sl) kartoffelspalten',
#  'seelachsfilet in ei-hülle dillsoße salzkartoffeln eisbergsalat',
#  'seelachsfilet, salbeipesto, (ei, fi, glw) tomaten- sahne [bio]- soße (mi, sl) gnocchi (ei)',
#  'seelachs im backteig (fi, glw, mi, sf) bratkartoffeln erbsen-gurken-dip (3, ei, glw, sl)',
#  'lauwarmer bunter linsensalat, frühlingszwiebeln, rosinen, karotten (sw) seelachsfilet gebraten (fi)',
#  'seelachs paniert remouladensoße kartoffelspalten',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, röstkartoffeln',
#  'knuspriges seelachsfilet 2,70 € ... mit kartoffelspalten und kräuterquark 4,60 €',
#  'seelachs im backteig, balsamicolinsen, meerrettich-stampf-kartoffeln (3, fi, glw, mi, sf, sw)',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) pommes frites',
#  'lachsfilet gebraten (fi) bulgur [bio]- broccoli- karottenpfanne (glw)',
#  'gebratener seelachs,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (3, 5, ei, fi, glw, mi, sf, sw)',
#  'seelachs, blattspinat, mozzarella, mandeln, tomaten-vollkornreis (fi, glw, mi, nmn)',
#  'kürbispfanne, seelachs, reis',
#  'seelachs im backteig remouladensoße gitterkartoffeln',
#  'seelachsfilet à la bordelaise (1, fi, glw) kräutersoße (mi) dillkartoffeln',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, kartoffelpüree',
#  'seelachsfilet, blattspinat, tomaten-farfalle (fi, glw, mi)',
#  'tagesgericht: knuspriges seelachsfilet (fi, glw, mi, sf) kartoffelsalat (ei, sf)',
#  'knuspriges seelachsfilet (fi, glw, mi, sf) kartoffelsalat (ei, sf)',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) gebackene kartoffeln (glw)',
#  'seelachsfilet, salbei-ei-hülle tomaten- sahne (bio)- soße gnocchi',
#  'seelachs in maispanade kirschtomaten-konfit, rucola stampfkartoffeln',
#  'poke-bowl mit shusireis, lachsfilet, avocado, sesam',
#  'one pot pasta: seelachswürfel, tomaten-sahne-soße, grüner pfeffer',
#  'seelachsfilet, kräuterei,tomatenragout, dijon- senf- soße, karotten, kartoffelstampf',
#  'seerlachs im backteig (fi, glw) erbsen-gurken-dip (3, ei, glw, sl) kartoffelspalten',
#  'poke bowl - hawaianischer foodtrend mit lachs, wasabi-soja-marinade, sushireis, avocado, chili-mayo',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) röstkartoffeln (glw)',
#  'überbackener seelachs (fi, mi) cherry-tomatensoße basmatireis',
#  'knuspriges seelachsfilet, remouladensoße',
#  'seelachsfilet à la bordelaise (1, fi, glw, mi) dillkartoffeln',
#  'seelachs, blattspinat, tomatentagliatelle',
#  'begrenztes angebot: gebratener seelachs, rührei, spinatsauce, kartoffeln',
#  'aktion azubiküche: hausgemachter backfisch seelachs warmer kartoffelsalat',
#  'seelachs im backteig remouladensoße röstkartoffeln',
#  'seelachsfilet à la bordelaise (1, fi, glw) dillkartoffeln',
#  'seelachsfilet, dijon- senf- soße, karotten, kartoffelstampf',
#  'gebratenes seelachsfilet, eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln',
#  'seelachs gebraten, karotten- kürbis- püree, sesam, kürbiskerne (fi, glw, mi, se)',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, kräuterkartoffeln',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) pommes frites (glw)',
#  'lauwarmer bunter linsensalat, frühlingszwiebeln, rosinen, karotten seelachsfilet gebraten',
#  'super! food!-lauwarmer bunter linsensalat, frühlingszwiebeln, rosinen, karotten seelachsfilet gebraten',
#  'seelachs tacco remouladensoße kartoffelspalten',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) pommes',
#  'kürbispfanne, seelachs, basmatireis',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) sellerie- kartoffelstampf (mi, sl)',
#  'seelachsfilet gebraten kirschtomaten-konfit, rucola meerrettich-stampfkartoffeln',
#  'begrenztes angebot: seelachsfilet à la bordelaise (1, fi, glw) cherry-tomatensoße reis',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, kräuterkartoffeln (ei, fi, glw, mi, sf)',
#  'seelachsfilet, kräutermarinade, dijon- senf- soße, karotten, kräuterkartoffeln',
#  'seelachsfilet, salbei-ei-hülle (ei, fi, glw) gemüse- kartoffelstampf (mi, sl) sahnesoße (mi)',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, bratkartoffeln',
#  'seelachs gebraten, karotten- kürbis- püree, sesam, kürbiskerne',
#  'seelachs paniert remouladensoße kartoffel- radieschen- salat',
#  'geebratener seelachs, senfsoße, frittierte kartoffel (fi, glw, sf, 3, ei, sl)',
#  'gebratener seelachs, mozzarella, mandeln, spinatpasta (ei, fi, glw, mi, nmn)',
#  'seelachs im backteig tomaten- sahne- soße salzkartoffeln',
#  'seelachs, blattspinat, mozzarella, mandeln, tomaten-vollkornreis',
#  'räucherlachs-bowl (8, fi, glw, mi, sf)',
#  'seelachs paniert cocktailsoße frittierte kartoffeln',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten',
#  'seelachs im backteig (fi, glw, mi, sf) dillsoße (mi) salzkartoffeln',
#  'seelachsfilet gebraten (fi, glw) helle dijon- senf- soße (glw, mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, kräuterkartoffeln (1, ei, fi, glw, mi, sf)',
#  'pasta bar, täglich wechselndes angebot (glw) pasta, kräuter- seelachsragout (fi, glw, mi, sf) pasta, pesto, marinierte tomaten (1, 2, 3, 5, glw, nw, nc, sw)',
#  'ofenkartoffel mit sour creme (mi) ... und lachs + 0,50€ ... und hähnchenstreifen + 0,50€',
#  'gebratener seelachs,eihülle, balsamicolinsen, meerrettich-kartoffeln-ragout',
#  'schlemmerfilet vom seelachs, kräuter-brot-kruste (1, fi, glw, mi) dillkartoffeln',
#  'seelachs im backteig blattspinat salzkartoffeln 3,90€',
#  'seelachs im backteig salzkartoffeln tomaten- sahne- soße',
#  'balsamicolinsenragout mit seelachs, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'begrenztes angebot; wechselnde auswahl reispfanne mit seelachs und currysoße',
#  'seelachs gebraten (fi, glw) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'seelachs im backteig remouladensoße steakhouse fries',
#  'seelachsfilet takko, blattspinat, tomatentagliatelle',
#  'lachsfilet gebraten (fi) mit pasta (glw) in cherry-tomatensoße',
#  'ocean burger - mit kross paniertem seelachs, zitronendip und pommes frites',
#  'seelachs im backteig (fi, glw, mi, sf) erbsen-gurken-dip (3, ei, glw, sl) kartoffelspalten',
#  'begrenztes angebot: seelachs im backteig remouladensoße kartoffelspalten',
#  'seelachsfilet in backteig (fi, glw, mi, sf) tomaten- sahne [bio]- soße (mi) kartoffelpüree (3, 5, mi, sw)',
#  'seelachsfilet, kräuter-ei-hülle (ei, fi, glw) gemüse- kartoffelstampf (mi, sl) sahnesoße (mi)',
#  'seelachs, blattspinat, tomatenpasta',
#  'seelachsfilet gebraten (fi, glw) helle dijon- senf- soße (mi, sf) salzkartoffeln',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) pommes frittes (glw)',
#  'gebratener seelachs,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln',
#  'gebratener seelachs,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (1, 3, 5, ei, fi, glw, mi, se, sf, sw)',
#  'hausgemachtes schlemmerfilet vom seelachs, kräuter- kruste (1, fi, glw) dillkartoffeln',
#  'tagesgericht: knuspriges seelachsfilet (fi) kartoffelsalat (ei, sf)',
#  'lachsfilet gebraten mit pasta in cherry-tomatensoße',
#  'begrenztes angebot seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) salzkartoffeln',
#  'super! food! - lauwarmer bunter linsensalat, frühlingszwiebeln, rosinen, karotten seelachsfilet gebraten',
#  'grünes erbsenpürree, kichererbsenpürree seelachs gebraten',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) röstkartoffeln',
#  'ofenkartoffel räucherlachs (fi, mi)',
#  'seelachsfilet mit tomate und käse überbacken, dijon- senf- soße, blattsalat, kräuterkartoffeln',
#  'begrenztes angebot: seelachs, blattspinat, mozzarella, ratatouille, pasta',
#  'seelachs, blattspinat, tomatentagliatelle (fi, glw, mi, sw, mn)',
#  'seelachs im backteig remouladensoße pommes frites',
#  'begrenztes angebot seelachs im backteig (fi, glw, mi, sf) tomatensoße spaghetti (glw)',
#  'seelachs im backteig (fi, glw, mi, sf) kräutersoße (mi) salzkartoffeln',
#  'kräuter- seelachs (fi, mi) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'seelachs im backteig (fi, glw, mi, sf) kartoffelsalat (ei, sf)',
#  'super! food! - lauwarmer bunter linsensalat, frühlingszwiebeln, cranberries, karotten seelachsfilet gebraten',
#  'seelachsfilet, kräutereihülle, dijon- senf- soße, karotten, kräuterkartoffeln, (ei, fi, glw, mi, sf)',
#  'gebratener seelachs, balsamicolinsen, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'seelachsfilet à la bordelaise (1, fi, glw) kräutersauce (mi) dillkartoffeln',
#  'seelachsfilet gebraten remouladensoße kartoffelspalten',
#  'begrenztes angebot: seelachsfilet gebraten (fi, glw) blattspinat (mi) tomatentagliatelle (glw)',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten (glw)',
#  'gebratener seelachs, karotten-kürbis-püree, lauch- mais- salat, sesamöl (fi, se)',
#  'azubi angebot: lachsfilet gebraten tomaten- sahne- soße bandnudeln',
#  'seelachs gebraten, karotten- kürbis- püree, sesam, kürbiskerne (ei, fi, glw, mi, se, sf)',
#  'seelachs im backteig, blattspinat, mandeln, tomaten-vollkornreis',
#  'seelachsfilet gebraten (fi, glw) helle dijon- senf- soße (mi, sf) kartoffel- kürbis- püree oder basmatireis',
#  'seelachs im backteig (fi, glw, mi, sf) balsamicolinsen, meerrettich-stampf-kartoffeln (3, 5, ei, fi, glw, mi, sf, sw)',
#  'seelachsfilet gebraten (fi, glw) helle dijon- senf- soße (glw, mi, sf) salzkartoffeln',
#  'seelachsfilet, salbei-ei-hülle (ei, fi, glw) tomaten- sahne [bio]- soße (mi) gnocchi (ei)',
#  'tagesgericht: knuspriges seelachsfilet (fi) mit kartoffelsalat (ei, sf)',
#  'poke-bowl mit shusireis, lachsfilet, avocado, sesam (3, ei, fi, glw, se, sl, so)',
#  'begrenztes angebot: seelachsfilet mit kräuterkruste (glw, fi, 1) blauschimmelsoße (mi) gnocchi (ei)',
#  'ofenkartoffel räucherlachs',
#  'seelachs im backteig (fi, glw, mi, sf) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'schlemmerfilet vom seelachs, kräuter-brot-kruste (1, fi, glw) dillkartoffeln',
#  'seelachs im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) frittierte kartoffelbeilage (glw)',
#  'seelachsfilet, salbei-ei-hülle tomaten- sahne- soße gnocchi',
#  'seelachsfilet à la bordelaise (1, fi, glw) dillsoße (mi) salzkartoffeln',
#  'protein power blattsalat bowl, seelachsfilet, quinoa hausgemachtes powerdressing',
#  'seelachs im backteig remouladensoße kroketten',
#  'seelachsfilet in tomaten- sahne- soße cous cous',
#  'gebratener seelachs kirschtomaten-konfit, rucola kräuterkartoffeln',
#  'seelachsfilet, gebraten, dijon- senf- soße, karotten, kräuterkartoffeln',
#  'begrenztes angebot seelachsfilet à la bordelaise (1, fi, glw) curry- kokos- soße (3) broccoli reis',
#  'limited edition seelachs im backteig tomaten- sahne- soße salzkartoffeln',
#  'begrenztes angebot schlemmerfilet vom seelachs, kräuter-brot-kruste (1, fi, glw) helle dijon- senf- soße (glw, mi, sf) röstkartoffeln',
#  'seelachs im backteig (fi, glw, mi, sf) helle dijon- senf- soße (glw, mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) paprika- maissoße (sl) rindergulasch ungarische art (sw)',
#  'mit rindfleisch- köfte türkischer dilljoghurt kichererbsen- bulgur',
#  'rindfleisch- cheeseburger, tomate, salat, basilikum- chili- aioli (3, ei, glw, gld, mi, sf, so, sl) kartoffelspalten',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, se, sf, sl) pommes frites',
#  'pasta bolognese mit rindfleisch 3,50€',
#  'rinder burger, mozzarella, rucola, eisbergsalat (glw, gld, mi, se, sf) tomaten- zwiebel- marmelade (sf, sw) pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rindergulasch mit gemüse (sl, sw) wurstragout mit bohnen und tomate (2, 3, 10)',
#  'ofenkartoffel, rotkohl, rindergulasch (3, 8)',
#  'begrenztes angebot; wechselnde auswahl rindfleischburger, kartoffelspalten',
#  'pasta bolognese mit rindfleisch (1, 2, glw, mi)',
#  'bulgur- salat joghurt- minz- dip mit rindfleisch- köfte',
#  'frisch aus dem wok: rindfleisch mit brokkoli, roter paprika, teriyakisoße und basmatireis',
#  'lahmacun, türkische "pizza", rind, rotkraut, weißkraut, kräuter',
#  'rinderhackbällchen currysoße steakhouse fries',
#  'rinderhacksteak rahmsoße basmatireis',
#  'rindfleisch- burger, mozzarella, tomate, chili- aioli kartoffelspalten',
#  'begrenztes angebot: rindfleischcurry, kokos, karotten, koriander pasta (glw)',
#  'rindergeschnetzeltes spiralnudeln',
#  'rindergulasch (sw, 6) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto kürbis- linsenragout cherry-tomatensoße, rinderhackfleisch',
#  'begrenztes angebot rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sf, sl) pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto rindfleischcurry, kokos, karotten (2, 4, glw, mi, sf, so) tomatensoße (sl, sw)',
#  'rindergulasch ungarische art nudeln (glw)',
#  'rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, so) basmatireis',
#  'elvis burger , rindfleisch, sauerkraut, bbq- soße (2, 8, glw, gld, sf, sl) kartoffelspalten',
#  'pasta bar,: nudelgratin, rinderragout, käsekruste (1, 2, 3, 4, glw, glg, mi, so)',
#  'burrito "mexico", rindfleisch filipino beef, bohnen, paparikacreme, salat (2, glw, so)',
#  'mit rindfleisch- köfte (glw)',
#  'rinderhacksteak jus salzkartoffeln erbsengemüse',
#  'rindergulasch ungarische art salzkartoffeln (glw)',
#  'pasta bolognese mit rindfleisch',
#  'frisch aus dem wok: rindfleisch mit brokkoli, roter paprika, teriyakisoße (glw, so) und basmatireis',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) tomatenpesto (sw) käse -spinat -soße, (1, mi) rindergulasch ungarische art (sw) chicken makhani (mi, nmn, sf) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, glr, glg, glh, gld, mi, se, sf, sl) kartoffelspalten',
#  'gulaschsuppe, rindfleisch (sw) baguettebrot (glw)',
#  'begrenztes angebot rindfleisch- burger, mozzarella, tomate, basilikum- aioli pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi, sl) pesto (1, 3, 5, nw, sw) kräuterrahmsoße (glw, mi, sl) tomatenrahmsoße, rinderhackfleisch, gemüse (1, 3, 5, mi, sl, sw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) bohnenragout, tomate kürbis, mais (se) pesto rindergulasch ungarische art (sw)',
#  'rindfleisch- köfte türkischer kräuterjoghurt kichererbsen- reis',
#  'begrenztes angebot: rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so) basmatireis',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, glg, mi, sl, so) kartoffelspalten',
#  'rindfleisch- burger, limetten-dip, eisbergsalat, süß-saure gurken (1, 2, 3, 5, 8, glw, glr, glg, glh, gld, se, sf, so, sw) kartoffelspalten',
#  'ma po tofu - asiastreetfood aus szechuan, rinderhack, tofu, szechuan pfeffer (1, 2, 4, glw, so)',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, mi) kartoffelspalten',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sf, sl, so) pommes frites',
#  'rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so) reis',
#  'rindfleischcurry, kokos, karotten, koriander (1, 2, 4, glw, mi, so) basmatireis',
#  'begrenztes angebot rindfleischeintopf, curry, kokos, karotten, kartoffeln baguettebrot',
#  'begrenztes angebot: tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan (ei, glw, glr, mi)',
#  'rindfleisch-burger, mozzarella, rucola, eisbergsalat (glw, gld, mi) tomaten- zwiebel- marmelade (sf, sw) pommes frites',
#  'rindfleisch burger burger 3,90 € .... mit pommes frites 5,50 €',
#  'rinderhacksteak zwiebelsoße stampfkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) nudelauflauf al arrabiata (1, 2, 6, glw, sl) rindergulasch ungarische art (sw) hähnchengeschnetzeltes (mi, sl)',
#  'winterliche ofenkartoffel mit rotkohl & rindergulasch (3, 8)',
#  'geschmorter rinderbraten rotkohl kartoffelklöße',
#  'aktionsgericht von unseren auszubildenden gebratene rinderleber, sautierte zwiebeln, apfelscheiben (glw) rotweinsoße (mi, sl, sw) stampfkartoffeln (mi)',
#  'begrenztes angebot bulgur- salat joghurt- minz- dip mit rindfleisch- köfte',
#  'rindergulasch ungarische art (sw) kartoffelspalten',
#  'tagesgericht: pasta bolognese mit rindfleisch (1, 2, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten-spinatsoße rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so)',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- feta creme (3, ei, glw, gld, mi, sf, sl) kartoffelspalten (glw)',
#  'bibimbap bowl - koreanisches reisgericht mit gemüse, rinderhack, ei (ei, en, glw, se, so)',
#  'burger " grana padano "rindfleisch, parmesan, rucola , tomaten, zwiebeln, gitterkartoffeln',
#  'rindfleisch-köfte türkischer dilljoghurt kichererbsen-bulgur',
#  'rindergulasch spiralnudeln (glw)',
#  'rindfleisch-burger mit mozzarella, tomate, basilikum-aioli und pommes frites',
#  'pasta bar, täglich wechselndes angebot (glw) reisnudelauflauf, rindfleischcurry, käse (1, 2, 3, 4, 5, glw, mi, se, sf, so, sw)',
#  'rindfleisch- köfte gemüsereis minz- joghurt- soße',
#  'rindergulasch ungarische art (sw) salzkartoffeln',
#  'rindfleischcurry, kokos, karotten, koriander reis',
#  'begrenztes angebot pasta bar mie-nudeln rindfleischcurry, kokos, karotten, koriander',
#  'rinderleber zwiebelsoße stampfkartoffeln',
#  'rindergulasch ungarische art (sw) spiralnudeln (glw)',
#  'begrenztes angebot: chili- käse- maiseintopf, rindfleisch, paprika',
#  'pasta bar, täglich wechselndes angebot (glw, mi) nudelauflauf, rindergulasch, käse (glw, mi, sw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so)',
#  'keema aloo parkistanisches rinderhackbällchen, bohnen-curry, joghurt',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, nw, sl, so) kartoffelspalten',
#  'rindfleischcurry, kokos, karotten, koriander (1, 2, 3, 4, 5, glw, mi, sf, so, sw) basmatireis',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, glr, glg, glh, gld, mi, se) kartoffelspalten',
#  'gulaschsuppe, rindfleisch, paprika',
#  'rindergulasch ungarische art (ei, mi, sl, sw) salzkartoffeln',
#  'rindergulasch ungarische art (sw) nudeln (glw)',
#  'gemüsepfanne, rindfleisch, oregano reis',
#  'mit rindfleisch- köfte gemüsereis minz- joghurt- soße',
#  'rinderhacksteak salzkartoffeln pilzrahmsoße',
#  'tagesgericht: tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan (1, 2, ei, glw, glr, mi)',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sl) pommes frites',
#  'rindergulasch rosenkohl salzkartoffeln',
#  'ofenkartoffel, rotkohl, rindergulasch',
#  'gemüsepfanne, rindfleisch reis',
#  'rindergulasch ungarische art (sw) sauerkraut bratkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tortelliniauflauf, kicherbsen, spitzkohl, jackfruit (1, 2, 3, glw, nc) rindergulasch, gemüse (sw)',
#  'rindergulasch ungarische art (sw) salzkartoffeln sauerkraut',
#  'kima alu parkistanisches rinderhackbällchen, bohnen-curry, joghurt',
#  'begrenztes angebot: rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sf, sl) kartoffelspalten (glw)',
#  'chili- käse- maiseintopf, rindfleisch, paprika baguettebrot',
#  'rindergulasch ungarische art (sw) salzkartoffeln oder nudeln (glw)',
#  'weißkohleintopf, rindfleisch, kartoffeln (sl) baguettebrot (glw)',
#  'pasta bar, nudeln mit rindfleisch (1, 2, glw, mi)',
#  'pasta bar, täglich wechselndes angebot pasta-rindfleisch-auflauf mit käse überbacken (2, 4, glw, mi, sf, so)',
#  'rindfleisch- köfte minz- joghurt- soße gemüsereis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rote- linsen- bolognese (sl) dijon- senf- soße, rindfleischstreifen (2, mi, sf, sl)',
#  'burger grana padano, rindfleisch, parmesan, rucola, tomaten (2, ei, glw, gld, mi, sf, so) kartoffelspalten zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'burger " grana padano "rindfleisch, parmesan, rucola , tomaten, zwiebeln, (2, 3, 8, ei, glw, mi, se, sf, sl) gitterkartoffeln (glw)',
#  'rinderhacksteak jus kartoffelgratin erbsen, mais, paprika',
#  'pasta bar, täglich wechselndes angebot pasta bolognese mit rindfleisch (1, 2, glw, mi) pasta, rotes pesto, oliven (1, 3, 5, 6, glw, mi, nw, sw)',
#  'pasta bar, täglich wechselndes angebot pasta, rindfleisch - caldereta beef (1, 2, 4, fi, glw, mi, sf, so)',
#  'rinderroulade (2, 3, glw, sf) champignonsoße (mi) röstkartoffeln',
#  'rindergulasch ungarische art (glw, sw) salzkartoffeln',
#  'moussaka, rindfleisch, radieschen-eisberg- salat',
#  'begrenztes angebot: rinderbraten rotweinsoße kartoffelgratin',
#  'rindergulasch ungarische art (sw) pasta (glw)',
#  'begrenztes angebot sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, mi) gitterkartoffeln (glw)',
#  'bibimbap bowl rind koreanisches reisgericht mit gemüse und rinderhack',
#  'limited edition curryreispfanne , rindfleisch ,gemüse',
#  'wrap mit gebratenem rinderhack, knackigem gemüse-salatmix salat (2, glw) und chili quark-dip (mi)',
#  'rinderhacksteak jus kroketten',
#  'tortelloni in rauke, sonnenblumenkernen, tomaten .... mit rindfleisch- .....oder quinoa- spinat- füllung 3,90 €',
#  'rindfleischcurry, kokos, karotten, sprossen, lauch basmatireis',
#  'rinderhacksteak pfefferrahmsoße pommes frites',
#  'rinderhacksteak reis jus',
#  'rinderhacksteak zwiebeljus kartoffelgratin',
#  'tagesgericht tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan, (1, 2, ei, glw, glr, mi)',
#  'rinderhacksteak jus kartoffelgratin mischgemüse',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) indisches kidneybohnen-curry (1) rindergulasch ungarische art (sw)',
#  'burger grana padano, rindfleisch, parmesan, rucola, tomaten (2, ei, glw, mi, se, sf, so) kartoffelspalten',
#  'rindfleisch- köfte pfefferjus kroketten',
#  'bibimbap bowl rind',
#  'szechuan rindfleisch basmatireis',
#  'rindfleischcurry, kokos, karotten,mie nudeln',
#  'burger " grana padano "rindfleisch, parmesan, rucola , tomaten, zwiebeln, (2, 3, ei, glw, gld, mi, sf, sl) pommes frites',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, mexicogemüse, käsekruste (ei, glw, mi, sl) pasta bolognese mit rindfleisch (1, 2, glw, mi)',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sl) kartoffelspalten',
#  'parmesan - burger, rindfleisch, parmesan, salat, tomaten, zwiebeln, gurken (2, 3, 8, ei, glw, mi, se, sf, sl) kartoffelspalten (glw)',
#  'chili con carne, mit rindfleisch und fladenbrot 3,50 €',
#  'rinderbraten gekocht meerrettichsoße wurzel- kartoffelstampf',
#  'rindfleischeintopf, weiße bohnen, rosmarin, kapern,mu-err-pilz, koriander baguettebrot',
#  'beef bowl, rinderhack, tomatensalsa, reis (glw, mi, so)',
#  'rindfleisch - burger, soja- chili- dip, tomate, gurke, rucola, emmentaler (glw, mi, se, sf, so) kartoffelspalten zu dem burger gibt es ein fritz-getränk zum aktionspreis von 1,40€ dazu !! wir freuen uns auf euch',
#  'feuertopf mit rindfleisch, wurstscheibchen, paprika, gemüse (sl, so, 8, 1, 2, 3, 10)',
#  'tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan',
#  'rindfleisch- burger, soja- paprika- dip, tomate, gurke, salat pommes frites',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli country steak frites',
#  'tagesgericht tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan (1, 2, ei, glw, glr, mi)',
#  'rindergeschnetzeltes stroganoff (8, glw, glg, mi, sf, sl, so) broccoli spätzle (ei, glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) käse -lauchsoße (mi) rindfleischcurry, kokos, karotten, koriander (1, 2, 3, 4, 5, glw, mi, sf, so, sw)',
#  'begrenztes angebot pasta bar nudeln rinderragout, bohnen',
#  'hack-tofu (bio)- bowl, rinderhackfleisch, biotofu, chinakohl, nudeln (glw, so)',
#  'rindfleischcurry, kokos, karotten, koriander basmatireis',
#  'ma po tofu - asiastreetfood aus szechuan, rinderhack, tofu, szechuan pfeffer',
#  'pad thai - gebratene reisbandnudeln, ei, tofu, tamarindenpaste, fischsauce, shrimps',
#  'bibimbap bowl (ei, en, glw, se, so) koreanisches reisgericht mit gemüse, rinderhack und spiegelei',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli kartoffelspalten',
#  'tagesgericht pasta bolognese mit rindfleisch (glw, mi) pasta bolognese mit rindfleisch',
#  'rindergulasch ungarische art (1, 3, 5, sw) salzkartoffeln',
#  'begrenztes angebot rinderhacksteak remouladensoße kartoffelspalten',
#  'rinderhacksteak jus kartoffelgratin',
#  'begrenztes angebot: rindergulasch ungarische art (sw) salzkartoffeln',
#  'bibimbap bowl - koreanisches reisgericht mit gemüse, rinderhack, ei',
#  'pasta bar, täglich wechselndes angebot bratnudeln, gemüse, erdnüsse (en, glw, nc, so) pasta bolognese mit rindfleisch (1, 2, glw, mi) pasta, rucolapesto, tomatenwürfel (glw)',
#  'campus welcome aktion: bibimbap bowl - koreanisches reisgericht mit gemüse und rinderhack',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, glg, mi, sl, so) pommes frites',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sf, sl) pommes frites',
#  'rinderbraten (sl) rotweinsoße (glw, glg, mi, sl, so) salzkartoffeln',
#  'rindergulasch ungarische art spiralnudeln (glw)',
#  'rinderroulade jus brokkoli, salzkartoffeln',
#  "schwentine original: rindergulasch wie bei jan's oma, spätzle, pilze, mit salat(ei, sf, glw, sw)",
#  'rindergeschnetzeltes, paprika, champignons (mi, sf, sw) salzkartoffeln',
#  'rindfleischcurry, kokos, karotten, koriander (1, 2, 4, glw, mi, sf, so) basmatireis',
#  'pasta bar, täglich wechselndes angebot (glw) pasta bolognese mit rindfleisch (1, 2, glw, mi) pasta, ratatouille (glw)',
#  'rindfleischcurry, kokos, karotten, koriander vollkornreis',
#  'tagesgericht tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan (ei, glw, glr, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) indisches kichererbsen curry (1, glw, mi, sf) nudelauflauf, rindergulasch, mozzarella (glw, mi, sw)',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, mi) pommes frites',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, glg, mi, sl, so) kartoffelspalten zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'elvis burger - menü , rindfleisch, sauerkraut, bbq- soße, (2, 8, glw, gld, sf, sl) kartoffelspalten, dazu gibt es ein mio-getränk für nur 1,30 € zum menü wir freuen uns auf euch',
#  'mit rindfleisch- köfte 3,80€',
#  'rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so) basmatireis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto rindfleischcurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so) tortelloniauflauf, gemüsesoße, fleischklöße, gouda (ei, glw, mi)',
#  'chili con carne, mit rindfleisch 3,50€ 1/2 flagueline rustikal',
#  'rinderroulade rotweinsoße brokkoli, kartoffelklöße',
#  'pasta bar: pasta, rindergeschnetzeltes (1, 2, 3, 4, glw, glg, mi, so)',
#  'begrenztes angebot: pommes frites chili - rindfleisch, -mais, -kidneybohnen, -mozzarella topping ajoli- dip',
#  'pasta bolognese mit rindfleisch, (2, ei, glw, mi)',
#  'rinder- gulasch salzkartoffeln',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sf, sl) kartoffelspalten (glw)',
#  'pasta bar, täglich wechselndes angebot avocado- pasta, tomatenwürfel (3, glw) pasta, kürbispesto (1, 2, glw, mi) nudelauflauf, rindfleisch, gemüse, käse überbacken (2, 4, glw, mi, sf, so)',
#  'pasta bolognese mit rindfleisch (glw, mi)',
#  'pad thai- gebratene reisbandnudeln, ei, tofu [bio], tamarindenpaste, fischsauce, shrimps',
#  'mit rindfleisch- köfte',
#  'begrenztes angebot rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, se, sf, sl) kartoffelspalten',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rindfleischcurry, kokos, karotten (2, 4, glw, mi, sf, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi, sl) rucolapesto (nc) käsesoße (1, mi) tomatenrahmsoße, rinderhackfleisch, gemüse (1, 3, 5, mi, sl, sw) currywurst hot pot(t) (2, 3, 10, sf, sl)',
#  'sloppy joe burger, brioche bun, rinderhack, gouda (ei, glw, mi) gitterkartoffeln (glw)',
#  'tagesgericht: ofenkartoffel, rotkohl, rindergulasch (3, 8)',
#  'ofenkartoffel, rotkohl, rindergulasch (3, 8, sw)',
#  'frisch aus dem wok: rindfleisch mit brokkoli, paprika, sprossen, teriyakisoße und basmatireis',
#  'tagegericht pasta bolognese mit rindfleisch (1, 2, glw, mi)',
#  'omelette bowl, omelettestreifen, rinderhack, champignons, cashew-dip, nudeln (ei, glw, mi, nc)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto rindergeschnetzeltes, paprika, champignons (mi, sf, sw) kräuter -käsesoße (mi)',
#  'rindfleisch- köfte türkischer dilljoghurt kichererbsen- bulgur',
#  'pasta bar, täglich wechselndes angebot (glw) pasta, kürbis-kokosnusssoße (glw) nudelauflauf, rindfleisch, käsekruste (glw, mi, sf, sl)',
#  'rindergulasch ungarische art (sw) wurzel- kartoffelstampf (mi, sl)',
#  'wrap mit gebratenem rinderhack, knackigem gemüse-salatmix salat und chili quark-dip',
#  'pfefferpotthast "westfälisches rinderragout" (2, glw, glg, sf, sl, so, sw) mit salzkartoffeln',
#  'tortellini rindfleisch mit tomaten, rucola, sonnenblumenkernen, parmesan (ei, glw, glr, mi)',
#  'begrenztes angebot rindfleischcurry, kokos, karotten, koriander basmatireis',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, gld, mi, sf, sl) kartoffelspalten',
#  'rindfleisch- burger, mozzarella, tomate, basilikum- aioli pommes frites',
#  'begrenztes angebot rindfleisch- burger, mozzarella, tomate, basilikum- aioli (3, ei, glw, glr, glg, glh, gld, mi, se, sf, sl) kartoffelspalten',
#  'rindergulasch ungarische art pariser karotten spätzle',
#  'pasta bar, täglich wechselndes angebot pasta,champignon - specksoße (2, 3, 4, glw) pasta, avocadopesto, tomatenwürfel (3, glw) nudelauflauf, rindfleisch, gemüse, käsekruste (1, 2, glw, glh, mi)',
#  'rindfleisch- köfte kräuterkartoffel, rosmarin minz- joghurt- soße',
#  'begrenztes angebot pasta bar nudelauflauf ,rindfleisch, gouda',
#  'rinderhacksteak, kohlrabi, paprika, schnittlauchkartoffeln',
#  'rindergulasch ungarische art salzkartoffeln',
#  'pasta bolognese mit rindfleisch (2, ei, glw, mi)',
#  'begrenztes angebot: (ei) meatballsandwich (2, 6, glw, mi, sl) meatballsandwich',
#  'filipino beef caldereta vollkornreis',
#  'filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) basmatireis',
#  'burrito "mexico", rindfleisch filipino beef, bohnen, paparikacreme, salat (2, glw, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja-bolognese (glg, sl, so) mangoldpesto (1, 2, sf) filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, sl, so)',
#  'filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) vollkornreis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) nudelauflauf, käsekruste (ei, glw, mi, sl)',
#  'filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot pasta, rindfleisch - caldereta beef (1, 2, 4, fi, glw, mi, sf, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so)',
#  'beef bowl',
#  'beef bowl, rinderhack, tomatensalsa, reis (glw, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) linsen -gemüseragout (sw) filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so)',
#  'begrenztes angebot filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) basmatireis',
#  'begrenztes angebot roastbeef kalt remouladensoße (3, 8, ei, glw, sf, sl) röstkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) gremolata filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so)',
#  'begenztes angebot filipino beef caldereta basmatireis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) currywurst hot pot(t) (2, 3, 10, sf, sl)',
#  'filipino beef caldereta basmatireis',
#  'filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, sl, so) basmatireis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) filipino beef caldereta (1, 2, 4, fi, glw, mi, sf, so) tomatensoße',
#  'röstkartoffeln mit feldsalat, rucola (5, glw, sw) barbecuesoße (glw, sl) pulled pork (2)',
#  'pulled pork burger (2, glw, gld) kartoffelspalten',
#  'mecklen pork burger, fetakäse, tomaten-zwiebel-marmelade, rucola, eisbergsalat tomaten- zwiebel- marmelade',
#  'begrenztes angebot pasta bar pulled pork- nudelauflauf',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) nudelauflauf, pulled pork , käse (glw, mi) kichererbsensoße',
#  'pulled pork burger',
#  'pulled pork burger im laugenbun (glw, gld, sf, so) pommes',
#  'röstkartoffeln mit feldsalat, rucola barbecuesoße pulled pork',
#  'begrenztes angebot pasta bar nudelauflauf-pulled pork',
#  'pulled pork burger (glw, gld) kartoffelspalten',
#  'pulled pork burger (2, glw, gld) kartoffelspalten zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'burrito, pulled pork, bohnen, guacomole, salat (2, glw)',
#  'pulled pork burger (1, 2, glw, gld, mi, sf, so) kartoffelspalten',
#  'pulled pork, honig, piment (2) fenchel- karotten salat (mi) salzkartoffeln',
#  'begrenztes angebot: pulled pork burger steakhouse fries',
#  'pulled pork burger, rotkrautsalat, kräutercreme (2, glw, gld, so) kartoffelspalten',
#  'pulled pork burger (glw, glg, gld) kartoffelspalten',
#  'pulled pork burger steakhouse fries',
#  'ofenkartoffel, sour creme pulled pork coleslaw',
#  'southern indian fish curry (2, en, fi, sf, sw) basmatireis',
#  'fish and chips remouladensoße pommes frites',
#  'begrenztes angebot southern indian fish curry basmatireis',
#  'southern indian fish curry (2, en, fi, sf) langkornreis',
#  'southern indian fish curry (2, en, fi, sf) basmatireis',
#  'fish & chips (ei, fi, glw, mi) cocktailsoße (3, ei, glw, mi, sl)',
#  'southern indian fish curry basmatireis',
#  'begrenztes angebot planted chicken, nasi goreng (2, glw, se, so)',
#  'planted chicken curry kokos, karotte, basmatireis (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto sauer-scharfe-soße, mu err pilze, jackfruit [bio], tofu, planted.chicken (3, glw, se, sf, so) wurstragout, gemüse (2, 8, 10, sw)',
#  'chicken crossies (glw) rucolapesto (mi) gnocchi (ei, glw)',
#  'begrenztes angebot hot chickenburger (2, 3, ei, glw, gld, sl) kartoffelspalten',
#  'cashew-chicken-bowl',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto paprikasoße, planted pulled chicken bbq (glh, sf, sl) nudelauflauf, blattspinat, tomatenfrischkäsesoße, mozzarella (glw, mi)',
#  'ceasars salad - eisberg, chicken crossies, bacon, hartkäse, croutons (2, 3, 4, 10, ei, glw, mi, sf, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kichererbsen curry mit kürbis, blumenkohl und planted.chicken (sf) nudelauflauf, käsekruste (glw, mi, sl)',
#  'chicken crossies cocktailsoße kartoffelspalten',
#  'pasta bar, täglich wechselndes angebot pasta (glw) chicken makhani (mi, nmn, sf) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chicken makhani basmatireis',
#  'planted chicken tenders (glw) cocktailsoße (3, ei, glw, sl) kartoffelspalten',
#  'planted.chicken rotkohl (1, 3, 5, 8, sw) frittierte kartoffelbeilage (glw) orangensoße',
#  'planted chicken, kokos, karotte, basmatireis (mi, sf)',
#  'planted chicken softshell tacos, limette, avocado, koriander (glw, sf, so)',
#  'hot chickenburger (2, 3, ei, glw, gld, sl) kartoffelspalten (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) tomatenpesto (sw) käse -spinat -soße, (1, mi) rindergulasch ungarische art (sw) chicken makhani (mi, nmn, sf) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chicken crossies (glw) cocktailsoße (3, ei, glw, sl, 6, so, sf) kartoffelspalten',
#  'chicken crossies (glw) coleslaw (3, ei, glw, mi, sl) pommes frites',
#  'burger im menü mit fritz 0,33l chicken burger (2, 3, ei, glw, se, sl) mit kartoffelspezialitäten',
#  'chicken crossies (glw) cocktailsoße (3, ei, glw, sl) kartoffelspalten',
#  'chicken burger (2, 3, ei, glw, glg, gld, sl) preiselbeerchutney (1, 2, 3, 5, sf, sw)',
#  'chicken makhani basmatireis indisches butterhuhn joghurt[bio], tomate, mandeln',
#  'chicken wings, bulgur(bio)- tomaten- rucola- salat',
#  'begrenztes angebot chicken makani pfefferrahmsoße pommes frites',
#  'chicken makhani (mi, nmn, sf) jasminreis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'planted chicken alfredo, blumenkohlsoße, pasta (glw, glh, nc, sf, so)',
#  'weihnachtsessen: planted.chicken, mariniert rotkohl (1, 3, 5, sw) kroketten (glw) orangensoße',
#  'chicken wings mit bulgur-tomaten-rucola-salat',
#  'begrenztes angebot planted.chicken makhan (1, glh, nmn, sf) gnocchi (glw) indisches butter planted.chicken, tomaten, mandeln, kokosmilch',
#  'begrenztes angebot chicken makhani (mi, nmn, sf) basmatireis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'pikante sesamnudeln, asiatisches pfannengemüse (en, glw, se, so) chicken makhani (mi, nmn, sf) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'tagessuppe: geflügelcremsuppe mit planted chicken (sl, mi)',
#  'hot chickenburger (2, glw, gld, sf, sl, so) kartoffelspalten',
#  'crispy chickenburger pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto planted.chicken, gemüseragout (2, en, glw, glh, se, so) currywurst hot pot(t) (3, 10, sf, sl)',
#  'tagesgericht burger im menü mit fritz 0,33l chicken burger (2, 3, ei, glw, se, sl) ... mit pommes frites',
#  'chicken makani - indisches butterhuhn mit tomaten, joghurt, mandeln, chili, knoblauch (mi, nmn, sf)',
#  'tagesgericht chicken burger (2, 3, ei, glw, glg, gld, sl) preiselbeerchutney (1, 2, 3, 5, sf, sw)',
#  'chicken bullar pommes frites rahmsoße',
#  'planted chicken, nasi goreng (2, glw, se, so)',
#  'begrenztes angebot: wechselnde auswahl chicken makhani mit duftreis (mi, nmn, sf)',
#  'chicken wings, bulgur- tomaten- rucola- salat',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto gemüsecurry, planted.chicken (glh, mi, sf, so)',
#  'grilled chicken burger preiselbeerchutney pommes frites',
#  'burger im menü mit fritz 0,33l hot chickenburger (giw, 1, mi, se, sl) ... mit frittierten kartoffeln',
#  'chicken crossies (glw) tomatensoße basmatireis',
#  'chicken makhani basmatireis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'begrenztes angebot chicken crossies (glw) cherry-tomatensoße basmatireis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten- gemüsesoße (1, 3, 5, sf, sw) planted.chicken curry, gemüse, tahina dip (3, se, sf, so) sauer-scharfe-soße, mu err pilze, jackfruit [bio], tofu (1, 2, 3, 4, glw, se, so)',
#  'limited edition chicken wings süßkartoffel pommes barbecuesoße',
#  'planted chicken- kokus- curry (mi, nmn, sf) basmatireis oder bulgur [bio] (glw) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chicken crossies, cocktailsoße (3, ei, glw, gld, sl, so) gemüsesticks & pommes fritiert (glw)',
#  'long chicken burger, brioche bun, salat, rauch-dip, tortillachips (ei, glw, mi, sf, so) pommes frites',
#  'planted chicken crossies (glw) cocktailsoße (3, ei, glw, sl) kartoffelspalten',
#  'hot chickenburger (2, 3, ei, glw, gld, sl) pommes frites',
#  'hot chickenburger (1, 2, 3, 10, 12, mi, ei, glw, gld, sl) pommes frites',
#  'grilled chicken burger 3,90 € ... mit pommes frites 5,50 €',
#  'begrenztes angebot chicken makhani basmatireis indisches butterhuhn joghurt[bio], tomate, mandeln',
#  'tagesgericht: chicken burger (2, 3, ei, glw, se, sl) potatoe wedges + 2,00 € preiselbeerchutney (1, 2, 3, 5, sf, sw)',
#  'chicken makani - indisches butterhuhn mit tomaten, joghurt, mandeln, chili, knoblauch',
#  'almost chicken burger (glw, gld) bunte fritten (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) asiatisches geschnetzeltes ,planed chicken (glw, so)',
#  'hot chickenburger pommes frites',
#  'pulled planted chicken burger (glw, glh, gld, sf) kartoffelspalten',
#  'chicken makhani (mi, nmn, sf) reis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chicken crossies (glw) quarkdip (3, mi, sl) pommes frites',
#  'begrenztes angebot planted.chicken, mariniert rotkohl (1, 3, 5, 8, sw) kroketten (glw) orangensoße',
#  'chicken burger (2, 3, ei, glw, glg, gld, sl) chilimayonnaise (2, 3, ei, glw, sl)',
#  'chicken crossies (glw) cocktailsoße (3, ei, glw, mi, sl) kartoffelspalten',
#  'planted chickencurry, kokos, karotten, koriander (2, 4, glw, mi, sf, so) basmatireis',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, plandet chicken, käsekruste (ei, glw, mi, sf, sl) currywurstragout, pasta (3, 10, glw, sf, sl)',
#  'planted.chicken makhan (1, glh, nmn, sf) basmatireis indisches butter planted.chicken, tomaten, mandeln, kokosmilch',
#  'hot chickenburger (2, 3, ei, glw, gld, sl) kartoffelspalten',
#  'planted chicken, rucolasoße, bandnudeln (glw, mi, sf)',
#  'chicken crossies (glw) cocktailsoße (3, ei, glw, sl) pommes frites',
#  'nasi goreng, planted chicken (2, glw, se, so)',
#  'hot chickenburger (2, 3, ei, glw, gld, sl, so) pommes frites',
#  'chicken crossies (glw) champignonsoße (mi) röstkartoffeln',
#  'streng limitiert: chicken burger mit pommes (2, 3, ei, giw, gid, sl)',
#  'planted chicken streifen, rucolasoße, bandnudeln (glw, mi)',
#  'chicken makhani (mi, nmn, sf) basmatireis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'burrito,planted chicken, bohnen, guacomole, salat (2, glw, sf)',
#  'chicken makani basmatireis',
#  'chicken crossies, (glw), cocktailsoße, (3, 5, ei, glw, mi, sl), kartoffelspalten',
#  'chicken crossies pfefferrahmsoße kroketten',
#  'cashew-chicken-bowl, basmati reis, paprika, brokkoli, honig, chili, ingwer',
#  'begrenztes angebot: spicy chickenburger (2, 3, ei, glw, gld, sl) zu lecker - schon ausverkauft',
#  'hot chickenburger (1, 2, 3, 10, ei, glw, gld, sl, 12, mi) pommes frites',
#  'hot chickenburger (2, 3, ei, glw, glr, glg, glh, gld, se, sl) pommes frites',
#  'tagesgericht burger im menü mit fritz 0,33l chicken burger (2, 3, ei, glw, se, sl, so) ... mit pommes frites',
#  'planted.chicken makhan (1, glh, nmn) basmatireis indisches butter planted.chicken, tomaten, mandeln, kokosmilch',
#  'hot chickenburger (1, glw, mi, se, sl)',
#  'kritharaki (griechische reisnudeln), planted. chicken filet, kräuterquark (2, en, glw, so, mi, 6, sl)',
#  'grilled chicken burger preiselbeerchutney als menü mit fritz + 1,00 €',
#  'chicken makhani (mi, nmn) basmatireis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chickenburger mit tomate und parmesan (2, 3, ei, glw, gld, sl) pommes frites',
#  'planted chicken alfredo, blumenkohlsoße, pasta (glw, nc, so)',
#  'begrenztes angebot hot chickenburger (2, 3, ei, glw, gld, sl) pommes frites',
#  'begrenztes angebot chickenburger (glw, se, sf, so) gemüsesticks & pommes fritiert (glw)',
#  'hot chickenburger kartoffelspalten',
#  'chicken makhani (mi, nmn, nc, sf) basmatireis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'cashew-chicken-bowl (2, glw, nc, se, sl, so)',
#  'planted chicken makhani (mi, nmn, sf) basmatireis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chicken crossies (glw) cocktailsoße (3, ei, glw, mi, sl) kartoffelspalten (glw)',
#  'weihnachtsessen: planted.chicken, mariniert rotkohl (1, 3, 5, 8, sw, so, giw) kroketten (glw) orangensoße',
#  'chicken makhani (mi, nmn, sf) langkornreis indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'begrenztes angebot chicken crossies (glw) cocktailsoße (3, ei, glw, sl) frittierte gemüsesticks (glw)',
#  'tagesgericht burger im menü mit fritz 0,33l chicken burger (2, 3, ei, glw, se, sl) preiselbeerchutney (1, 2, 3, 5, sf, sw) ... mit pommes frites',
#  'rezepte-duell indisches butter chicken (mi, so) basmatireis',
#  'hot chickenburger (2, 3, ei, glw, glg, gld, sl) pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kichererbsen, planted.chicken curry (sf)',
#  'planted chickencurry curry- kokos- soße (3) broccoli süßkartoffel-mais-pürre',
#  'hot chickenburger (2, 3, ei, glw, glg, gld, sl) kartoffelspalten',
#  'spargelragout, chickencrossies (2, 3, glw, mi)',
#  'planted chicken streifen, rucolasoße, bandnudeln (glw, mi, sf)',
#  'pasta bar, täglich wechselndes angebot chicken makhani (mi, nmn, sf) mie-nudeln (glw, se) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'chicken crossies (glw) cocktailsoße (3, ei, glw, mi, sl) pommes frites',
#  'crispy chickenburger kartoffelspalten',
#  'planted bbq chicken (glh, sf) quark [bio]- knoblauch- dip (1, 3, ei, glw, mi, sf, sl) pommes frites',
#  'tagesgericht chicken burger (2, 3, ei, glw, se, sl) preiselbeerchutney (1, 2, 3, 5, sf, sw)',
#  'planted.chicken makhan (1, glh, nmn, sf) reis indisches butter planted.chicken, tomaten, mandeln, kokosmilch',
#  'pulled chicken burger, mozzarella, rucola, eisbergsalat (glw, gld, mi) tomaten- zwiebel- marmelade (2, sf, sw) pommes frites',
#  'cashew chicken bowl mit jasminreis, brokkoli, paprika, honig, limette',
#  'ceasars salad - eisberg, chicken crossies, bacon, hartkäse, croutons (2, 3, 4, 10, ei, fi, glw, mi, sf, sl)',
#  'weihnachtsessen: planted.chicken, mariniert rotkohl (1, 3, 5, 8, sw) kroketten (glw) orangensoße',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) süßkartoffel- paprika- soße, planted chicken (sf, sl) gemüse- fisch- ragout (fi, glw, mi)',
#  'chicken bullar rahmsoße stampfkartoffeln',
#  'hummus (se) planted.chicken curry, gemüse tahina dip (3, se, sf, so) naan brot (glw, so)',
#  'ofenkartoffel hähnchenstreifen',
#  'hähnchen wiener [bio] (2)',
#  'kroketten, gemüse hähnchen vom grill rahmsoße',
#  'curry- gemüse- eintopf, hähnchenstreifen (mi, so) baguettebrot (glw)',
#  'hähnchenschnitzel (glw) cocktailsoße (2, 3, ei, glw, mi, sl) basmatireis',
#  'hähnchen-piccata milanese (glw, mi) cherry-tomatensoße rosmarinkartoffeln',
#  'hähnchenschnitzel cordon bleu gitterkartoffeln geflügelrahmsoße',
#  'hähnchen-piccata milanese cherry-tomatensoße pasta',
#  '...und hähnchenstreifen',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto hähnchenbruststreifen, rucolasoße (mi)',
#  'döner teller mit hähnchen, salat,',
#  'hähnchenschnitzel cordon bleu champignonsoße kroketten',
#  'bandnudeln cherry-tomatensoße hähnchenschnitzel, knuspermantel',
#  'tagesgericht: röstkartoffeln, mediterranes gemüse, kräuterquark (mi) ... und hähnchen vom grill + 1,80 € (glw, sf)',
#  'bulgur-salat (2, glw) ...und hähnchenstreifen',
#  'hähnchenschenkel, zitronen-salbeimarinade coleslaw (3, ei, glw, mi, sl) pommes frites',
#  'begrenztes angebot hähnchen-piccata milanese (glw, mi) cherry-tomatensoße spaghetti (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, glg, mi, sf, so) chili sin carne (2) erbsen- cashewkern- pesto (nw, nc) tomatensoße, gemüse, hähnchenstreifen (glw, mi, sf, sw)',
# ...
#  'chop suey!, (1, 2, 4, en, fi, glw, so), reisnudeln, hähnchen, wokgemüse, sojasauce',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) rucolapesto (nc) paprika- maissoße, gemüse (sl) gemüse- hähnchen- pfanne (2, 5, nc, se, sl)',
#  'hähnchen-piccata milanese (glw, mi) tomatensoße bandnudeln (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto kokos-currysoße, gemüse, erdnuss, hähnchenstreifen (en, glw, se, so)',
#  'knusper- hähnchenschnitzel paprikasoße reis leipziger allerlei',
#  'tagesgericht: bulgur-salat (2, glw) joghurt [bio]- minz- dip (mi) ... und hähnchenstreifen + 1,70 € ... undfalafel + 1,60 € (glw)',
#  'hähnchenbruststreifen, rucolasoße, spiralnudeln (glw, mi)',
#  'hähnchenbockwurst [bio] (2)',
#  'pasta bar, täglich wechselndes angebot pasta (glw) hähnchen-tomaten-rosmariensoße',
#  'hähnchenbrust tomatensoße basmatireis',
#  'hähnchenschnitzel cordon bleu geflügelsoße broccoli basmatireis',
#  'hähnchenbruststreifen, rucolasoße, reis',
#  'hähnchenbrust in curry-grillmarinade fetacreme kräuterbaguette',
#  'hähnchensteak cherry-tomatensoße basmatireis',
#  'hähnchenschenkel, zitronen-salbeimarinade karotten- pfirsich - konfit polenta',
#  'hähnchenschnitzel, knuspermantel (glw, glg) pommes frites potatoe wedges',
#  'hähnchenbruststreifen, rucolasoße, nudeln (glw, mi)',
#  '"your favorites" hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) champignonsoße (mi) bratkartoffeln',
#  'hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) champignonsoße (mi, sl) bratkartoffeln',
#  '...mit hähnchenschnitzel im knuspermantel (glw, glg)',
#  'tagesgericht ofenkartoffel hähnchenstreifen (mi)',
#  'nutzt auch gerne unser cafeteriaangebot . knuspriges hähnchenschnitzel',
#  'pasta bar: hähnchenstreifen, spargelragout, fleischklöschen (1, 2, 3, 4, glw, glg, mi, so)',
#  'hähnchengyros, griechischer weißkrautsalat, vollkornreis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) paprika- maissoße, jackfruit, bohnen (3, glw, sl, so) hähnchenbruststreifen, tomaten-sahne-soße (mi)',
#  'tagesgericht: couscous-salat (2, glw) joghurt [bio]- minz- dip (mi) mit falafel (glw, sl) +1,60€ ...und hähnchenstreifen + 1,70€',
#  'tagesgericht: hähnchenschnitzel in knuspermantel, pommes frites, cocktailsoße (3, 5, ei, glw, glg, mi, sl, sw)',
#  'bratnudeln, hähnchenstreifen, zuckerschoten, basilikum',
#  'hähnchen piccata, salbeisoße reisnudeln',
#  'hähnchenbrust, pfefferrahmsoße kaisergemüse kroketten',
#  'hähnchenbruststreifen, rucolasoße, bandnudeln (glw, mi)',
#  'hähnchenschnitzel cordon bleu champignonsoße bratkartoffeln',
#  'gemüse- hähnchen- pfanne, aprikosen, cashewkerne, bulgur (2, 5, glw, nc, se, sl)',
#  'curry-hähnchen mit blumenkohl-spinat-gratin, (5, mi, sf, sw) curry-joghurt-dip (mi, sf) und wildreis',
#  'makkaroni- hähnchen- auflauf (glw, mi)',
#  'hähnchenbrust, sesamkruste, basilikum- knoblauch- dip, gnocchis',
#  'hähnchenschnitzel, knuspermantel, (glw, glg)',
#  'hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) champignonsoße (mi) kartoffelspalten (glw)',
#  'hähnchenschnitzel cordon bleu champignonsoße röstkartoffeln',
#  'ofenkartoffel,sour creme, hähnchenstreifen',
#  'tagesgericht: kartoffelgratin, hähnchenbruststreifen, gouda (ei, mi)',
#  'hähnchenbrust, curry-grillmarinade naan brot melonenchutney',
#  'tagesgericht: couscous-salat (2, glw) mit falafel (glw, sl) ...und hähnchenstreifen',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße (1, 3, 5, nw, sw) hähnchengeschnetzeltes, champignons (mi)',
#  'hähnchengyros, griechischer weißkraut- paprikasalat, basmatireis',
#  'tagesgericht bandnudeln (glw) in cherry-tomatensoße ...mit hähnchen- piccata in parmesanhülle + 2,90 € (glw, mi) ...mit mozzarella- tomaten- schnitzel + 2,60 € (ei, glw, glh, mi)',
#  'gyrostasche mit hähnchenfleisch, 2 mini- geflügelfrikadellen türkischer dilljoghurt casik djuvec reis',
#  'kartoffelgratin, hähnchenbruststreifen, gouda',
#  'bulgur [bio]-salat (2, glw) ...und hähnchenstreifen',
#  'aktionsgericht von unseren auszubildenden hähnchenbrust chop suey, gemüse, mienudeln (2, 5, en, glw, so, wt)',
#  'röstkartoffeln, mediterranes gemüse, tomaten- zwiebel- marmelade hähnchen vom grill',
#  'hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) champignonsoße (mi) kartoffelspalten',
#  'gemüse- hähnchen- pfanne, aprikosen, cashewkerne, bulgur (glw, nc, se)',
#  'röstkartoffeln, pfannengemüse, kräuterquark (mi) .. und hähnchen vom grill (glw, sf)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) tomatensoße hähnchenstreifen currysoße (so) tortelliniauflauf (1, 2, 3, glw, glg, so)',
#  'hähnchenbockwurst [bio] zum eintopf (2)',
#  'nacho bowl - salatmix, hähnchen, sourcream, guacomole, reis, tortillachips',
#  'bandnudeln in cherry-tomatensoße hähnchen- piccata in parmesanhülle',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi, sl) chili sin carne (glw, glg, so) hähnchenstreifen, gemüse, rahmsoße (glw, mi)',
#  'sesamnudeln, hähnchenstreifen (2, mi) baguettebrot suppe (glw)',
#  'hähnchen-piccata milanese (glw, mi) tomatensoße spaghetti (glw)',
#  'begrenztes angebot: schweine oder hähnchenschnitzel, waldpilzsoße, kartoffelstampf (1, 2, ei, glw, mi)',
#  'begrenztes angebot hähnchenbruststreifen, rucolasoße, nudeln',
#  'hähnchenbrust, thailändisches gemüse, reis (mi)',
#  'tagesgericht: couscous-salat (2, glw) joghurt [bio]- minz- dip (mi) mit falafel (glw, sl) ...und hähnchenstreifen',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) broccolirahmsoße, hähnchenbruststreifen (mi)',
#  'hähnchenschenkel, zitronen-salbeimarinade karotten-mango-konfit polenta',
#  'hähnchenschnitzel paniert (glw) curry- kokos- soße (3) broccoli salzkartoffeln',
#  'wrap mit gebratenen hähnchenbruststreifen, knackigem gemüse-salatmix salat und chili quark-dip',
#  'hähnchenbockwurst',
#  'hähnchenschnitzel (glw, glg) cherry-tomatensoße spaghetti (glw)',
#  'begrenztes angebot hähnchen-piccata milanese (glw, mi) tomatensoße pommes frites',
#  'hähnchen-piccata milanese (glw, mi) champignonsoße (mi) rosmarinkartoffeln',
#  'hähnchenschenkel, zitronen-salbeimarinade karotten- mango- konfit polenta',
#  'hähnchen-piccata milanese (glw, mi) cherry-tomatensoße pasta (glw)',
#  'begrenztes angebot: hähnchenschnitzel (glw, glg) paprika- oliven- soße (6) reis',
#  'hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) lebkuchensoße (2) bayrisch kraut (2, 3, 4) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) makkaroni- tomaten- auflauf, basilikumsoße (glw, mi) hähnchengeschnetzeltes, gemüse (mi, so)',
#  'begrenztes angebot hähnchen-piccata milanese (glw, mi) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'hähnchenbrust, sesamkruste, basilikum- knoblauch- soße, gemüsereis',
#  'couscous-salat (2, glw) ...und falafel (glw, sl) + 1,60€ ...und hähnchenstreifen + 1,70€',
#  'hähnchenbruststreifen, bärlauchsoße, bandnudeln (glw, mi)',
#  'hähnchen-piccata milanese (glw, mi) cherry-tomatensoße stortelli (glw)',
#  'pasta: bandnudeln mit cherry- tomatensoße (glw) ...mit mozzarella- tomaten- schnitzel + 2,60 € (ei, glw, glh, mi) hähnchen-piccata milanese +2,90 € (glw, mi)',
#  'bulgur-salat (2, glw) ...und hähnchenstreifen joghurt [bio]- minz- dip (mi)',
#  'tagesgericht: hähnchenschnitzel, knuspermantel (glw, glg) pommes frites + 1,95€ potatoe wedges + 2,00€',
#  'ingwer curry hähnchen',
#  'tortilla, hähnchen, salat, sojajoghurt-dip (2, glw, so)',
#  'begrenztes angebot pasta bar nudeln hähnchengeschnetzeltes',
#  'hähnchen-piccata milanese (ei, glw, mi) cherry-tomatensoße spaghetti (glw)',
#  'ofenkartoffel, hähnchenstreifen, kräuterdip',
#  'couscous-salat (2, glw) joghurt [bio]- minz- dip (mi) mit falafel (glw, sl) ...und hähnchenstreifen',
#  'hähnchenschenke, zitronen-salbeimarinade karotten- mango- konfit polenta',
#  'hähnchenbruststreifen, rucolasoße, bandnudeln',
#  'begrenztes angebot hähnchengeschnetzeltes "züricher art" (mi) bandnudeln (glw)',
#  'tagesgericht: röstkartoffeln, mediterranes gemüse, kräuterquark (mi) .. und hähnchen vom grill + 1,80 € (glw, sf)',
#  'marinierte hähnchenkeule, kartoffelsalat (3, ei, glw, mi, sf, sl, so)',
#  'hähnchenbockwurst (bio)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) al arrabiata soße (1, 2, 6, glw, sl) curry-soße, hähnchenbruststreifen (3)',
#  'hähnchengyros krautsalat kräuterquark, gurke (mi) pommes frites',
#  '"your favorites" hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) champignonsoße (mi) röstkartoffeln',
#  'geflügelbratwurst, braune schmorkohl- soße, petersilienkartoffeln (giw, gig, so, sl, mi)',
#  'begrenztes angebot pasta bar nudeln geflügeltopf',
#  'hähnchenschnitzel cordon bleu gitterkartoffeln geflügelrahmsoße',
#  'kirschtomaten-konfit, rucola kichererbsen- bulgur 6 mini- geflügelfrikadellen',
#  'kabuli palau afghanischer kabulireis, lamm, geflügel, karotten, rosinen, mandeln',
#  'begrenztes angebot kabuli palau afghanischer kabulireis, lamm, geflügel, karotten, rosinen, mandeln',
#  'stu gkai - thailändischer geflügel-gemüse-topf',
#  'geflügelbratwurst sauerkraut stampfkartoffeln (mi)',
#  'geflügelgeschnetzeltes, karotte, reis (mi)',
#  '2 geflügelbratwurst [bio] (sf) sauerkraut kartoffelgratin (ei, mi)',
#  'frische geflügelbratwurst (sl) sauerkraut, stampfkartoffeln, klecks sauce (mi, giw)',
#  '2 geflügelbratwurst [bio] sauerkraut stampfkartoffeln (1)',
#  '2 geflügelbratwurst [bio] stampfkartoffeln (mi) sauerkraut',
#  'stu gkai, thailändischer geflügel-gemüse-topf',
#  'hähnchenbrust paniert (glw) geflügelsoße erbsen- möhrengemüse (mi) salzkartoffeln',
#  'feuriges gemüse- geflügel- curry (mi, nmn, sf, sl, so) basmatireis',
#  '6 mini- geflügelfrikadellen kräuterquark, gurke kartoffelspalten',
#  'stu gkae - thailändischer geflügel-gemüse-kartoffel-topf',
#  'geflügelgeschnetzeltes, kokos, karotte, basmatireis',
#  'begrenztes angebot 2 geflügelbratwurst [bio] (sf) senfsoße (sf) kaisergemüse kartoffelspalten',
#  'hähnchenschnitzel cordon bleu geflügelsoße broccoli salzkartoffeln',
#  'tagessuppe: geflügelcremsuppe mit planted chicken (sl, mi)',
#  'pasta bar (1, 2, glw, glg, mi, so) geflügel-curry-kokos- soße (mi) arrabiata-soße (1, 2, 6, sl)',
#  'begrenztes angebot: zwei bio- geflügelbratwürste rote bete- schnittlauch- dip bärlauchstampf',
#  'geflügelfrikadellen (glw, mi) tomaten- zwiebel- marmelade (sf, sw) pommes frites',
#  'kichererbsen- bulgur 6 mini- geflügelfrikadellen kirschtomaten-konfit, rucola',
#  '2 geflügelbratwurst (bio) sauerkraut stampfkartoffeln',
#  '2 geflügelbratwurst [bio] (sf) sauerkraut (mi) bratkartoffeln',
#  '2 geflügelbratwurst [bio] (sf) sauerkraut stampfkartoffeln (mi)',
#  'geflügelfrikadellen (bio) geflügelsoße stampfkartoffeln',
#  'pasta bar (1, 2, glw, glg, mi, so) ...kürbissoße und kürbiskernen (glw, mi) ...geflügel-tomatensoße (glw, mi)',
#  '2 geflügelbratwurst [bio] sauerkraut stampfkartoffeln (mi)',
#  'freshbowl mit geflügelbällchen (bio)',
#  '5 mini- geflügelfrikadellen sauerkraut stampfkartoffeln',
#  'grünkohleintopf, geflügelwurst baguettebrot',
#  'freshbowl mit geflügelbällchen, cous cous, tomate, gurke, rotkraut, eisberg, mandeln, joghurtdip',
#  'frühlings- minestrone, geflügelfleischklößchen, nudeln, grana padano baguettebrot',
#  'geflügelsuppe " thai " baguettebrot',
#  '2 geflügelbratwurst [bio] (sf) sauerkraut stampfkartoffeln (1, mi)',
#  'schweineschnitzel, gemüserahmsoße, wedges thailändischer geflügel-gemüse-topf',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tomatensoße, geflügelfleischklöße tomatensoße, fleischklöße (ei)',
#  '2 geflügelbratwurst (bio) sauerkraut meerrettich- stampf- kartoffeln',
#  'begrenztes angebot 2 geflügelbratwurst [bio] (sf) sauerkraut stampfkartoffeln (mi)',
#  'putenbraten geflügelsoße kroketten (glw)',
#  '6 mini- geflügelfrikadellen (bio) barbecuesoße pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tomaten -basilikumsoße geflügelragout, champignon -gemüsesoße (glw, mi, sf)',
#  '6 mini- geflügelfrikadellen geflügelsoße röstkartoffeln',
#  'freshbowl mit geflügelbällchen',
#  'geflügelbratwurst sauerkraut stampfkartoffeln',
#  'hähnchenschnitzel cordon bleu geflügelsoße broccoli basmatireis',
#  'arroz caldo asia geflügel (ei)',
#  '6 mini- geflügelfrikadellen barbecuesoße country steak frites',
#  'geflügelbratwurst (mi, sf, sl) sauerkraut stampfkartoffeln (mi)',
#  '6 mini- geflügelfrikadellen (bio) sauerkraut stampfkartoffeln',
#  '2 geflügelbratwurst [bio] (sf) sauerkraut (1, sf) stampfkartoffeln (mi)',
#  '6 mini- geflügelfrikadellen senfsoße sauerkraut stampfkartoffeln',
#  'kabuli palau - afghanischer reis mit lamm, geflügel, karotten, rosinen, mandeln',
#  'begrenztes angebot 2 geflügelbratwurst [bio] sauerkraut bratkartoffeln',
#  '6 mini- geflügelfrikadellen kichererbsen- bulgur kirschtomaten-konfit, rucola',
#  'curry- geflügelcremesuppe mit baguettebrötchen (mi, so)',
#  'pasta bar, pikante tomatensoße, geflügelwürstchen (1, 2, 6, glw, mi) pasta',
#  'gyrostasche mit hähnchenfleisch, 2 mini- geflügelfrikadellen türkischer dilljoghurt casik djuvec reis',
#  'freshbowl mit geflügelbällchen [bio], geflügelbällchen, rotkohl,kräuter-joghurt, orangen-couscous (glw, mi, nmn)',
#  '2 geflügelbratwurst sauerkraut stampfkartoffeln',
#  'begrenztes angebot: stu gkai - thailändischer geflügel-gemüse-topf',
#  'arroz caldo asia geflügel',
#  'fischnuggets (hefe, fi, glw, sf) cocktailsoße (3, ei, glw, sl) kartoffelspalten',
#  'fischfilet, ei-hülle (ei, fi, glw) kräutersoße (mi, sl) salzkartoffeln',
#  'fisch- nuggets im backteig (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten (glw)',
#  'feuriges gemüse- fisch- curry, ingwerreis',
#  'street style: fischbrötchen, grünkohlchutney, gepickelte zwiebeln, brioche, gurke (1, 3, 5, ei, fi, glw, mi, sf, sw) pommes frites',
#  'fischfrikadelle, remouladensoße (ei, fi, glw, mi, sf, so) kartoffelsalat (ei, sf)',
#  'fischnuggets (ei, fi, glw, mi) cocktailsoße (3, ei, glw, mi, sl) tomaten-gurken- salat kartoffelspalten (glw)',
#  'gebratener fisch (fi) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten (glw)',
#  'gebratenes fischfilet ,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (3, 5, ei, fi, glw, mi, sf, sw)',
#  'hamburger fischpfanne dillsoße',
#  'begrenztes angebot fischnuggets (fi, glw, sf) rote bete -remoulade (2, 3, 8, ei, fi, glw, mi, sf, sl) kartoffelspalten',
#  'unser kombüsen snack - fischbrötchen, grünkohlchutney, gepickelte zwiebeln, brioche, gurke (ei, fi, glw, mi, sf, so, sw) pommes frites',
#  'fischnuggets cocktailsoße pommes frites',
#  'fischwich, rucola, eisbergsalat (glw, gld, mi) tomaten- zwiebel- marmelade (sf, sw) pommes frites',
#  'linsen-fisch curry, salzkatoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'fischfrikadelle (fi, glw, mi, sf) kräuterdip (3, ei, glw, sl) salzkartoffeln',
#  'aktion azubiküche: hausgemachter backfisch seelachs warmer kartoffelsalat',
#  'street style: fischbrötchen, grünkohlchutney, gepickelte zwiebeln, gurke (ei, fi, glw, mi, sf, sw) pommes frites',
#  'fischnuggets cocktailsoße kartoffelspalten',
#  'fischnuggets (ei, fi, glw, mi) cocktailsoße (3, ei, glw, mi, sl) röstkartoffeln',
#  'fischnuggets fried potatoes cocktailsoße',
#  'tagesgericht fischfrikadelle, remouladensoße (ei, fi, glw, mi, sf, so) pommes frites',
#  'begrenztes angebot: pfannfisch remouladensoße bratkartoffeln',
#  'fischnuggets cocktailsoße twisterkartoffeln',
#  'fischnuggets (fi, glw, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten',
#  'fischfrikadelle(fi)',
#  'linsen-fischcurry , salzkartoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'begrenztes angebot : fischfrikadelle (fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) röstkartoffeln',
#  'fischnuggets (fi, glw, sf) cocktailsoße (3, ei, glw, sl) röstkartoffeln',
#  'pfannfisch, senfsoße, bratkartoffeln und sauerkrautchutney (2, 8, fi, glw, mi, sf)',
#  'fischnuggets (ei, fi, glw, mi) cocktailsoße (3, ei, glw, mi, sl) wedges (glw)',
#  'tagesgericht fischstäbchen (fi, glw) blattspinat salzkartoffeln',
#  'fischbrötchen, grünkohlchutney, gepickelte zwiebeln, brioche, gurke (ei, fi, glw, mi) pommes frites',
#  'fischnuggets (ei, fi, glw, mi) cocktailsoße (3, ei, glw, mi, sl) country steak frites (glw)',
#  ...]

# %%
terms_veg = ["mozarella", "egg", "cheese", "milk", "yoghurt", "pana cotta", "schokolade", "rahmsauce", "honig", "hühnerei", "rahmsoße", "gouda", "vegetarisch", "milch", "eier", "käse", "gelatine", "joghurt", "quark", "schalenfrüchte", "zatziki", "zaziki", "butter"]

veg_regexs = generate_regex(terms_veg)
veg = apply_regexs(veg_regexs, nc_names )
veg += regex_filter(r"\bei\b", nc_names)
veg += regex_filter(r"\bml\b", nc_names)
veg += regex_filter(r"\bmi\b", nc_names)


nc_names = set(nc_names)-set(veg)
print(len(veg))
veg
# Out:
# 1488
# ['italian burger - mozarella, eisberg , roten zwiebeln kartoffelspalten',
#  'bio puten- cheeseburger ts - leider schon weggesnackt - war zu lecker.(glw, gld, mi, sf, sw)',
#  'mac `n` cheese 3,10€',
#  'cheese burger pommes frites',
#  'cheese burger (1, glw, mi, se, sf, sl) pommes frites',
#  'begrenztes angebot mac n cheese',
#  'burger im menü mit fritz 0,33l cheese burger (1, glw, mi, se, sl) ... mit pommes frites',
#  'mac n cheese (1, glw, mi, sf)',
#  'mac and cheese',
#  'tagesgericht: mac n cheese - gratin, blumenkohl, gouda, (1, glw, mi)',
#  'cheese burger (1, glw, mi, se, sl)',
#  'cheese burger (1, glw, mi, se, sf, sl)',
#  'cheese burger kartoffelspalten',
#  'tagesgericht cheese burger (1, glw, mi, se, sf, sl)',
#  'tagesgericht: mac n cheese - gratin, blumenkohl, gouda (1, glw, mi)',
#  'cheese burger "wie hausgemacht" (1, glw, mi, se, sl)',
#  '"your favorites" mac n cheese (1, glw, mi, sf)',
#  'mac n cheese',
#  'cheese burger (ei, glw, glr, glg, glh, gld, mi, se, sf) tomaten -paprikasoße kartoffelspalten',
#  'tagesgericht: burger im menü mit fritz 0,33l cheese burger (1, glw, mi, se, sl) ... mit pommes frites',
#  'tagesgericht burger im menü mit fritz 0,33l cheese burger (1, glw, mi, se, sl) ... mit pommes frites',
#  'bio puten- cheeseburger ts - leider schon weggesnackt - war zu lecker.(glw, gld, mi, sf, sw)',
#  'tagesgericht: cheese burger mit pommes und fritz im menü (1, glw, mi, se, sl)',
#  'mac n cheese - gratin, blumenkohl, gouda (1, glw, mi)',
#  'cheese burger',
#  'tagesgericht mac n cheese - gratin, blumenkohl, gouda (1, glw, mi)',
#  'mac n cheese (1, glw, mi, sf, sl)',
#  'falafel rote bete, honig, pinienkerne, koriander curry- dattel- dip joghurt- zitronen- minz- dip',
#  'falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt- zitronen- minz- dip',
#  'falafel curry- dattel- dip rote bete, honig, sesam, koriander joghurt (bio)- zitronen- minz- dip',
#  'pulled turkey burger mit honig- senf dip, rotkohl und röstzwiebeln 3,90€ pommes frites 1,60€',
#  'falafel (glw, sl) rote bete, honig, sesam, koriander (8, se) curry- dattel- dip (mi) joghurt [bio]- zitronen- minz- dip (mi) fladenbrot (glw, glg, se)',
#  'begrenztes angebot falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt(bio)- zitronen- minz- dip',
#  'falafel oder köfte rote bete, honig, sesam, koriander curry- dattel- dip joghurt (bio)- zitronen- minz- dip',
#  'falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt(bio)- zitronen- minz- dip',
#  'falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt (bio)- zitronen- minz- dip',
#  'falafel guacamole rote bete, honig, sesam, koriander curry- dattel- dip',
#  'erbsen- quinoa- frikadelle (sl) pfefferrahmsoße (glw, glg, mi, sl, so) brechbohnen kartoffelgratin (ei, mi)',
#  'frikadelle pfefferrahmsoße rosenkohl kroketten',
#  'gnocchi, blattspinat (ei) tomaten-käse-rahmsoße (mi)',
#  'gnocchi, pilzrahmsoße, käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) broccolirahmsoße (mi) putengeschnetzeltes "züricher art" (mi)',
#  'ravioli mit käsefüllung, broccolirahmsoße',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) sauerkraut kartoffelgratin (ei, mi)',
#  'köfte pfefferrahmsoße rosenkohl kroketten',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) chilli sin carne (2, 6, sl) gemüserahmsoße (mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) spätzleauflauf, bergkäse (ei, glw, mi) wurstgulasch, rahmsoße, champignons (1, 2, 3, 8, mi)',
#  'semmelknödel (ei, glw) pilzrahmsoße (mi, sf)',
#  '" schmaler taler - teller " (glw) pasta, pilzrahmsoße (mi, sf) jeden tag ein preiswertes gericht solange der vorat reicht',
#  'frikadelle (2, 3, 4, sf) pfefferrahmsoße (2, 3, 4, 8, 10, sf, sl) röstkartoffeln',
#  'frikadelle (ei, glw, mi) pfefferrahmsoße (mi) kartoffelgratin (ei, mi)',
#  'frikadelle karottengemüse pfefferrahmsoße kroketten',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) kroketten (glw)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) erbsen kartoffelgratin (ei, mi)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) brechbohnen kartoffelpüree (3, 5, sw, mi)',
#  'pasta bar, täglich wechselndes angebot pasta, champignon - gemüserahmsoße (glw, mi) pasta al arrabiata (1, 2, 6, glw, sl) nudelauflauf, " mexico styl", kidneybohnen, gemüse, käse überbacken (glw, mi)',
#  'frikadelle x pfefferrahmsoße salzkartoffeln',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) sommergemüse pommes frites',
#  'große frikadelle (ei, glw) pfefferrahmsoße (mi) brechbohnen kartoffelgratin (ei, mi)',
#  'frikadelle (ei, glw) pilzrahmsoße (mi, sf) kartoffelgratin (ei, mi)',
#  'frikadelle pfefferrahmsoße kartoffelgratin',
#  'frikadelle pfefferrahmsoße kroketten',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) sesamnudeln, gemüse (en, glw, se) erdnusssauce, gemüse (en, glw, se, so) pfefferrahmsoße (mi)',
#  'ravioli, pfifferlinge -käsefüllung (ei, glw, mi) gemüserahmsoße (1, mi, sl)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) brechbohnen kartoffelgratin (ei, mi)',
#  'kasselernackenbraten (2, 8, 10) rahmsoße (mi) sauerkraut kartoffelpüree (glw, mi, sl)',
#  'tortellini, frischkäsefüllung (ei, glw, mi) gemüserahmsoße (1, mi, sl)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) karotten-erbsen kartoffelgratin (ei, mi)',
#  'welsfilet gebraten (fi, glw) tomaten-gemüserahmsoße (mi, sl) pasta (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tofu -gemüseragout (1, 2, 4, glw, sf, so, sw) gyros, pfefferrahmsoße (mi)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) kartoffelgratin (ei, mi)',
#  'street style: ofenkartoffel "kumpir", oliven, tomaten, gurken, quark-dip, minze, gouda (6, mi, sf)',
#  'salatteller mit gouda und pute 2,95€',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) mangoldpesto (1, 2, sf) gorgonzolasoße (mi) nudelauflauf, paprika- oliven- soße, spinat, gouda (6, glw, mi)',
#  'kartoffelgratin, gemüse, gouda (ei, mi)',
#  'begrenztes angebot nudelgratin, mangold, karotten, gouda (ei, glw, mi) tomatensoße',
#  'salatteller mit gouda und pute',
#  'begrenztes angebot pasta bar nudelauflauf ,pute ,gouda',
#  'tagesgericht: mac n cheese - gratin, blumenkohl, gouda, (1, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (glw) käsespätzleauflauf, tomatensoße, gouda (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot italienischer nudelauflauf, champignons, gouda (ei, glw, mi)',
#  'kartoffelgratin, erbsen, karotten, gouda',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) nudelauflauf, paprika- oliven- soße, gemüse, gouda (1, 3, 5, 6, glw, mi, so, sw) spinat-hummus (se) käsesoße (1, glw, mi, sf)',
#  'tortelliniauflauf, tomaten-gemüseragout, gouda (ei, glw, mi)',
#  'kartoffelgratin, erbsen, karotten, gouda (ei, mi)',
#  'kartoffelgratin, erbsen, karotten, gouda, (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) curry- kokos- gemüsesoße (sl) nudelauflauf, pulled duck, gouda (1, 2, 3, 4, 5, glw, mi, sf, so, sw)',
#  'tagesgericht: mac n cheese - gratin, blumenkohl, gouda (1, glw, mi)',
#  'ofenkartoffel "kumpir style", oliven, tomaten, gurken, quark-dip, minze, gouda (6, mi)',
#  'kartoffelgratin, paprika, zucchini, gouda (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) curry mit kichererbsen (so) nudelauflauf, pulled duck, gouda (1, 2, 3, 4, 5, glw, mi, so, sw) wurstgulasch, champignonsoße (2, 3, 4, 8, 10, mi, sf, sl)',
#  'ofenkartoffel "kumpir style", oliven, tomaten, gurke, joghurt, minze, gouda (6, mi, sf)',
#  'kartoffelgratin, paprika, zucchini, gouda joghurt-kräuter- dip',
#  'kartoffelgratin, brokkoli, gouda (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße pesto (nw) nudelgratin, mangold, karotten, gouda (ei, glw, mi)',
#  'street style: ofenkartoffel "kumpir style", oliven, tomaten, gurken, gouda (6, 8, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl)',
#  'kartoffelgratin, gemüse, gouda',
#  'mac n cheese - gratin, blumenkohl, gouda (1, glw, mi)',
#  'kartoffelgratin, paprika, zucchini, gouda',
#  'ofenkartoffel "kumpir style", oliven, tomaten, gurken, quark-dip, minze, gouda (3, 6, mi)',
#  'nudel- gratin, gouda überbacken cherry-tomatensoße',
#  'kartoffelgratin, paprika, zucchini, gouda als menü mit fritz + 1,00 €',
#  'tagesgericht mac n cheese - gratin, blumenkohl, gouda (1, glw, mi)',
#  'tagesgericht: kartoffelgratin, erbsen, karotten, gouda (ei, mi)',
#  'süßkartoffel- paprika- suppe,kokosmilch mandel- kräuter- mix baguettebrot',
#  'milchreis (mi) heiße kirschen',
#  'milchreis (mi) rhabarber- waldbeer- soße',
#  'bhaingan bharta - indisches auberginen mus mit tomate, kokosmilch, naan brot (glw, sf, so)',
#  'gebratener seehecht (fi, glw) currysoße, paprika, kokosmilch, banane gemüsereis (sl)',
#  'milchreis heiße kirschen',
#  'kokosmilchreis mangofruchtsauce',
#  'karotten- paprika- suppe,kokosmilch mandel- kräuter- mix (nmn, sl) baguettebrot (glw)',
#  'milchreis zimt und zucker (mi)',
#  'milchreis rhabarber- erdbeer- soße',
#  'frikadelle (ei, glw) milchbohnen (glw, mi) pommes',
#  'frikadelle (ei, glw) milchbohnen (glw, mi) salzkartoffeln',
#  'frikadelle (ei, glw) stampfkartoffeln (1, mi) milchbohnen (glw, mi)',
#  'milchreis mit roter grütze groß (mi)',
#  'milchreis mit roter grütze (mi)',
#  'milchreis mit roter grütze, (mi)',
#  'milchreis (mi) apfelmus (3)',
#  'milchreis rhabarber- erdbeer- soße oder heidelbeerfruchtsauce',
#  'kokosmilchreis mango-melone-fruchtsauce',
#  'begrenztes angebot gebratener seehecht (fi, glw) kartoffelcurry, paprika, kokosmilch, banane',
#  'bhaingan bharta - indisches auberginen mus mit tomate, kokosmilch, naan brot',
#  'milchreis (mi) beerenfruchtsoße',
#  'kokosmilchreis mango-erdbeertopping',
#  'hafermilchreis..... apfelkompott',
#  'milchreis (mi) rhabarber- erdbeer- soße',
#  'seehecht (fi, glw) kartoffelcurry, paprika, kokosmilch, banane',
#  'putensteak cherry-tomatensoße basmatireis kleines dessert - milchreis, sauerkirschen (mi)',
#  'milchreis apfelkompott',
#  'kokos- mohn- milchreis, mangokompott',
#  'milchreis (mi) erdbeer- soße',
#  'milchreis (mi) blaubeerenkonfit',
#  'gebratener seehecht (fi, glw) kartoffelcurry, paprika, kokosmilch, banane',
#  'milchreis beerenfruchtsoße',
#  'grünkohleintopf, kokosmilch, curry, koriander (sf) baguettebrot (glw)',
#  'begrenztes angebot milchreis (mi) rhabarber- erdbeer- soße',
#  'gebackener seehecht (fi, glw) kartoffelcurry, paprika, kokosmilch, banane',
#  'milchreis kalt (mi) mit beerenfruchtsoße',
#  'kokosmilchreis mangotopping',
#  'milchreis apfelmus',
#  'hafermilchreis apfelkompott',
#  'süßkartoffel- paprika- suppe,kokosmilch mandel- kräuter- mix (nmn, sl) baguettebrot (glw)',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne basilikum- sahne (bio)- soße',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne pesto',
#  '3 senf-eier mit kartoffelstampf und roter beete mit stampfkartoffeln',
#  '2 senfeier in sauce (ei, mi, sf) mit salzkartoffeln',
#  'eierpfannkuchen, zimtzucker (ei, glw, mi)',
#  'karfreitag feiertag',
#  'dreierlei gnocchi, viererlei pesto, salbei, sonnenblumenkerne (giw, nc, en, 6)',
#  'dreierlei gnocchi, kartoffel, roter beete, spinat, salbei, sonnenblumenkerne (glw) rucola-kürbispesto (nc)',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, sonnenblumenkerne rucolapesto',
#  'dreierlei gnocchi, süßkartoffel, rote bete, spinat, salbei, sonnenblumenkerne (glw) rucolapesto (nc)',
#  'zweierlei gnocchi, salbei, sonnenblumenkerne bärlauchpesto',
#  'begrenztes angebot dreierlei gnocchi, süßkartoffel, roter beete, spinat mangoldpesto',
#  'hausgemachter eierpfannkuchen beerenfruchtsoße',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne feldsalatpesto',
#  'ostermontag feiertag',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, (glw), petersilienpesto',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne rucolapesto (nc)',
#  'dreierlei gnocchi, kräuter, spinat, tomate, sonnenblumenkerne (1, 2, 4, ei, glw, so) rucolapesto (nc)',
#  'feiertag geschlossen',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne (glw) rucolapesto (nc)',
#  'limited edition dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne petersilienpesto',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne petersilienpesto',
#  'zweierlei gnocchi, süßkartoffel, spinat, salbei, sonnenblumenkerne feldsalatpesto',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne (ei) rucolapesto',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, salbei, sonnenblumenkerne rucolapesto',
#  'dreierlei gnocchi, süßkartoffel, roter beete, kartoffel, basilikum-pesto kirschtomaten-konfit, rucola',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat, sonnenblumenkerne feldsalatpesto',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat mit gemüse',
#  'dreierlei gnocchi, süßkartoffel, roter beete, spinat mit schmorgemüse sojasoße',
#  '3 senf-eier mit kartoffelstampf und roter beete (ei, mi, sf) mit stampfkartoffeln (8, mi)',
#  '" schmaler taler - teller " (glw) gnocchiauflauf mit käse überbacken (mi) jeden tag ein preiswertes gericht solange der vorat reicht',
#  'gnocchi, blattspinat, käsesoße (1, ei, glw, mi, sf)',
#  'pasta bar... tortellini mit kichererbsen und spitzkohl, auf wunsch mit käse (1, 2, glw, mi, nc)',
#  'tagliatelle, kürbis- käse- soße, walnüsse (ei, glw, mi, nw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) rucolapesto (nc) käsesoße (1, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) blattspinat- tomaten- frischkäsesoße (glw, mi) putengeschnetzeltes "züricher art" (mi)',
#  'tortellini, käsefüllung (ei, glw, mi) tomatensoße',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) käsesoße (1, glw, mi, sf)',
#  'gnocchi, blattspinat (ei) tomaten-käse-rahmsoße (mi)',
#  'pasta bar, täglich wechselndes angebot (glw) tortellini-auflauf, gemüse, käsekruste (glw, mi, nc) pasta, rucolapesto, marinierte kirschtomaten',
#  'begrenztes angebot pasta bar nudelauflauf,käse-spinat-jackfruit',
#  'pasta (glw) käsesoße (1, mi)',
#  'nudelkäseauflauf (1, glw, mi, sf) tomatensoße',
#  'pasta bar, täglich wechselndes angebot patsa, ratatouille (glw) pasta, erbsenpesto, tomatenwürfel (glw) spätzle-brokkoliauflauf, käsekruste (ei, glw, mi)',
#  'gnocchi, pilzrahmsoße, käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi) grüner salat',
#  'grüne tortellini, ricotta- käse- spinatfüllung (ei, glw, mi)',
#  'nudelauflauf, käsekruste',
#  'nudel-kürbisauflauf mit käsekruste',
#  'pasta bar, täglich wechselndes angebot nudelauflauf, gemüse, käsekruste (ei, glw, mi, sl)',
#  'ravioli mit käsefüllung, broccolirahmsoße',
#  'pasta (glw) käsesoße (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) sauer-scharfe-soße, mu err pilze, jackfruit [bio], tofu (1, 2, 3, 4, en, glw, se, so) nudelauflauf, planted.pulled bbq, käsekruste (1, 2, glw, glh, sf, so)',
#  'pasta, bio bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'pasta bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'kartoffel-spinat-curry mit schafskäse',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, so) kürbis -frischkäsesoße (mi)',
#  'weizenteigfladen, scharfes kichererbsenmus, hirten-käse, salat (2, glw, mi, se, sf)',
#  'oriental bowl - feigen, datteln, aprikosen, cous cous, schafskäse, granatapfel (2, 5, glw, mi, sw)',
#  'bunte pasta (glw) käsesoße (1, mi)',
#  'kartoffel- kürbisauflauf, käsekruste (ei, glw, mi)',
#  'tagliatelle, kürbis- käse - soße, walnüsse',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, blumenkohl- kartoffel- curry, käse (mi)',
#  'salatteller mit hirtenkäse',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) ratatouille käsesoße (1, glw, mi, sf)',
#  'laugen leberkäse burger pommes frites',
#  'bayern-burger, leberkäse, sauerkraut, schmand, senf gitterkartoffeln',
#  'allgäuer käsespätzle, käse, geschmelzte zwiebeln',
#  'pasta bar, täglich wechselndes angebot tortellini-auflauf, käse überbacken, sourcreme (glw, mi, nc)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) gemüse-tomatensoße nudelauflauf, käsekruste (1, glw, mi, sf, sl)',
#  'pasta, blattspinat- tomaten- frischkäsesoße (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja-bolognese (glg, sl, so) pesto allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'pastabar bolognese soße (1, 2, mi, sl) käsesoße (mi)',
#  'tagesgericht: pasta mit (glw, mi) käsesoße (1, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) spätzleauflauf, bergkäse (ei, glw, mi) wurstgulasch, rahmsoße, champignons (1, 2, 3, 8, mi)',
#  'leberkäse (2, 3, 4, 8, 10, sf, sl) dunkle dijon-senf- soße (8, glw, glg, sf, sl, so) sauerkraut (sf) laugen-semmelknödel (ei, glw)',
#  'pasta bar, täglich wechselndes angebot (glw) penne, grünkohlpesto (glw, nmn, nc) nudelauflauf, kürbis, käsekruste (ei, glw, mi, sl)',
#  'kartoffel- kürbisauflauf, käsekruste kräutersoße',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (1, ei, glw, mi)',
#  'tagliatelle, blattspinat- tomaten- frischkäsesoße',
#  'börek, fetakäse (ei, glw, mi) tomaten- minzsugo couscous (glw)',
#  'shakshuka - tomate, paprika, ei, hirtenkäse',
#  'pasta bar, täglich wechselndes angebot (glw) gnocchigratain , hokkaido, käse (ei, glw, mi)',
#  'kartoffel-kürbisauflauf mit käsekruste',
#  'begrenztes angebot pasta bar chili sin carne nudelauflauf, käsekruste',
#  'pasta bar: pasta, würstchen, käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten curry soße (sf, sw) käsesoße, kichererbsen (1, 2, mi, se)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, putengeschnetzeltes, käse (glw, mi)',
#  'mughlai-sahnesoße, indische frischkäsebällchen basmatireis',
#  'pasta bar, in selbstbedienung (glw, glg, mi, so) soja-bolognese (glw, so) tomaten- frischkäse- soße (mi)',
#  'letzter tag - heute nur bis 13:30 geöffnet pasta bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'tagliatelle, blattspinat- tomaten- käsesoße',
#  'leberkäse (2, 3, 10) dunkle dijon-senf- soße (8, glw, glg, sf, sl, so) sauerkraut salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) rucolapesto (nc) bohnen- tomaten- soße nudelauflauf,rosenkohl,kichererbsen, käsekruste (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) paprika- oliven- soße (6, glw) käsesoße (1, 3, 5, glw, mi, nw, sw)',
#  'nudelauflauf, brokkoli, champignons, käse (1, 2, glw, glh, mi)',
#  'pasta bar, täglich wechselndes angebot (glw) käsespätzleauflauf, tomatensoße, gouda (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) arrabiata-soße, planted pulled (1, 2, 6, glh, sf, sl) nudelauflauf - linsen- bolognese,käse (glw, mi, sl)',
#  'pasta käse-spinatsoße',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) nudelauflauf, paprika- oliven- soße, gemüse, gouda (1, 3, 5, 6, glw, mi, so, sw) spinat-hummus (se) käsesoße (1, glw, mi, sf)',
#  'pasta (glw) käsesoße (1, mi) gebackene tomaten',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tomaten-käsesoße (1, mi)',
#  'oriental bowl - feigen, datteln, aprikosen, cous cous, schafskäse, granatapfel',
#  'kartoffel-spinat-curry mit schafskäse (5, mi)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße nudelauflauf, gemüse, käsesoße (ei, glw, mi)',
#  'shakshuka - tomate, paprika, ei, hirtenkäse naan brot',
#  'kürbis-pastinaken-suppe, hirtenkäse baguettebrot',
#  'kartoffel- kürbisauflauf, käsekruste',
#  'pasta käsesauce (giw, mi, 1)',
#  'pasta bar, täglich wechselndes angebot (glw, mi) nudelauflauf, bolognese soße, käse (mi, sl)',
#  'pasta bar, täglich wechselndes angebot (glw) tortelliniauflauf, käse (1, 3, 5, glw, mi, nw, nc, sw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto käsesoße (1, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto soja-bolognese (glg, so) kürbis -frischkäsesoße (mi)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, champignons, brokkoli, käsekruste (ei, glw, mi, sl) pasta, pesto, marinierte tomaten (1, 3, 5, glw, nw, sw)',
#  '1/2 pizza hirtenkäse paprika (giw, gig, mi)',
#  'kartoffel- kürbisauflauf, käsekruste (ei, mi)',
#  'pasta bar, täglich wechselndes angebot tortellini, kichererbsen, spitzkohl, (glw, nc) nudelauflauf, gemüse, käsekruste (ei, glw, mi, sl) pasta,tomatensoße (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rucolapesto chili sin carne (3) spätzleauflauf, pulled turkey, tomaten, käse (ei, glw, mi)',
#  'pasta (glw) käsesoße (1, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, spinat, hirtenkäse (ei, glw, mi, sl) pasta, ratatouille (glw)',
#  'pasta, blattspinat- tomaten- frischkäsesoße (1, glw, mi)',
#  'pasta gratin mit spinat in ziegenkäse-bechamel, dazu fruchtige tomaten- basilikumsoße',
#  'kartoffel- broccoli- gratin frischkäsesoße',
#  'pasta bar, täglich wechselndes angebot pasta, champignon - gemüserahmsoße (glw, mi) pasta al arrabiata (1, 2, 6, glw, sl) nudelauflauf, " mexico styl", kidneybohnen, gemüse, käse überbacken (glw, mi)',
#  'pasta, blattspinat- tomaten- frischkäsesoße',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi) cherry-tomatensoße',
#  'begrenztes angebot allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tortelliniauflauf, kichererbsen, spitzkohl, tomatensoße, käse (2, 6, glw, mi, nc, sl, sw) wurstragout, gemüse (2, 8, 10, sw) chili con carne (2, glw)',
#  'pasta käsesoße',
#  'ravioli, pfifferlinge -käsefüllung (ei, glw, mi) kräutersoße (mi)',
#  'börek, spinatfüllung (glw) tomaten- frischkäsesoße (mi) couscous (glw)',
#  'nudelauflauf, käsekruste (ei, glw, mi, sl) kräutersoße (mi)',
#  'pasta bar, täglich wechselndes angebot kartoffel - gemüsecurryauflauf, käse überbacken (ei, mi) pasta, erbsen- cashewkern- pesto, tomatenwürfel (glw, nw, nc) pasta, kräutersoße (glw, mi)',
#  'gnocchi, blattspinat, hirtenkäse käsesoße (mi)',
#  'begrenztes angebot pasta bar nudeln blattspinat- tomaten- frischkäsesoße-hühnchen',
#  'laugen leberkäse burger (2, 3, 8, 10, glw, sf) pommes frites',
#  'pasta bar, täglich wechselndes angebot gnocchiauflauf, gemüse, käse überbacken (ei, mi) tomatensoße',
#  'spagetti, blattspinat- tomaten- frischkäsesoße',
#  'pasta bar, täglich wechselndes angebot pasta, jackfruit ragout (3, glw, sw) gnocciauflauf, käse überbacken (mi) pasta, rotes pesto, (1, 3, 5, glw, mi, nw, nc, sw)',
#  'pasta bar, täglich wechselndes angebot pasta, kürbispesto (1, 2, glw, mi, nmn, nc) pasta, bolognese soße (1, 2, glw, mi, sl) nudelauflauf, ratatouillegemüse, käsekruste (glw, mi, sl)',
#  'ravioli, pfifferlinge -käsefüllung (ei, glw, mi) gemüserahmsoße (1, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja bolognese (1, 3, 5, glg, sl, so, sw) pesto (nw) nudelauflauf, tomaten joghurtsoße, gemüse, käse (glw, mi, nmn, sf)',
#  'laugen leberkäse burger (2, 3, 8, 10, glw, sf)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) chili sin carne allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'shakshuka - tomate, paprika, ei, hirtenkäse fladenbrot',
#  'gnocchi, blattspinat, kirschtomaten (ei) käsesoße (1, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kartoffel-weiße bohnen ragout (sl) käse - gemüsesoße (1, mi)',
#  'käse- lauch- suppe (1, mi) baguettebrot (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) paprika- oliven- soße (6) käsesoße (1, glw, mi, sf)',
#  'begrenztes angebot: asiatischer mie-nudeln-auflauf, gemüse, käse',
#  'laugen leberkäse burger, sauerkraut-chutney, kartoffel-aioli (2, 3, 10, ei, glw, sf, sl) pommes frites',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi) eisbergsalat, italiendressing',
#  'tagliatelle, blattspinat- tomaten- frischkäsesoße (glw, mi)',
#  'allgäuer käsespätzle mit bergkäse und geschmolzenen zwiebeln',
#  'pasta bar (1, 2, glw, glg, mi, so) würzige thai soja bolognese (1, 2, 4, glw, glg, so) käsesoße (mi)',
#  'tortellini, frischkäsefüllung (ei, glw, mi) gemüserahmsoße (1, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (2, 3, 4, glw, glg, mi, so) nudelauflauf, asiagemüse, käse (2, en, glw, mi, so)',
#  'cous cous gemüse pfanne mit feigen, datteln, aprikosen, schafskäse-dip',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, 4, glw, mi, sl) ratatouille käsesoße (1, glw, mi, sf)',
#  'pasta alfredo (1, 2, 4, glw, glg, so, sf, sl) nudeln in würziger käsesauce, kräuter, geriebener hartkäse',
#  'weizenteigfladen mit scharfem kichererbsenmus, schafskäse und salat (2, 3, glw, mi, sf, se)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) würzige soja bolognese, ingwer, erdnuss, gemüse (1, 2, 4, en, glw, glg, sf, sl, so) käse -gemüse -soße (1, mi)',
#  'begrenztes angebot kartoffel- kürbisauflauf, käsekruste (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf,ratatouille, käsekruste (glw, mi) pasta , tomaten- mango- linsenragout (glw)',
#  'lahmacun, türkische "pizza", hirtenkäse, rotkraut, weißkraut, kräuter',
#  'kartoffel- broccoli- gratin (ei, mi) frischkäsesoße (mi)',
#  'tortellini, käsefüllung gremolata',
#  'pasta bar, täglich wechselndes angebot (glw) makkaroni- tomaten- auflauf, basilikumsoße, käse (glw, mi)',
#  'schupfnudeln, kürbis, champignon, hirtenkäse-quark [bio]-dip (glw, mi)',
#  'pasta gratin mit spinat in ziegenkäse-bechamel, (2, glw, mi) dazu fruchtige tomaten- basilikumsoße',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto soja-bolognese (glg, sl, so) frischkäsesoße (mi)',
#  'pasta bar: nudel-käseauflauf (1, 2, 3, 4, glw, glg, mi, so)',
#  'pasta bar, täglich wechselndes angebot nudelauflauf, gemüse, käsekruste (1, 2, glw, glh) paprika- oliven- soße (6)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, kürbis- ricotta- soße, walnüsse, käse (glw, mi, nw)',
#  'pasta mit käsesoße (glw) käsesoße (1, mi)',
#  'allgäuer-käse-spätzle, bergkäse, geschmelzte zwiebeln',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, spinat, käsekruste (ei, glw, mi, sl) pasta, rucolapesto, tomatenwürfel (glw)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln',
#  'begrenztes angebot: leberkäse oder frikadelle (2, 3, 10, ei, glw) bratensoße (mi) sauerkraut (mi) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot pasta, spinat-frischkäsesoßesoße (1, glw, mi) pasta, paprika-olivenpesto (1, 3, 5, 6, glw, nw, sw)',
#  'pasta (glw) käsesoße (1, ei, mi, sl)',
#  'laugen leberkäse burger pommes frites 1,60 €',
#  'nudelauflauf, brokkoli, champignons, käsekruste (glw, mi)',
#  'weizenteigfladen mit scharfem kichererbsenmus, schafskäse und salat',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) käsesoße (1, mi) pulled turkey nudelauflauf (glw, mi, sl)',
#  'kartoffel-kürbisauflauf mit käsekruste (ei, mi)',
#  'grüne tortellini, ricotta- käse- spinatfüllung, rucculapesto (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, ratatouille, käsekruste (ei, glw, mi, sl) pasta, rucolapesto, marinierte kirschtomaten (glw)',
#  'ravioli pfifferlinge, gemüse, olivenöl, hartkäse (1, 2, ei, mi, so) käsesoße (1, mi)',
#  'begrenztes angebot gnocchi (ei) blattspinat- tomaten- frischkäsesoße (mi)',
#  'kürbis- pastinaken- suppe, hirtenkäse baguettebrot',
#  'nudel-kürbisauflauf mit käsekruste (2, ei, glw, mi)',
#  'shakshuka - tomate, paprika, ei, hirtenkäse (ei, mi) fladenbrot (glw, glg, se)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi, sl) käsesoße (1, glw, mi, sf) gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf)',
#  'tortellini käsesoße',
#  'pasta bar, täglich wechselndes angebot (glw) pasta , rote- linsen- bolognese (glw, sl) kürbis -gnocchi -auflauf, käsekruste (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) ratatouille pesto nudelauflauf, barbecue soße, spare ribs, pulled turkey, gemüse, käse (1, 3, 5, glw, mi, sl, sw)',
#  'blumenkohl käse medaillon (ei, glw, mi, sl) champignonsoße (mi) stampfkartoffeln (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten- frischkäsesoße (glw, mi) currywurst hot pot(t) (3, 10, sf, sl)',
#  'pasta bar (1, 2, glw, glg, mi, so) käsesoße (mi) bolognese soße (1, 2, mi, sl)',
#  'allgäuer käsespätzle, geschmelzte zwiebeln (ei, glw, mi)',
#  'nudelauflauf mit käsekruste 3,10€',
#  'linsenbratling mit joghurtdip, chilikartoffeln und gurken-radieschen-salat',
#  'weizenteigfladen, avocado, weißen bohnen, kürbis, mais, joghurt (2, 3, glw, mi)',
#  'lahmacun mit rotkraut, weißkraut, kräuter (glw, so) curry- joghurt [bio]- dip (mi, sf)',
#  'paprika-champignonpfanne quark-joghurtdip reis',
#  'falafel (glw, sl) linsensalat (sl, sw) joghurt [bio]- zitronen- minz- dip (mi)',
#  'linsenbratling, joghurtdip, chilikartoffeln, gurken- radieschen- salat',
#  'falafel bowl, falafelbällchen, rotkohl, kräuter-joghurt, orangen-couscous (glw, mi, nmn, sl)',
#  'falafel rote bete, honig, pinienkerne, koriander curry- dattel- dip joghurt- zitronen- minz- dip',
#  'falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt- zitronen- minz- dip',
#  'ofengemüse, basilikum- joghurt- dip, rosmarinkartoffeln',
#  'linsenbratling, joghurtdip, chilikartoffeln, gurken- radieschen- salat (ei, glw, mi)',
#  'ofengemüse, basilikum- joghurt (bio)- dip, rosmarinkartoffeln',
#  'lahmacun mit rotkraut, weißkraut, feta, kräuter (glw, mi, so) curry- joghurt [bio]- dip (mi, sf)',
#  'börekstange spinat gurkensalat (mi) bulgur [bio] (glw) joghurt [bio]- zitronen- minz- dip (mi)',
#  'falafel bowl, cous cous, tomate, gurke, rotkraut, eisberg, mandeln, joghurtdip',
#  'dürüm türkischer dilljoghurt cacik (2, glw, mi)',
#  'seehechtfilet gebraten, tomate, zucchini, kräuterkartoffeln, heidelbeerjoghurt',
#  'falafel joghurt (bio)- zitronen- minz- dip bratreis, zucchini, paprika, kreuzkümmel, mandeln',
#  'falafel curry- dattel- dip rote bete, honig, sesam, koriander joghurt (bio)- zitronen- minz- dip',
#  'planted kebab tortilla, salat, sojajoghurt-möhren-dip (2, 3, glw, so)',
#  'ofengemüse, basilikum- joghurt(bio)- dip, rosmarinkartoffeln',
#  'begrenztes angebot bulgur- salat joghurt- minz- dip mit falafel',
#  'gemüseschnitzel vn joghurt (bio)- zitronen- minz- dip linsensalat',
#  'börekstange spinat kichererbsen- bulgur (bio) joghurt (bio)- zitronen- minz- dip',
#  'seehechtfilet gebraten, tomate, zucchini, kräuterkartoffeln, erdbeerjoghurt',
#  'planted kebab tortilla, salat, sojajoghurt-dip (2, glw, so)',
#  'couscous-salat (2, glw) joghurt [bio]- minz- dip (mi)',
#  'planted kebab tortilla, salat, sojajoghurt-dip (2, glw, sf, so)',
#  'lahmacun, türkische "pizza", rotkraut, weißkraut, kräuter türkischer dilljoghurt',
#  'falafel (glw, sl) rote bete, honig, sesam, koriander (8, se) curry- dattel- dip (mi) joghurt [bio]- zitronen- minz- dip (mi) fladenbrot (glw, glg, se)',
#  'ofenkartoffel "kumpir style", oliven, tomaten, gurke, joghurt, minze, gouda (6, mi, sf)',
#  'bulgur- salat joghurt- minz- dip mit falafel',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja bolognese (1, 3, 5, glg, sl, so, sw) pesto (nw) nudelauflauf, tomaten joghurtsoße, gemüse, käse (glw, mi, nmn, sf)',
#  'kartoffelgratin, paprika, zucchini, gouda joghurt-kräuter- dip',
#  'falafel joghurt (bio)- zitronen- minz- dip linsensalat',
#  'couscous- broccoli- karottenpfanne (glw) rucola-joghurt-quark-dip (mi) paprikasoße (1, 2, 4, glw, so)',
#  'bulgur-salat (2, glw) mit falafel (glw, sl) joghurt [bio]- minz- dip (mi)',
#  'begrenztes angebot falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt(bio)- zitronen- minz- dip',
#  'lahmacun, türkische "pizza", rotkraut, weißkraut, kräuter türkischer dilljoghurt casik',
#  'gemüsepfanne mit couscous und zitronen- joghurt- minz -dip',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) indisches butterhuhn, joghurt[bio], tomate, mandeln (mi, nmn, sf) erdnusssauce (en, glw, se, so) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'pasta bar, täglich wechselndes angebot soja-gemüse kokos- curry, langkornreis (sf, sl, so) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'bulgur salat joghurt- minz- dip 2,20€',
#  'seehechtfilet gebraten, tomate, zucchini, kräuterkartoffeln, himbeerjoghurt',
#  'bulgur (bio)-salat joghurt (bio)- minz- dip',
#  'seehechtfilet gebraten, buntes gemüseallerlei, kräuterkartoffeln, himbeerjoghurt(bio)',
#  'ofengemüse, basilikum- joghurt [bio]- dip, rosmarinkartoffeln (mi)',
#  'falafel oder köfte rote bete, honig, sesam, koriander curry- dattel- dip joghurt (bio)- zitronen- minz- dip',
#  'linsenbratling, joghurtdip, chilikartoffeln, gurken- radieschen- salat (ei, glw, mi, se)',
#  'falaffelbällchen mit joghurt-zitronenminz-dip auf linsensalat',
#  'soja gyros couscous joghurt- zitronen- minz- dip',
#  'falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt(bio)- zitronen- minz- dip',
#  'falafel rote bete, honig, sesam, koriander curry- dattel- dip joghurt (bio)- zitronen- minz- dip',
#  'seehechtfilet gebraten, tomate, zucchini, kräuterkartoffeln, himbeerjoghurt(bio)',
#  'begrenztes angebot broccoli-nuss-ecke reis paprika- oliven- soße kräuterquark',
#  'kartoffel- karotten- gratin, rucolaquark(bio)',
#  'paprika-champignonpfanne quark-joghurtdip reis',
#  'street style: ofenkartoffel "kumpir", oliven, tomaten, gurken, quark-dip, minze, gouda (6, mi, sf)',
#  'kürbis- kartoffel- karotten- gratin, rucolaquark(bio)',
#  'steckrüben- kartoffel- karotten- gratin, rucolaquark',
#  'schupfnudeln, gemüse , quarkdip mit frühlingszwiebel',
#  'begrenztes angebot steckrüben- kartoffel- karotten- gratin, kräuterquark (ei, glw, mi)',
#  'röstkartoffeln, mediterranes gemüse, kräuterquark',
#  'steckrüben- kartoffel- karotten- gratin, rucolaquark (ei, mi)',
#  'röstkartoffeln, mediterranes gemüse, kräuterquark (mi)',
#  'röstkartoffeln, pfannengemüse, kräuterquark (mi)',
#  'ofenkartoffel "kumpir style", oliven, tomaten, gurken, quark-dip, minze, gouda (6, mi)',
#  'steckrüben- kartoffel- karotten- gratin, rucolaquark (ei, glw, mi)',
#  'röstkartoffeln, mediterranes gemüse, kräuterquark, (mi)',
#  'broccoli-möhrenpfanne mit bulgur und krautsalat mit kräuterquark',
#  'begrenztes angebot wurst-gemüse-pfanne, reis, quark - dip',
#  'couscous- broccoli- karottenpfanne (glw) rucola-joghurt-quark-dip (mi) paprikasoße (1, 2, 4, glw, so)',
#  'schupfnudeln, kürbis, champignon, hirtenkäse-quark [bio]-dip (glw, mi)',
#  'ofenkartoffel "kumpir style", oliven, tomaten, gurken, quark-dip, minze, gouda (3, 6, mi)',
#  'broccoli- blumenkohl- gratin, gorgonzolasoße, heidelbeerquark',
#  'steckrüben- kartoffel- karotten- gratin, rucolaquark(bio)',
#  'tagesgericht röstkartoffeln, mediterranes gemüse, kräuterquark (mi)',
#  "butter chick'n peas - indisches kichererbsen curry mit kürbis und blumenkohl (sf) basmatireis",
#  "butter chick'n peas - indisches kichererbsen curry mit kürbis und blumenkohl (sf) vollkornreis",
#  "butter chick'n peas - indisches kichererbsen curry mit kürbis und blumenkohl (sf) reis",
#  "butter chick'n peas - indisches kichererbsen curry mit kürbis und blumenkohl (nc, sf) basmatireis",
#  "butter chick'n peas; indisches kichererbsen curry (sf) basmatireis",
#  "butter chick'n peas - indisches kichererbsen curry mit kürbis und blumenkohl (se, sf) basmatireis",
#  'begrenztes angebot: wechselnde auswahl königsberger klopse mit kapernsoße und butterkartoffeln, rote bete (2, 8, mi, glw, sf)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) indisches butterhuhn, joghurt[bio], tomate, mandeln (mi, nmn, sf) erdnusssauce (en, glw, se, so) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'pasta bar, täglich wechselndes angebot soja-gemüse kokos- curry, langkornreis (sf, sl, so) indisches butterhuhn, joghurt[bio], tomate, mandeln',
#  'maultaschen, gemüsefüllung, salbeibutter (ei, glw, mi)',
#  'gnocchi, blattspinat, käsesoße (1, ei, glw, mi, sf)',
#  'begrenztes angebot gebratener seehecht,eihülle, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf) paprika- oliven- soße (6)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pikante sesamnudeln, asiatisches pfannengemüse (en, glw, se, so) gnocchi-blattspinat-auflauf (1, ei, glw, mi, sf) wurstgulasch (2, 3, 4, 8, 10, mi, sf, sl)',
#  'putenschnitzel paniert (ei, glw) curry- kokos- soße (3) broccoli reis',
#  'tagliatelle, kürbis- käse- soße, walnüsse (ei, glw, mi, nw)',
#  'begrenztes angebot kartoffelpuffer (ei, glw) apfelkompott (3)',
#  'gebratener seehecht,eihülle, balsamicolinsen mit kürbis, meerrettich-stampf-kartoffeln (1, 3, 5, ei, glw, mi, sf, sw)',
#  'gebratener seehecht, (3, ei, fi, glw, mi, sf, sw) remouladensoße (3, 8, ei, glw, mi, sf, sl) dillkartoffeln',
#  'tortellini, käsefüllung (ei, glw, mi) tomatensoße',
#  'spargelrisotto, walnüsse (2, ei, mi) spargelfond für spargelsuppe',
#  'erbsen- quinoa- frikadelle (sl) pfefferrahmsoße (glw, glg, mi, sl, so) brechbohnen kartoffelgratin (ei, mi)',
#  'gnocchi, blattspinat (ei) tomaten-käse-rahmsoße (mi)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sw) zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'frikadelle (ei, glw) sauerkraut stampfkartoffeln (mi)',
#  'hokkaido gebraten, gnocchi, kürbiskernöl (ei)',
#  'überbackene pasta mit mediterranem gemüse (ei, glw, mi, sl)',
#  'pasta bar, täglich wechselndes angebot patsa, ratatouille (glw) pasta, erbsenpesto, tomatenwürfel (glw) spätzle-brokkoliauflauf, käsekruste (ei, glw, mi)',
#  'maultaschen-bowl, maultaschen, zuckerschoten, kichererbsen-dip (2, 8, ei, glw, mi)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi) grüner salat',
#  'grüne tortellini, ricotta- käse- spinatfüllung (ei, glw, mi)',
#  'putengeschnetzeltes "züricher art" (mi) spätzle (ei, glw)',
#  'gnocchiauflauf (ei) gorgonzolasoße (mi)',
#  'begrenztes angebot kaiserschmarrn (ei, glw, mi, nmn) rhabarber- erdbeer- soße',
#  'pasta bar, täglich wechselndes angebot pasta,orientalische linsen- bolognese, datteln, rosinen (glw, sl) haferflockenbratling, (ei, glw, glh, mi, se)',
#  'kibbelinge, dijon- senf- soße, karotten, kräuterkartoffeln (1, ei, fi, glw, mi, sf)',
#  'gnocchi, (ei, sl) tomaten- gemüse- soße (sw) rucolapesto',
#  'spaghetti carbonara (2, 3, 4, ei, glw, mi, sl)',
#  'frikadelle (ei, glw) rotweinsoße (sw) kroketten (glw)',
#  'strammer burger, pommes (2, 3, ei, glw, mi, se)',
#  'kartoffel-reibekuchen (ei, glw)',
#  'apfelpfannkuchen, zimtzucker (ei, glw, mi)',
#  'street style: miso ramen, champignons, erdnüsse, pak choi, koriander (1, 2, 4, ei, en, glw, sl, so)',
#  'begrenztes angebot kartoffelpuffer (ei, glw) apfelmus (3)',
#  'pasta aktion: strotelli- auflauf mit mangold (glw, ei, mi) babymöhren bärlauchcreme (mi)',
#  'frikadelle (ei, glw) helle dijon- senf- soße (glw, mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'welsfilet gebraten (fi, glw) kohlrabi in rahm (ei, mi, sl) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot nudelauflauf, gemüse, käsekruste (ei, glw, mi, sl)',
#  'gnocchi, brokkoli (ei) gorgonzolasoße (mi)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) sauerkraut kartoffelgratin (ei, mi)',
#  'frikadelle (ei, glw) petersiliensoße (mi) wurzel- kartoffelstampf (mi, sl)',
#  'bratklops- stulle, süßer senf, süßkartoffelpommes (giw, sf, ei, se)',
#  'putenschnitzel paniert (2, ei, glw, mi) curry- kokos- soße (3) broccoli und süßkartoffel-mais-pürre',
#  'pasta, bio bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'sloppy gnocchi (ei, mi)',
#  'frikadelle (ei, glw) rotweinsoße (sw) rotkohl (1, 3, 5, 8, sw) kartoffelgratin (ei, mi)',
#  'pasta bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'frikadelle (ei, glw) paprika- maissoße (sl) pommes frites',
#  'paniertes welsfilet (ei, fi, glw) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'steckrüben- kartoffel- karotten- gratin, grünkohlpesto (ei, mi, nmn, nc)',
#  'kartoffelpuffer (ei) apfelmus (3)',
#  'welsfilet im backteig (fi, glw) erbsen-gurken-dip (3, ei, glw, sl) gitterkartoffeln (glw)',
#  'welsfilet im backteig (fi, glw) erbsen-gurken-dip (3, ei, glw, sl) röstkartoffeln',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (1, 3, ei, fi, glw, mi, sf, sw)',
#  '2 senfeier in sauce (ei, mi, sf) mit salzkartoffeln',
#  'eierpfannkuchen, zimtzucker (ei, glw, mi)',
#  'kartoffel- kürbisauflauf, käsekruste (ei, glw, mi)',
#  'kasselernackenbraten (2, 8, 10) rotweinsoße (sw) rosenkohl kartoffelgratin (ei, mi)',
#  'gefüllte pasta (ei, glw, mi) currysoße (mi)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (2, en, glw, ei, sl, so)',
#  'frikadelle (ei, glw) milchbohnen (glw, mi) pommes',
#  'putengeschnetzeltes "züricher art" (mi, so) spätzle (ei, glw)',
#  'hühnerfrikassee (1, 3, ei, mi, sf, sl) reis',
#  'kartoffel-reibekuchen (ei) apfelkompott (3)',
#  'gnocchi, blattspinat (ei) gorgonzolasoße (mi)',
#  'frikadelle (ei, glw) milchbohnen (glw, mi) salzkartoffeln',
#  'frikadelle (ei, glw) stampfkartoffeln (1, mi) milchbohnen (glw, mi)',
#  'nudel- blumenkohl- karotten- gratin, bärlauchdip (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot gnocchi-gemüsepfanne (ei)',
#  'königsbergerklopse (ei) kapernsoße (mi) salzkartoffeln',
#  'nudel- mangold- karotten- gratin, bärlauchdip (ei, glw, mi)',
#  'heringssalat, salzkartoffeln (2, 8, ei, fi, mi, sf)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja-bolognese (glg, sl, so) pesto allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'brezelauflauf (ei, glw, glg, mi) rahmspinat (1, mi)',
#  'linsenbratling, joghurtdip, chilikartoffeln, gurken- radieschen- salat (ei, glw, mi)',
#  'kartoffelgratin, gemüse, gouda (ei, mi)',
#  'hokaido gebraten, gnocchi, kürbiskerne (ei)',
#  'kartoffelgratin, tomate, mozzarella (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) spätzleauflauf, bergkäse (ei, glw, mi) wurstgulasch, rahmsoße, champignons (1, 2, 3, 8, mi)',
#  'kabeljau im backteig (ei, fi, glw) erbsen-gurken-dip (3, ei, glw, sl) kartoffelspalten',
#  'pasta mit grünem spargel, kirschtomaten (glw) und rucolapesto (2, ei, mi)',
#  'dinkel-mediterran-burger, soja- chili- dip, tomate, gurke, rucola (ei, glw, gld, mi, sf, so) gitterkartoffeln (glw)',
#  'leberkäse (2, 3, 4, 8, 10, sf, sl) dunkle dijon-senf- soße (8, glw, glg, sf, sl, so) sauerkraut (sf) laugen-semmelknödel (ei, glw)',
#  'semmelknödel (ei, glw) pilzrahmsoße (mi, sf)',
#  'pasta bar, täglich wechselndes angebot (glw) penne, grünkohlpesto (glw, nmn, nc) nudelauflauf, kürbis, käsekruste (ei, glw, mi, sl)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (1, ei, glw, mi)',
#  'frikadelle (ei, glw) coleslaw (3, ei, glw, mi, sl) kartoffelgratin (ei, mi)',
#  'börek, fetakäse (ei, glw, mi) tomaten- minzsugo couscous (glw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) überbackenes moussaka (ei, glw, mi, so) soja-bolognese (glg, so) pesto',
#  'shakshuka - tomate, paprika, ei, hirtenkäse',
#  'tagesgericht bandnudeln (glw) in cherry-tomatensoße ...mit mozzarella- tomaten- schnitzel (ei, glw, glh, mi)',
#  'gnocchi, buntes gemüse (ei) rucolapesto (1, 2, mi, nc)',
#  'frikadelle (ei, glw) petersiliensoße (1, mi) wurzel- kartoffelstampf (mi, sl)',
#  'gebratener seehecht, rührei, balsamicolinsen, meerrettich-kartoffelstampf (3, 5, ei, fi, glw, mi, sf, sw, sl)',
#  'welsfilet gebraten (ei, fi, glw) gemüsesoße (glw, mi, sf) salzkartoffeln',
#  'gebratener seehecht,eihülle, balsamicolinsen, kürbis, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'pasta bar, täglich wechselndes angebot (glw) gnocchigratain , hokkaido, käse (ei, glw, mi)',
#  'bagel mit grillgemüse und pesto (glw, glr, glg, glh, se, lu) mit rucolapesto (2, ei, mi)',
#  'begrenztes angebot nudelgratin, mangold, karotten, gouda (ei, glw, mi) tomatensoße',
#  'begrenztes angebot steckrüben- kartoffel- karotten- gratin, kräuterquark (ei, glw, mi)',
#  'tortellini, gemüsesoße (ei, glw, glr)',
#  'tortellini, hirschfüllung, rucolapesto (ei, glw)',
#  'letzter tag - heute nur bis 13:30 geöffnet pasta bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sl, sw)',
#  'kaiserschmarrn (ei, glw, glh, nmn) fruchtsoße',
#  'frikadelle (ei, glw, mi) pfefferrahmsoße (mi) kartoffelgratin (ei, mi)',
#  'spaghetti carbonara (2, 3, 4, ei, glw, mi)',
#  'pfannkuchen, zimtzucker (ei, glw, mi) apfelmus (3)',
#  'apfelpfannkuchen, zimtzucker (3, ei, glw, mi)',
#  'labskaus, rollmops, spiegelei (2, 8, ei, fi)',
#  'pasta bar, täglich wechselndes angebot (glw) käsespätzleauflauf, tomatensoße, gouda (ei, glw, mi)',
#  'hausgemachter pfannkuchen, zimtzucker (ei, glw, mi) apfelkompott (3)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) kroketten (glw)',
#  'pasta bar, täglich wechselndes angebot nudel- mangold- karotten- gratin, bärlauchdip (ei, glw, mi)',
#  'seehecht im backteig (fi, glw) erbsen-gurken-dip (3, ei, glw, sl) röstkartoffeln',
#  'pasta bar, täglich wechselndes angebot italienischer nudelauflauf, champignons, gouda (ei, glw, mi)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) erbsen kartoffelgratin (ei, mi)',
#  'pasta bar, täglich wechselndes angebot gnocchi, bunten gemüse (ei) cherry-tomatensoße',
#  'welsfilet in eihülle (ei, fi, glw) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'steckrüben- kartoffel- karotten- gratin, rucolaquark (ei, mi)',
#  'frikadelle (ei, glw) stampfkartoffeln (mi) sauerkraut (glw, mi)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'quinoa-burger mit soja-chili-dip, tomate, gurke, rucola (ei, glw, gld, mi, sf, so)',
#  'blumenkohl- kartoffelcurry- gratin, rucolasalat, eine banane (ei, mi)',
#  'frikadelle (ei, glw) gestovte bohnen (mi) salzkartoffeln',
#  'kibbelinge (ei, fi, glw, mi, sf) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten (glw)',
#  'begrenztes angebot sahnehering (3, 8, ei, fi, glw, mi, sf, sl) röstkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße nudelauflauf, gemüse, käsesoße (ei, glw, mi)',
#  'shakshuka - tomate, paprika, ei, hirtenkäse naan brot',
#  'jahrmarktpuffer , kicherbsen, spitzkohl, cashewkerne und rosmarin (ei, nc)',
#  'begrenztes angebot putengeschnetzeltes, kokos, karotte (mi) spätzle (ei, glw)',
#  'tortelliniauflauf, tomaten-gemüseragout, gouda (ei, glw, mi)',
#  'frikadelle, (ei, glw), rotweinsoße, (sw), broccoli, kartoffelspalten',
#  'begrenztes angebot kartoffel-reibekuchen (ei) apfelmus (3)',
#  'regionaler stangenspargel vom gut friedrichshof hollandaise soße (ei, mi) salzkartoffeln',
#  'haferfrikadelle (glw, glh) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten',
#  'kartoffelgratin, erbsen, karotten, gouda (ei, mi)',
#  'pasta, kürbis- ricotta- soße, walnüsse (ei, glw, mi, nw, sl)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, champignons, brokkoli, käsekruste (ei, glw, mi, sl) pasta, pesto, marinierte tomaten (1, 3, 5, glw, nw, sw)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) brechbohnen kartoffelpüree (3, 5, sw, mi)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (1, 3, 5, ei, fi, glw, mi, sf, sw)',
#  'bunte spiralnudeln, (glw), bolognese soße, (2, ei, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, 4, glw, mi, sl) curry- kokos- gemüsesoße (glw, sl, so) kartoffel- grünkohl- auflauf (2, 3, 4, 8, 10, ei, mi, sf)',
#  'frikadelle (ei, glw) champignonsoße (mi) semmelknödel (ei, glw)',
#  'mensa 2 salatteller, eisberg, rucola, tomate, olive, gurke, radieschen, ei (6, ei, glw, sf)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rote- linsen- bolognese (sl) gnocchiauflauf, linsen- bolognese, mozzarella (ei, mi, sl) tomatensoße',
#  'kartoffel- kürbisauflauf, käsekruste (ei, mi)',
# ...
#  'überbackener gyrosauflauf (1, 2, 3, 4, glw, glg, mi, so)',
#  'welsfilet gebraten (fi, glw) kohlrabi in rahm (ei, mi, sl) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) broccolirahmsoße (mi) putengeschnetzeltes "züricher art" (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto kokos-gemüsecurry, mu err pilze, jackfruit [bio], glasnudeln (3, glw, se, so)',
#  'falafel (glw, sl) linsensalat (sl, sw) joghurt [bio]- zitronen- minz- dip (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten-gemüse-soße curry- kokos- soße, spinat (3)',
#  'spaghetti carbonara (1, 2, 3, 4, glw, mi)',
#  'pasta bar, täglich wechselndes angebot nudelauflauf, gemüse, käsekruste (ei, glw, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kidneybohnen-curry (1) nudelauflauf, kidneybohnen-curry, gemüse (1, 2, glw) radieschenblatt -rucolapesto wurstgulasch mit gemüse (2, 3, 10, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kichererbsenragout (2, se) rucolapesto',
#  'begrenztes angebot putengeschnetzeltes, kokos, karotte (mi) reis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kürbis- ricotta- soße (mi, nw) putengeschnetzeltes, kokos, karotte (mi)',
#  'pasta (glw) käsesoße (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja bolognese (1, 3, 5, glg, sl, so, sw) pesto (nw)',
#  'gnocchi, brokkoli (ei) gorgonzolasoße (mi)',
#  'frikadelle (ei, glw) pfefferrahmsoße (mi) sauerkraut kartoffelgratin (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) süßkartoffel- kokos- curry (sw) currywurst hot pot(t) (1, 2, 3, 5, 10, sf, sl, sw)',
#  'reisnudeln, tofu, gemüse (1, 2, 3, 4, glw, glg, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) linsen ragout',
#  'pasta bar, pasta, putencurry (1, 2, 3, 4, glw, glg, mi, so)',
#  'frikadelle (ei, glw) petersiliensoße (mi) wurzel- kartoffelstampf (mi, sl)',
#  'putenschnitzel paniert (2, ei, glw, mi) curry- kokos- soße (3) broccoli und süßkartoffel-mais-pürre',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) sauer-scharfe-soße, mu err pilze, jackfruit [bio], tofu (1, 2, 3, 4, en, glw, se, so) nudelauflauf, planted.pulled bbq, käsekruste (1, 2, glw, glh, sf, so)',
#  'street style: ofenkartoffel "kumpir", oliven, tomaten, gurken, quark-dip, minze, gouda (6, mi, sf)',
#  'pasta, bio bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) sauer-scharfe-soße, mu err pilze, tofu, jackfruit [bio], (3, glw, se, so) pesto',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) grünes- kokos- gemüse- curry (so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) chilli sin carne (2, 6, sl) gemüserahmsoße (mi, sl)',
#  'sloppy gnocchi (ei, mi)',
#  'frikadelle (ei, glw) rotweinsoße (sw) rotkohl (1, 3, 5, 8, sw) kartoffelgratin (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) linsen-kartoffel-curry (sl, sw) grünkohlpesto (nmn, nc)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto rote- linsen- bolognese (sl, sw)',
#  'pasta bolognese, geriebener hartkäse (sl, giw, sw, mi, ei)',
#  'blumenkohl- kartoffel- curry, rucola, tomaten (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, so) kürbis -frischkäsesoße (mi)',
#  'paniertes welsfilet (ei, fi, glw) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'kürbissuppe, ingwer, croutons (glw, mi) baguettebrot (glw)',
#  'steckrüben- kartoffel- karotten- gratin, grünkohlpesto (ei, mi, nmn, nc)',
#  'putenschnitzel paniert (glw) curry- kokos- soße (3, mi) broccoli reis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) arrabiata soße (2, 6, sl) rajma dal (1) indisches kidneybohnen-curry',
#  'weizenteigfladen, scharfes kichererbsenmus, hirten-käse, salat (2, glw, mi, se, sf)',
#  'oriental bowl - feigen, datteln, aprikosen, cous cous, schafskäse, granatapfel (2, 5, glw, mi, sw)',
#  'tortellini, quinoafüllung (glw) rahmspinat (mi)',
#  'pasta bar, in selbstbedienung bolognese soße (1, 2, mi, sl) soja-bolognese (glw, so) pasta (glw)',
#  'pasta bar, täglich wechselndes angebot pasta, pesto, peperoni (1, 3, 5, glw, mi, nw, sw) pasta, brokkoli - tomatensoße (glw)',
#  'welsfilet gebraten (fi, glw) helle dijon- senf- soße (mi, sf) gemüsestreifen (sl) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tomatensoße, gemüse, tofu (1, 2, 4, en, glw, se, sf, so, sw)',
#  'begrenztes angebot (1, 2, 3, 4, glw, glg, mi, so) nudelauflauf mit hänchen, rucola (en, glw, mi, so)',
#  'gnocchi, buntes gemüse (1, 2, mi)',
#  'bunte pasta (glw) käsesoße (1, mi)',
#  'falafel bowl, falafelbällchen, rotkohl, kräuter-joghurt, orangen-couscous (glw, mi, nmn, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) knoblauch- chili- sud, wokgemüse (en, glw, so) nudelauflauf, gemüse (1, glw, mi, sf) mie-nudeln (en, glw)',
#  'milchreis zimt und zucker (mi)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln (1, 3, ei, fi, glw, mi, sf, sw)',
#  '2 senfeier in sauce (ei, mi, sf) mit salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) jackfruit-nudelauflauf (1, 2, 3, glw, sf, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten-oliven-pesto (6) paprika- oliven- soße (6)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto indisches kidneybohnen-curry (1, en, glw, glg, se, so)',
#  'eierpfannkuchen, zimtzucker (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto sojasteifen, knoblauch- chili- sud, wokgemüse (1, en, glw, glh, sf, so)',
#  'kartoffel- kürbisauflauf, käsekruste (ei, glw, mi)',
#  'kasselernackenbraten (2, 8, 10) rotweinsoße (sw) rosenkohl kartoffelgratin (ei, mi)',
#  'erbseneintopf, roggenbrötchen (glw, glr, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) chili sin carne basilikum-gemüsesoße (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto (nw) tomatensoße (1, 3, 5, sl, sw)',
#  'gefüllte pasta (ei, glw, mi) currysoße (mi)',
#  'frikadelle (ei, glw) milchbohnen (glw, mi) pommes',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, blumenkohl- kartoffel- curry, käse (mi)',
#  'putengeschnetzeltes "züricher art" (mi, so) spätzle (ei, glw)',
#  'pasta bar, täglich wechselndes angebot (2, 3, 4, glw, glg, mi, so)',
#  'welsfilet gebraten (fi, glw) helle dijon- senf- soße (mi, sf) steckrübengemüse (mi, sf) salzkartoffeln',
#  'pasta bar, in selbstbedienung bolognese soße (mi, sl) bandnudeln (glw) im menü mit mio ginger + 1,30 € zzgl. pfand',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) mangoldpesto (1, 2, sf) gorgonzolasoße (mi) nudelauflauf, paprika- oliven- soße, spinat, gouda (6, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto soja-bolognese (glw, glg, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße pesto',
#  'hühnerfrikassee (1, 3, ei, mi, sf, sl) reis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) ratatouille käsesoße (1, glw, mi, sf)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten- kichererbsensoße mit chili (2, se, sl) kürbis- ricotta- soße (mi, nw, sl)',
#  'gnocchi, blattspinat (ei) gorgonzolasoße (mi)',
#  'tagesgericht: erbseneintopf, basilikumschmand (mi, sl)',
#  'pasta bar in selbstbedienung (glw, mi) rucolapesto (nc) soja-bolognese (glw, so) bolognese soße (sl)',
#  'frikadelle (ei, glw) milchbohnen (glw, mi) salzkartoffeln',
#  'frikadelle (ei, glw) stampfkartoffeln (1, mi) milchbohnen (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto ratatouille (6)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto ratatouille',
#  'spargelcremesuppe, frühlingszwiebel (mi) baguettebrot (glw)',
#  'pasta bar, täglich wechselndes angebot tortellini-auflauf, käse überbacken, sourcreme (glw, mi, nc)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensugo, minze rucolapesto, kürbiskerne',
#  'brokkolisuppe, geräucherter tofu (glw, mi, so) baguettebrot (glw)',
#  'nudel- blumenkohl- karotten- gratin, bärlauchdip (ei, glw, mi)',
#  'gebratener seehecht (fi, glw) kohlrabi in rahm (mi) salzkartoffeln',
#  'welsfilet gebraten (fi, glw) helle dijon- senf- soße (glw, mi, sf) gemüse (sl) salzkartoffeln',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) arrabiata soße (2, 6, sl) kräutersoße (mi) makkaroni- tomaten- auflauf (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) gemüse-tomatensoße nudelauflauf, käsekruste (1, glw, mi, sf, sl)',
#  'königsbergerklopse (ei) kapernsoße (mi) salzkartoffeln',
#  'pasta, blattspinat- tomaten- frischkäsesoße (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto indisches curry, kichererbsen, gemüse',
#  'nudel- mangold- karotten- gratin, bärlauchdip (ei, glw, mi)',
#  'heringssalat, salzkartoffeln (2, 8, ei, fi, mi, sf)',
#  'gefülltes baguette pulled turkey mit spitzkohlsalat (glw, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja-bolognese (glg, sl, so) pesto allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (ei, glw, mi)',
#  'pastabar bolognese soße (1, 2, mi, sl) käsesoße (mi)',
#  'grüne- thai- erbsen - gemüsesuppe, (glw, mi, sl) baguettebrot (glw)',
#  'milchreis mit roter grütze groß (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja-bolognese (glg, sl, so) blattspinat (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten- kokossoße putengeschnetzeltes, kokos, karotte (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) thai soja bolognese, ingwer, basilikum, koriander (1, 2, 4, glw, glg, so) pesto',
#  'brezelauflauf (ei, glw, glg, mi) rahmspinat (1, mi)',
#  'linsenbratling, joghurtdip, chilikartoffeln, gurken- radieschen- salat (ei, glw, mi)',
#  'kartoffelgratin, gemüse, gouda (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) kichererbsen curry mit kürbis und blumenkohl (sf) pesto',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto rosenkohl- curry mit kichererbsen tomaten- gemüse- soße (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) indisches kidneybohnen-curry (1) tomaten- sahne- soße,gemüse (mi, so)',
#  'tagesgericht: pasta mit (glw, mi) käsesoße (1, mi)',
#  'kartoffelgratin, tomate, mozzarella (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) spätzleauflauf, bergkäse (ei, glw, mi) wurstgulasch, rahmsoße, champignons (1, 2, 3, 8, mi)',
#  'pasta mit grünem spargel, kirschtomaten (glw) und rucolapesto (2, ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto wurstragout, gemüse (2, 3, 10, sl, sw)',
#  'dinkel-mediterran-burger, soja- chili- dip, tomate, gurke, rucola (ei, glw, gld, mi, sf, so) gitterkartoffeln (glw)',
#  'semmelknödel (ei, glw) pilzrahmsoße (mi, sf)',
#  'lahmacun mit rotkraut, weißkraut, feta, kräuter (glw, mi, so) curry- joghurt [bio]- dip (mi, sf)',
#  'burger im menü mit fritz 0,33l cheese burger (1, glw, mi, se, sl) ... mit pommes frites',
#  'pasta bar, täglich wechselndes angebot (glw) penne, grünkohlpesto (glw, nmn, nc) nudelauflauf, kürbis, käsekruste (ei, glw, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) kichererbsen-tomaten-ragout (3) kartoffel-weiße bohnen ragout, kochwurst (1, 2, 3, 4, 8, 10, sf, sl)',
#  'grünkohl (2, 3, 4, mi, sf) röstkartoffeln kochwurst (2, 3, 4, 8, 10, sf, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, glw, mi, sl) kartoffel-weiße bohnen ragout (sl) tomaten - bohnen ragout (1, glw, mi)',
#  'allgäuer käsespätzle, bergkäse, geschmelzte zwiebeln (1, ei, glw, mi)',
#  'broccolicremesuppe (mi)',
#  'mac n cheese (1, glw, mi, sf)',
#  'frikadelle (ei, glw) coleslaw (3, ei, glw, mi, sl) kartoffelgratin (ei, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi, so) pesto jackfruitragout [bio], gemüse, sauer-scharfe-soße (1, 3, 5, glw, se, sf, so, sw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) erbsen- cashewkern- pesto (nw, nc) gorgonzolasoße mit spinat (glw, mi)',
#  'börek, fetakäse (ei, glw, mi) tomaten- minzsugo couscous (glw)',
#  'börekstange spinat gurkensalat (mi) bulgur [bio] (glw) joghurt [bio]- zitronen- minz- dip (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) überbackenes moussaka (ei, glw, mi, so) soja-bolognese (glg, so) pesto',
#  'pasta bar, täglich wechselndes angebot (glw, mi) bolognese soße (mi, sl) soja-bolognese (glw, so)',
#  'tagesgericht bandnudeln (glw) in cherry-tomatensoße ...mit mozzarella- tomaten- schnitzel (ei, glw, glh, mi)',
#  'gnocchi, buntes gemüse (ei) rucolapesto (1, 2, mi, nc)',
#  'milchreis mit roter grütze (mi)',
#  'frikadelle (ei, glw) petersiliensoße (1, mi) wurzel- kartoffelstampf (mi, sl)',
#  'erbseneintopf, minzdip, roggenbrötchen (glw, glr, mi, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tomaten- kokosnuss-soße makkaroni- tomaten- auflauf (glw, mi)',
#  'gebratener seehecht, rührei, balsamicolinsen, meerrettich-kartoffelstampf (3, 5, ei, fi, glw, mi, sf, sw, sl)',
#  'griesbrei (glw, mi) heiße kirschen',
#  'dürüm türkischer dilljoghurt cacik (2, glw, mi)',
#  'welsfilet gebraten (ei, fi, glw) gemüsesoße (glw, mi, sf) salzkartoffeln',
#  'gebratener seehecht,eihülle, balsamicolinsen, kürbis, meerrettich-stampf-kartoffeln (3, ei, fi, glw, mi, sf, sw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rote- linsen- bolognese (sl) cherry-tomatensoße rucolapesto (1, 2, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) soja-bolognese (glg, sl, so)',
#  'pasta bar, täglich wechselndes angebot (glw) gnocchigratain , hokkaido, käse (ei, glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) rote- linsen- bolognese (sl)',
#  'thüringer bratwurst (2, 3, 8, 10, sf, sl) sauerkraut kartoffelpüree (mi)',
#  'langosch (2, 3, 4, glw, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße (1, 3, 5, sw)',
#  'pasta bar: täglich wechselndes angebot (1, 2, 3, 4, glw, glg, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, glg, mi, sf, so) cherry-tomatensoße, zucchini, oliven (6) rote- linsen- bolognese (glw, sl)',
#  'bagel mit grillgemüse und pesto (glw, glr, glg, glh, se, lu) mit rucolapesto (2, ei, mi)',
#  'spargelcremesuppe, tofu, frühlingszwiebeln (glw, mi, so) baguettebrot (glw)',
#  'wurstgulasch (2, mi) kartoffelspalten',
#  'begrenztes angebot nudelgratin, mangold, karotten, gouda (ei, glw, mi) tomatensoße',
#  'bratwurst dithmarscher art (3, 4, sf, sl) sauerkraut stampfkartoffeln (mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomatensoße (1, 3, 5, sw) rosenkohl- curry mit kichererbsen',
#  '" schmaler taler - teller " (glw) pasta, pilzrahmsoße (mi, sf) jeden tag ein preiswertes gericht solange der vorat reicht',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, 4, glw, glg, mi, so) tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, so) afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf) paprika- oliven- soße (6)',
#  'pasta bar, täglich wechselndes angebot (1, 2, 3, 4, glw, mi, sl) grünes- kokos- gemüse- curry (so) chili con carne',
#  'hühnerfrikassee (1, 3, mi, sf) reis',
#  'arabischer linseneintopf (3, 5, mi, sl, sw) baguettebrot (glw)',
#  'pasta bar: pasta, würstchen, käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) tomaten curry soße (sf, sw) käsesoße, kichererbsen (1, 2, mi, se)',
#  'begrenztes angebot steckrüben- kartoffel- karotten- gratin, kräuterquark (ei, glw, mi)',
#  'thüringer bratwurst (2, 3, 8, 10, sf, sl) stampfkartoffeln (mi) sauerkraut',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, putengeschnetzeltes, käse (glw, mi)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto tomatensoße',
#  'burger bescherung - pulled duck burger, rotkrautsalat, rucola, preiselbeer dip (1, 2, 3, 4, 5, glw, mi, se, sf, so, sw) pommes frites',
#  ...]

# %%
terms_vgn = ["vegan"]
vgn_heuristic = ["tofu", "reis", "soja", "asia"]

vgn_regexs = generate_regex(terms_vgn)
vgn += apply_regexs(vgn_regexs, nc_names)
nc_names = set(nc_names)-set(vgn)

vgn_heuristic_regexs = generate_regex(vgn_heuristic)
vgn += apply_regexs(vgn_heuristic_regexs, nc_names)
nc_names = set(nc_names)-set(vgn)


print(len(vgn))
vgn
# Out:
# 731
# ['vegane brastwurst (sf) sauerkraut stampfkartoffeln (mi)',
#  'veganer burger im menü mit fritz 0,33l falafel burger mit soja-paprika-dip, tomate, gurke, salat (glw, glh, gld, sf, so) ... mit pommes frites',
#  'falafel bowl cous cous, tomate, gurke, rotkraut, eisbergsalat, mandeln, veganer dip',
#  'veganissimo: rainbow pasta, kürbis, rote beete, oliven, kräuter, blumenkohl (6, 8, en, glw)',
#  'veganer chrunchy chick`n burger, (glw, gld, sf, so) gemüsesticks & pommes fritiert',
#  'sojagyros, vegane aioli ebly',
#  'streng limitiert tomaten- oliven- peperoni- nudelauflauf mit veganem "käse"',
#  'vegane ente orangensoße rotkohl kroketten',
#  'planted bratwurst (sf) sauerkraut stampfkartoffeln vegan (1)',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, glw, gld, sf, so) gitterkartoffeln (glw)',
#  'begrenztes angebot vegane bratwurst currysoße pommes frites',
#  'bulgur [bio]-gemüsepfanne (glw, sf) veganer dip (1, 2, 4, 10, glw, sf, so)',
#  'pasta bolognese vegan 3,50€',
#  'vegane currywurst hot pot(t) currysoße karamellisierte balsamico zwiebeln gebackenen kartoffeln',
#  'pasta bar, täglich wechselndes angebot (glw) pasta, basilikum-chilipesto, paprikawürfel (1, 3, 5, glw, nw, sw) veganes wurstgulasch, pasta (3, glw, sl)',
#  'veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) gitterkartoffeln (glw) zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'vegane nuggets (glw)',
#  'holsteiner vegane kartoffelsuppe mit gemüse und croutons 2,50 € ... mit wiener würstchen 3,50 €',
#  'falafel teller mit salat, (3, 5, glw, sw) veganer tzatziki (3, sf, so) pommes frites',
#  'veganuary: veggie-backfisch vom feld (glw) erbsen-gurken-dip (sf, so) röstkartoffeln',
#  'pasta bar, täglich wechselndes angebot pasta, soja bolognese (1, 2, 4, glw, glg, so) hausgemachte apfelpfannkuchen, zimtzucker (3, ei, glw, mi) bratnudeln, veganes chicken, gemüse (glw, nc, so)',
#  'vegane bratwurst (sl, so) currysoße (2, 3, sf, sl) pommes frites',
#  'döner teller mit salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) pommes frites',
#  'veganuary: p.h.d. - planetary health dog (8, glw, sf, so) laugenbrötchen, planted. bratwurst, peperoni, tomate, röstzwiebelmayo',
#  'currywurst vegan hot pot(t) (2, 3, sf, sl, so) gitterkartoffeln (glw) karamellisierte balsamico zwiebeln (1, 3, 5, sw)',
#  'begrenztes angebot pasta bar nudelauflauf ,vegan streukäse',
#  'vegane haferflockenfrikadelle mit grünem gemüse (glw, glh, mi, nmn, sf) basmatireis tomatensauce (sw) indisches butterpatty, joghurt[bio], tomate, mandeln',
#  'begrenztes angebot jackfruit [bio] burger, vegane cocktailsoße (3, glw, gld, sf, so) kartoffelspalten',
#  'campus welcome aktion vegan: sabsi rosenkohl- curry mit kichererbsen',
#  'planted veganer hot dog (glw, glg) currysoße (3, sl) fritierte kartoffel',
#  'bunte pommes mischung, süßkartoffel guacamole tomatensalsa wasabi veganese',
#  'pasta bar (1, 2, glw, glg, mi, so) putengeschnetzeltes, kokos, karotte (mi) vegane thai soja bolognese (1, 2, 4, glw, glg, so)',
#  'tagesgericht lahmacun vegan - türkische pizza mit frischen salaten, kräutern und chilisoße (glw, so)',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, chili sin carne, vegan käse (1, 2, glg, so)',
#  'begrenztes angebot schweine cordon bleu (2, 3, glw, mi) vegane cocktailsauce (sf, so) kartoffelspalten',
#  'campus welcome aktion vegan: bibimbap bowl - koreanisches reisgericht mit gemüse und sojahack',
#  'pasta bolognese vegan',
#  'chilli fries sin carne veganese (6, sf, so)',
#  'begrenztes angebot veganer green hero oat burger, eisbergsalat, cocktailsauce (3, glw, glg, glh, sf, so) kartoffelspalten',
#  'bunte pommes mischung (1, glw) guacamole (so) tomatensalsa (sw) wasabi veganese (3, sf, so)',
#  'tagesgericht: veganer burger im menü mit fritz 0,33l green hero oat burger mit soja-chili-dip, tomate, gurke, rucola (glw, glh, gld, sf, so) ... mit pommes frites',
#  'mediterrane spargel- kartoffel- pfanne veganer kräuter -dip (3, sf, so)',
#  'vegane currywurst hot pot(t) (3, glw, sl) fritierte kartoffel',
#  'ofengemüse holsteiner art rosmarinkartoffeln veganer soja dip (3, sf, so)',
#  'veganuary: planted.chicken makhan (1, glh, nmn, sf) basmatireis indisches butter planted.chicken, tomaten, mandeln, kokosmilch',
#  'nudelgratin, brokkoli, champignons, vegane käsekruste (ei, glw, mi)',
#  'vegane nuggets (glw) sommerlicher kartoffelsalat (sf)',
#  'hähnchenbrust, curry-grillmarinade (se) vegane cocktailsauce (sf, so) kartoffelspalten',
#  'tagesgericht pasta bolognese vegan (glw, glg, sl, so)',
#  'erbseneintopf, kassler mich gibt es auch vegan (2, 3, 4, 5, 8, 10, sl, sw) baguettebrot (glw)',
#  'falafel burger, vegane mayonaise, salat, tomate, coleslaw (3, glw, gld, sf, sl, so) süßkartoffelpommes (1)',
#  'begrenztes angebot: veganuary: p.h.d. - planetary health dog (8, glw, sf, so) laugenbrötchen, planted. bratwurst, peperoni, tomate, röstzwiebelmayo',
#  'maniok- und kartoffelspalten veganes tofu chili mit kidneybohnen, mais, knoblauch, rucolapesto',
#  'pasta bar, täglich wechselndes angebot (glw) nudelauflauf, chili sin carne, vegan käse (1, 2, glw)',
#  'vitalburger, falafel, rotkraut,zwiebeln, salat, vegane cocktailsoße (glw, glr, sf, sl, so) kartoffelspalten (glw)',
#  'vegane currywurst (sl, so) pommes frites currysoße (2, 3, sf, sl)',
#  '2 geflügelbratwurst [bio] (sf) sauerkraut stampfkartoffeln vegan (1)',
#  'tagesgericht: planted döner style teller (glw, glg, se) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'veganes schnitzel (glw) pommes frites champignonsoße (mi)',
#  'veganer bachfisch (glw) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten',
#  'currywurst vegan hot pot(t) (3, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten',
#  'veganer chrunchy chick`n burger, (glw, gld, gir, gig, gih, sf, so, se) oder veganer onion burger (giw, gid, gir, gig, gih, sf, so, se) pommes',
#  'veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) gemüsesticks & pommes fritiert (glw)',
#  'ofengemüse, rosmarinkartoffeln veganese (sf, so)',
#  'veganes indisches butter chik`n (nmn, so) basmatireis',
#  'begrenztes angebot: wechselnde auswahl nudelgratin mit brokkoli und basilikumsoße (mi, glw) auch als vegane alternative mit champignons (glw, glh)',
#  'vegane ofenkartoffel, tomaten- zwiebel- marmelade 2,80€',
#  'ofengemüse holsteiner art veganer kräuter -dip (3, glh, sf, so) röstkartoffeln',
#  'grünkohl vegan röstkartoffeln',
#  'weihnachtsessen veganer entenschmaus rotkohl kroketten orangensoße',
#  'falafel bowl cous cous, tomate, gurke, rotkraut, eisbergsalat, mandeln, veganer kräuter joghurt',
#  'ofengemüse holsteiner art veganer kräuter-dip (3, sf, so) röstkartoffeln',
#  'planted vegane currywurst currysoße (3, sl) pommes frites',
#  'nudelauflauf, brokkoli, champignons, vegane käsekruste (1, 2, glw)',
#  'jackfruit burger, vegane cocktailsoße (3, glw, gld, sf, so) kartoffelspalten (glw) vegane mayo ohne ei (sf, so)',
#  'begrenztes angebot planted chicken softshell tacos, limette, koriander (glw, sf) vegane cocktailsoße (sf, so)',
#  'chicken kräuter+zitrone vegan, kokos, karotte, basmatireis (mi, sf)',
#  'lahmacun vegan türkische pizza mit frischen salaten, kräutern und chilisoße',
#  'currywurst vegan hot pot(t) gitterkartoffeln',
#  'börek, spinatfüllung (glw) couscous (glw) veganer minzjoghurt (3, so)',
#  'jackfruit burger, vegane cocktailsoße (3, glw, gld, sf, so) kartoffelspalten (glw)',
#  'currywurst vegan hot pot(t) karamellisierte balsamico zwiebeln steakhouse fries',
#  'ofengemüse holsteiner art (sl) veganer kräuter -dip (3, sf, so) röstkartoffeln',
#  'leider ausverkauft!!! veganissimo: chrunchy chick`n burger, (glw, sf, so, gld) gemüsesticks & pommes fritiert (glw)',
#  'begrenztes angebot: wechselnde auswahl vegane zwiebelfrikadelle auf gemüse-ragout mit kokos-duftreis (sf)',
#  'veganer burger im menü mit fritz 0,33l falafel burger mit soja-paprika-dip, tomate, gurke, salat (glw, glh, gld, sf, so) ... mit wedges',
#  'nutzt auch gerne unser cafeteriaangebot zbsp. neu vegane currywurst',
#  'ofengemüse holsteiner art veganer kräuter -dip (3, sf, so) röstkartoffeln',
#  'campus welcome aktion vegan: currywurst hot pot(t) karamellisierte balsamico zwiebeln gebackenen kartoffeln',
#  'pasta bar, täglich wechselndes angebot bratnudeln, gemüse, veganes chicken, misorahm (1, 2, 4, en, glw, glh, sl, so) pasta , oliven-tomatenpesto (en, glw)',
#  'bunte pommes mischung, maniok, süßkartoffel (1) guacamole (so) tomatensalsa (1, 3, 5, sw) wasabi veganese (3, 5, so, sw)',
#  'ofenkartoffel, planted.chicken, kräuter und zitrone (sf) chinakohl- mango- salat veganer kräuter -dip (3, sf, so)',
#  'erbsen- quinoa- frikadelle (sl) veganer kartoffelsalat (sf)',
#  'fischnuggets (fi, glw, sf) vegane cocktailsauce (3, sf, so) pommes frites',
#  'vegane wurst (sf)',
#  'geschöpfte vegane currywurst, baguette karamellisierte balsamico zwiebeln',
#  'veganuary: planted.chicken tenders (glw) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'currywurst vegan hot pot(t) (3, sl, so) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten',
#  'ofengemüse holsteiner art röstkartoffeln veganer kräuter -dip (3, sf, so)',
#  'pulled vegan duck burger, rotkrautsalat, kräutercreme (glw, gld, se, so) kartoffelspalten',
#  'vegane nuggets (glw) pommes frites',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto currywurstragout vegan (1, 3, 5, sl, sw) currywurstragout (1, 3, 5, 10, sf, sl, sw) gemüsesoße, fleischklöße (ei)',
#  'pasta, vegane soja bolognese (1, 2, 6, glw, sl, so)',
#  "veganissimo: butter chick'n peas - indisches kichererbsen curry mit kürbis und blumenkohl (sf) basmatireis",
#  'falafel teller mit salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) kartoffelspalten',
#  'vegane tortellini, vegane cremige pilzsauce, vegane frische kräuter (glw, nc, so)',
#  'bunte pommes mischung (1) guacamole (3, so) tomatensalsa (sw) wasabi veganese (3, sf, so)',
#  'planted vegane currywurst, currysoße, (3, sl), pommes frites',
#  'bunte pommes mischung, süßkartoffel (1) guacamole (so) tomatensalsa (sw) wasabi veganese (sf, so)',
#  'bunte vegane gnocchi, tomaten-oliven-topping, basilikumdip',
#  'begrenztes angebot; wechselnde auswahl (sl, gid) veganes linsenchili, basmatireis',
#  'weihnachtsessen vegane entenbowl, kroketten, rosenkohl',
#  'veganissimo: chrunchy chick`n burger, (glw, gld) gemüsesticks & pommes fritiert (glw)',
#  'veganissimo! bunte pommes mischung, süßkartoffeln,maniok,kartoffel guacamole tomatensalsa wasabi veganese',
#  'veganer backfisch, senfsoße, bratkartoffeln (2, 8, glw, mi, sf)',
#  'pasta bar (1, 2, glw, mi) bolognese soße (sl) vegane tomatensoße',
#  'weizenteigfladen, scharfes kichererbsenmus, veganer käse, salat (1, 2, 3, glw, sf, se)',
#  'bayern-burger, falafel, sauerkraut, röstzwiebeln vegane mayonnaise, süßer senf, gitterkartoffeln',
#  'currywurst vegan hot pot(t) karamellisierte balsamico zwiebeln gitterkartoffeln',
#  'veganer backfisch (glw) dillkartoffeln kräutersauce (mi, sf)',
#  'begrenztes angebot: (1, 2) kartoffelgemüsepfanne, veganer käse',
#  'planted chicken curry, ofenkartoffel (sf) chinakohl- mango- salat (sf, so) veganer kräuter-dip (3, sf, so)',
#  'veganissimo: sizilianische pasta alla norma - aubergine, tomate, basilikum (1, 2, glw)',
#  'veganer chrunchy chick`n burger, (glw, glr, glg, glh, gld, se, sf, so) gemüsesticks & pommes fritiert (glw)',
#  'hähnchenbrust kartoffelspalten vegane mayo',
#  'vegane nuggets (glw) blattspinat salzkartoffeln',
#  'veganuary: planted.pulled bbq burger, smoked remoulade (8, glw, glh, gld, sf, so) pommes frites',
#  'veganuary: planted.chicken tenders vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'freestyle pasta, vegane blumenkohl- rahmsoße, soja- gemüse chunks (glw, nc, so, sl, 2)',
#  'planted.chicken tenders (glw) vegane cocktailsauce (3, sf, sl, so) kartoffelspalten',
#  'veganissimo lahmacun, türkische "pizza", rotkraut, weißkraut, kräuter kirschtomaten-konfit, rucola',
#  'ofenkartoffel chinakohl- mango- salat (sf, so) veganer kräuter-dip (3, sf, so)',
#  'planted chicken curry, ofenkartoffel chinakohl- mango- salat (sf, so) veganer kräuter-dip (3, sf, so)',
#  'weihnachtsessen vegane entenbowl',
#  'holsteiner vegane kartoffelsuppe (sl)',
#  'tagesgericht vegane nuggets (glw) pommes frites',
#  'veganuary: p.h.d. - planetary health dog (8, glw, sf, sl, so) laugenbrötchen, planted. bratwurst, peperoni, tomate, röstzwiebelmayo, pommes',
#  'döner teller mit falafel, salat, veganer tzatziki pommes frites',
#  'veganissimo bunte pommes mischung, maniok, guacamole tomatensalsa wasabi veganese',
#  'gefüllte, gratinierte zuchhini, veganes hack, veganer käse, tomatisierter bulgur (bio) (giw, sl, sf)',
#  'fischnuggets (fi, glw, sf) vegane cocktailsoße (sf, so) kartoffelspalten',
#  'planted.chicken tenders (glw) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'mediterrane spargel- kartoffel- pfanne (mi) veganer kräuter -dip (3, sf, so)',
#  'pasta, paprikaragout, veganer käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'bunte pommes mischung, maniok, süßkartoffel (1) guacamole (so) tomatensalsa (sw) wasabi veganese (sf, so)',
#  'jackfruit burger pommes frites vegane mayo',
#  'tagesgericht: döner style teller mit gyros (glw, glg, se) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'veganer currywurst hot pot(t) (3, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten',
#  'veganissimo bunte pommes mischung, kartoffel guacamole tomatensalsa wasabi veganese',
#  'vegane currywurst (2, 3, sf, sl, so) karamellisierte balsamico zwiebeln (1, 3, 5, sw) gitterkartoffeln (glw)',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, glw, gld, sf, so) kartoffelspalten zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'tagesgericht: erbsen- quinoa- frikadelle (sl) veganer kartoffelsalat (sf)',
#  'planted chicken curry, ofenkartoffel mango- salat (sf, so) veganer kräuter-dip (3, sf, so)',
#  'falafel bowl (3, glw, nmn, sl, so) cous cous, tomate, gurke, rotkraut, eisbergsalat, mandeln, veganer kräuter- joghurt',
#  'limited edition bbq veganer enten burger, country steak fries',
#  'vegane nuggets stampfkartoffeln kräutersoße',
#  'döner teller mit falafel, salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) pommes frites',
#  'tagesgericht vegane nuggets (glw) blattspinat salzkartoffeln',
#  'döner teller mit hähnchen, salat, (3, 5, sw) veganer tzatziki (3, sf, so) pommes frites',
#  'vegane currywurst hot pot(t) karamellisierte balsamico zwiebeln gebackenen kartoffeln',
#  'veganes fischfilet, balsamicolinsen, meerrettich-stampf-kartoffeln (3, en, glw, mi, sf, so, sw)',
#  'schweineschnitzel (ei, glw, mi) veganer kartoffelsalat (sf)',
#  'tagesgericht erbsen- quinoa- frikadelle (sl) veganer kartoffelsalat (sf)',
#  'veganissimo kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot',
#  'veganissimo! bunte pommes mischung, maniok, kartoffel und süßkartoffel guacamole tomatensalsa wasabi veganese',
#  'begrenztes angebot: wechselnde auswahl (ei, mi, so, sw, 6, sf) kartoffel- kürbis gratin, vegane apfelmayo, tomaten- oliven- tapenade (ei, mi, so, sw, 6, sf)',
#  'bunte pommes mischung, maniok, süßkartoffel (1) guacamole (so) tomatensalsa (sw) wasabi veganese (3, 5, sf, so, sw)',
#  'veganer burger im menü mit fritz 0,33l cheeseburger (glw, glh, gld, sf, so) ... mit pommes frites',
#  'begrenztes angebot veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) gemüsesticks & pommes fritiert (glw)',
#  'pasta bolognese vegan, (glw, sl, so)',
#  'falafel wasabi veganese rote bete, honig, sesam, koriander joghurt- zitronen- minz- dip',
#  'begrenztes angebot vegane nuggets (glw) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'vegane nuggets (glw) vegane cocktailsauce (3, sf, so) pommes frites',
#  'grünkohl (1, glw, sf, so) vegane bratwurst (sl, so) röstkartoffeln',
#  'veganer chrunchy chick`n burger, (glw, gld, sf, so) gemüsesticks & pommes fritiert (glw)',
#  'tagesgericht: vegane nuggets (glw) veganer kartoffelsalat (sf)',
#  'rezepte duell! - veganes indisches butter chik`n (nmn, so) basmatireis',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, 5, glw, gld, sf, so, sw) pommes frites',
#  'pasta bolognese vegan (glw, sl, so)',
#  'veganes kartoffelgratin mit gemüse (1)',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, glw, gld, sf, so) pommes frites',
#  'veganes schnitzel (glw) petersiliensoße (1, mi) wurzel- kartoffelstampf (mi, sl)',
#  'begrenztes angebot: jackfruit [bio] burger, vegane cocktailsoße (3, glw, glr, glg, glh, gld, se, sf, sl, so) kartoffelspalten',
#  'veganuary: planted.pulled bbq burger, smoked remoulade (8, glw, glh, gld, sf, so) frittierte gemüsesticks (glw)',
#  'jackfruit burger (3, glw, gld, sf, so) kartoffelspalten vegane mayo ohne ei (sf, so)',
#  'begrenztes angebot: seelachs gebraten, (fi, glw) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'nudelgratin, brokkoli, vegane käsekruste (1, 2, glw)',
#  'ofenkartoffel vegane bratwurst currysoße karamellisierte balsamico zwiebeln kräuter veganese',
#  'chicken crossies (glw) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'nudelgratin, brokkoli, champignons, vegane käsekruste (glw, mi)',
#  'vegane nuggets (glw) vegane cocktailsauce (3, sf, sl, so) kartoffelspalten',
#  'planted chicken curry, ofenkartoffel chinakohl- mango- salat (sf, so) veganer kräuter-dip (glh, nmn, sf, so)',
#  'planted.chicken curry mit salat veganer tzatziki (3, sf, so) pommes frites',
#  'veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) gemüsesticks & pommes frittiert (glw)',
#  'veganissimo: mercimek çorbasi - türkische linsensuppe (1, glw, glg, se)',
#  'maniok fries veganes tofu chili mit kidneybohnen, mais, knoblauch, rucolapesto',
#  'weizenteigfladen, scharfes kichererbsenmus, veganer käse, salat',
#  'tagessuppe: veganer bohnentopf mit avocado und kürbis',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) misosoße, jackfruit, gemüse (1, 2, 3, 4, en, glw, sl, so) nudelauflauf, brokkoli, champignons, vegane käsekruste (1, 2, glw)',
#  'bunte pommes mischung, maniok, süßkartoffel (1) tomatensalsa (sw) wasabi veganese (3, 5, sf, so, sw) veganese, melone, mango (sf, so)',
#  'bunte pommes mischung, maniok, süßkartoffel guacamole tomatensalsa wasabi veganese',
#  'veganer kartoffelsalat (sf) ...mit veganen nuggets + 2,95€ (glw) ...mit wiener würstchen + 1,90€ (2, 3)',
#  'döner style teller mit gyros (glw, glg, se) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'pasta bar: vegane pasta, kidneybohnen, oliven, veganer käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'ofengemüse holsteiner art veganer kräuter -dip (mi, sf, so) röstkartoffeln',
#  'tagesgericht pasta bolognese vegan (glw, sl, so)',
#  'vegane bratwurst (sf) sauerkraut stampfkartoffeln (mi)',
#  'vegane chili nuggets (glw) pommes frites',
#  'vegane nuggets (glw) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) kartoffelspalten',
#  'falafel bowl - cous cous, tomate, gurke, rotkraut, eisbergsalat, mandeln, veganer kräuter joghurt',
#  'jackfruit burger kartoffelspalten vegane mayo',
#  'planted chicken curry, ofenkartoffel chinakohl- mango- salat (glw, sf, so) veganer kräuter-dip (3, sf, so)',
#  'bunte pommes mischung (1) guacamole (so) tomatensalsa (sw) wasabi veganese (sf, so)',
#  'bunte pommes mischung, maniok, süßkartoffel vegane mayo mit chili meerrettich dip gurken- salat',
#  'falafel teller mit salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) gitterkartoffeln (glw)',
#  'vegane bratwurst, (sl, so)',
#  'begrenztes angebot: falafel bowl - cous cous, tomate, gurke, rotkraut, eisbergsalat, mandeln, vegane',
#  '"street-food-markt" vegane chili-cheese-fries chili sin carne vega tofunese',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw, mi) pesto veganes wurstragout (1, 3, 5, glw, nw, sw) soja-bolognese (glw, so)',
#  'tagesgericht planted döner style teller (glw, glg, se, sf) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'tagesgericht: vegane nuggets (glw) kartoffel- gurken salat (sf)',
#  'vegane currywurst (sl, so) currysoße (3, sl) pommes frites',
#  'vegane currywurst (sl, so) pommes frites',
#  'currywurst vegan hot pot(t) karamellisierte balsamico zwiebeln twisterkartoffeln',
#  'veganissimo kartoffel- broccoli- gratin frischkäsesoße',
#  'tagesgericht: schweineschnitzel (ei, glw, mi) veganer kartoffelsalat (sf)',
#  'tagesgericht döner style teller mit gyros (glw, glg, se) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'pizza vegan fantasy (1, glw)',
#  'tagesgericht: planted döner style teller (glw, glg, se, sf) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'campus welcome aktion vegan:indisches rosenkohl-curry mit kichererbsen und basmatireis',
#  'begrenztes angebot grünkohl vegan bratkartoffeln',
#  'veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) pommes fritiert',
#  'tagesgericht: pasta bolognese vegan (glw, glg, sl, so)',
#  'falafel teller mit salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) pommes frites zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'planted vegane currywurst',
#  'veganer chrunchy chick`n burger, (glw, glg, gld, sf, so) gemüsesticks & pommes fritiert (1, glw)',
#  'pasta bar: pasta, fruchtige gemüsesoße, veganer käse (1, 2, 3, 4, glw, glg, mi, so)',
#  'planted.bratwurst vegane stampfkartoffeln (1) kaisergemüse senfsoße (glw, sf)',
#  'chicken schnitzel paniert vegan (glw) curry- kokos- soße (3) broccoli reis',
#  'vegane paella, artischocken, paprika',
#  'bunte pommes mischung, maniok, süßkartoffel (1) tomatensalsa (sw) wasabi veganese (3, 5, sf, so, sw) vegane mayonnaise, melone, chili (sf, so)',
#  'falafel teller mit salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) kartoffelspalten (glw)',
#  'vegane bratwurst currysoße pommes frites',
#  'holsteiner vegane kartoffelsuppe baguettebrot',
#  'pasta bolognese vegan(glw, sl, so)',
#  'vegane bratwurst zum eintopf',
#  'pulled jackfruit burger, dinkel-vollkorn-bun, rotkraut, vegane cocktailsauce kartoffelspalten vegane mayonnaise',
#  'pasta bar (1, 2, glw, glg, mi, so) soße al arrabiata vegan (1, 2, 6, sl) schinkensoße (2, 3, 4, mi)',
#  'veganer burger im menü mit fritz 0,33l falafel burger, soja-paprika-dip, tomate, gurke, salat, frittierte kartoffeln (glw, gld, sf, so)',
#  'begrenztes angebot; wechselnde auswahl (giw, 3, so, sf) "almost chicken" nuggets, kartoffelspalten, cocktailsoße vegan',
#  'vegane bratwurst',
#  'börek, spinatfüllung (glw) veganese (sf, so) bulgur [bio] (glw)',
#  'vegane bratwurst mit salat, (3, 5, sl, so, sw) veganer tzatziki (3, sf, so) pommes frites',
#  'fischnuggets (fi, glw, sf) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'pasta bar, täglich wechselndes angebot (glw, mi) tomatensoße mit speckwürfel (2, 3, 4, mi) vegane kürbisrahm- soße mit gerösteten kürbiskernen (en, so)',
#  'tagesgericht vegane nuggets (glw) veganer kartoffelsalat (sf)',
#  'bunter veganer grünkohltopf (sf) auf wunsch mit kochwurst und schweinenacken (2, 3, 4, 8, 10, sf, sl) baguettebrot (glw)',
#  'pasta mit rindfleischbolognese oder veganer bolognese 3,50 €',
#  'lahmacun vegan - türkische pizza mit frischen salaten, kräutern und chilisoße (glw, so)',
#  'vegane currywurst (sl, so)',
#  'vegane bratwurst (sl, so) currysoße (3, sl) pommes frites',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, glw, gld, sf, so) kartoffelspalten',
#  'begrenztes angebot: mie nudeln, bambussprossen, paprika, frühlingszwiebeln knusprige vegane ente',
#  'campus welcome aktion vegan: indisches rosenkohl-curry mit kichererbsen und basmatireis',
#  'veganuary: planted.pulled bbq burger, smoked remoulade (8, glw, glh, gld, sf, so) frittierte kartoffeln',
#  'veganes geschnetzeltes "züricher art" (mi, sf) spätzle (ei, glw)',
#  'jackfruit burger kartoffelspalten vegane mayo ohne ei',
#  'holsteiner vegane kartoffelsuppe',
#  'begrenztes angebot vegane bratwurst',
#  'nudelauflauf, brokkoli, champignons, vegane käsekruste (1, 2, glw, glh)',
#  'planted vegane currywurst, pommes frites',
#  'veganuary: p.h.d. - planetary health dog (8, glw, sf, sl, so) laugenbrötchen, planted. bratwurst, peperoni, tomate, röstzwiebelmayo',
#  'tagesgericht: lahmacun vegan - türkische pizza mit frischen salaten, kräutern und chilisoße (glw, so)',
#  'jackfruit burger kartoffelspalten veganese',
#  'veganer nudelauflauf (1, 2, 3, 4, glw, glg, mi, so)',
#  'veganer onion- burger, (glw, glg, gld, sf, so) pommes',
#  'jackfruit burger, vegane cocktailsoße (3, glw, gld, sf, so) kartoffelspalten',
#  'vegane bratwurst (sl, so)',
#  'nudelgratin, brokkoli, champignons, vegane käsekruste (1, 2, glw)',
#  'bunte pommes mischung (1) guacamole (so) tomatensalsa (sw) wasabi veganese (3, sf, so)',
#  'currywurst vegan hot pot(t) (2, 3, sf, sl, so) karamellisierte balsamico zwiebeln (1, 3, 5, sw) gitterkartoffeln (glw)',
#  'planted döner style teller (glw, glg, se, sf) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'begrenztes angebot currywurst vegan (2, 3, sf, sl, so) basmatireis',
#  'pasta bar, täglich wechselndes angebot pasta, basilikumpesto,tomatenwürfel, veganer reibekäse (1, 2, 3, 5, glw, nw, sw) orientalischer nudelauflauf, linsen, dattel, käsekruste (ei, glw, mi, sl)',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, glw, glr, glg, glh, gld, se, sf, sl, so) kartoffelspalten',
#  'veganissimo! bunte pommes mischung guacamole tomatensalsa wasabi veganese',
#  'tagesgericht planted döner style teller (glw, glg, se) veganer tzatziki (3, sf, so) vegane curry mayonnaise (sf, so)',
#  'begrenztes angebot nudelauflauf, brokkoli, champignons, vegane käsekruste (1, 2, glw, glh) tomatensoße',
#  'vegane erbsenbällchen, rucolapesto, vollkornreis (1, 2, 4, glw, glg, so)',
#  'campus welcome aktion vegan: bibimbap bowl - koreanische gemüsebowl mit reis und sojahack',
#  'planted vegane currywurst pommes frites',
#  'veganissimo: planted chicken softshell tacos, limette, avocado, koriander (glw, sf, so)',
#  'currywurst vegan hot pot(t) (2, 3, sf, sl, so) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten',
#  'begrenztes angebot hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) veganer -dip (3, sf, so) kartoffelspalten',
#  'vegane ente orangensoße kroketten',
#  'veganes knusperfilet (glw) remouladensoße (3, 8, ei, glw, mi, sf, sl) kartoffelspalten',
#  'bibimbap bowl vegan',
#  'pasta bolognese vegan (glw, glg, sl, so)',
#  'grünkohl (2, 3, 4, sf) röstkartoffeln, vegan oder auf wunsch mit speckstippe',
#  'vegane ofenkartoffel, tomaten- zwiebel- marmelade',
#  'veganer backfisch (glw) erbsen-gurken-dip (3, ei, glw, sl) kartoffelspalten',
#  'jackfruit [bio] burger, vegane cocktailsoße (3, glw, gld, sf, sl, so) gitterkartoffeln (glw)',
#  'falafel teller mit salat, (3, 5, glw, sl, sw) veganer tzatziki (3, sf, so) pommes frites',
#  'begrenztes angebot hähnchenschnitzel cordon bleu (1, 2, 3, 10, 12, glw, mi) vegane cocktailsauce (3, sf, so) kartoffelspalten',
#  'veganer chrunchy chick`n burger, (glw, gld, sf, so) kartoffelspalten',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw) soja-bolognese, gemüse (glg, sl, so) curry- kokos- soße,tofu (3, so)',
#  'ma po tofu',
#  'börek, spinatfüllung tofunese holsteiner mixsalat',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (1, 2, 4, en, glw, so)',
#  'ofenkartoffel karotten-mango-konfit tofunese',
#  'bratnudeln, tofu [bio], chili, wokgemüse (2, en, glw, sl, so)',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, so)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, so)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (2, en, glw, sf, sl, so)',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, se, so)',
#  'ofenkartoffel tomaten- zwiebel- marmelade tofunese',
#  'ofenkartoffel karotten- mango- konfit (1, 3, sw) tofunese (3, 6, sf, so)',
#  'begrenztes angebot: wechselnde auswahl indisches rosenkohlcurry mit tofu und duftreis (so, glw)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, se, so)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (2, en, glw, so)',
#  'tofu (bio)- bällchen, kapernsauce, (1, 10, glw, glg, sf, so) salzkartoffeln',
#  'begrenztes angebot; wechselnde auswahl (1, 2, 4, en, giw, so) bratnudeln mit tofu, chili und wokgemüse',
#  'geräuchertes tofusteak, ratatouille, kräuter-vollkornreis, weintrauben',
#  'gebackene ofenkartoffel, tofunese, mango-sellerie-konfit',
#  'kalter glasnudelsalat mit wakame und sesam-tofu (1, glw, se, so)',
#  'gebackene ofenkartoffel mit tofunese (6, so, sf) und chili sin carne',
#  'ofenkartoffel karotten- mango- konfit tofunese (6, sf, so)',
#  'bun chay vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (2, en, glw, se, sl, so)',
#  'chilli fries sin carne (sl) tofunese (3, 6, sf, so)',
#  'pastinaken- tofu (bio) -ragout, hirse (glw, so, sw)',
#  'tofu (bio), knoblauch- chili- sud, wokgemüse, mie-nudeln',
#  'chilli fries sin carne (2, 6, sl) tofunese (6, sf, so)',
#  'chilli fries sin carne tofunese',
#  'gebackene ofenkartoffel mit tofunese und chili sin carne',
#  'vn chilli fries sin carne vn tofunese (6, sf, so)',
#  'bun chay - vietnamesische mienudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, sf, so)',
#  'ofenkartoffel karotten- mango- konfit (1, 3, sw) tofunese (6, sf, so)',
#  'topped fries, linsensalat, olivensalat tofunese (6, sf, so)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, sl, so)',
#  'bun chay (1, 2, 4, en, glw, so, sw) vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'begrenztes angebot: wechselnde auswahl (2, en, giw, so) scharfe erdnuss- reisnudeln mit tofu (2, en, giw, so)',
#  'bun chay - vietnamesische mie-nudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, so)',
#  'scharfe erdnuss-nudeln mit tofu (2, en, glw, se, so)',
#  'protein power tofu bällchen salzkartoffeln kapernsoße',
#  'tofu klopse kapernsauce, salzkartoffeln',
#  'chilli fries sin carne (3) tofunese (6, sf, so)',
#  'chili con quinoa tofunese (6, sf, so)',
#  'begrenztes angebot tofu [bio], wokgemüse, mie-nudeln (en, glw, so) curry- kokos- soße (3)',
#  'chilli fries sin carne tofunese (3, sl, 6, sf, so)',
#  'bun chay (1, 2, 4, en, glw, so, se) vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'tofu, knoblauch- chili- sud, wokgemüse, mie-nudeln',
#  'gebackener tofu ,gemüse-mienudeln,soja-kokossauce',
#  'scharfe erdnuss bratnudeln mit tofu (2, en, glw, so)',
#  'tofu , knoblauch- chili- sud, wokgemüse, mie-nudeln',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (en, glw, nmn, nh, nw, nc, so)',
#  'pasta bar, täglich wechselndes angebot bratnudeln, bambussprossen, tofu, (glw, nc, so)',
#  'tofu [bio], knoblauch- chili- sud, wokgemüse, mie-nudeln (2, en, glw, sl, so)',
#  'chilli fries sin carne tofunese (3, 6, sf, so)',
#  'gemüse- couscous- pfanne, tofu',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (en, glw, so)',
#  'scharfe erdnuss mienudeln mit tofu (2, en, glw, so)',
#  'tofu in rahm, champignons ,erbsen, karotten, spargel reis',
#  'tofu',
#  'pastinaken- tofu (bio) -ragout, hirse',
#  'scharfe erdnuss reisnudeln mit tofu (2, en, glw, so)',
#  'tofu süss scharf pfannengemüse basmatireis',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (2, en, glw, so)',
#  'geräuchertes tofusteak',
#  'bratnudeln, zuckerschoten, cashewkerne, basilikum, tofu (2, en, glw, nc, se, sl, so)',
#  'ofenkartoffel karotten- mango- konfit tofunese',
#  'pastinaken- tofu',
#  'begrenztes angebot bun chay vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'pastinaken- tofu - ragout, hirse',
#  'spicy potatoes mit tomatisierten kichererbsen, rucola und tofu-dip (so)',
#  'tofu salzkartoffeln',
#  'ofenkartoffel karotten- mango- konfit (sw) tofunese (6, sf, so)',
#  'begrenztes angebot pasta bar tofu , wokgemüse, mie-nudelnauflauf',
#  'kürbissuppe, ingwer, tofu, croutons (glw, so) baguettebrot (glw)',
#  'begrenztes angebot: ofenkartoffel tomaten- zwiebel- marmelade karotten- mango- konfit tofunese',
#  'pasta bar, täglich wechselndes angebot bratnudeln, gemüse (glw, nc, so) soja-chillisoße (2, glw, so) pasta, tofu-bolognese (glw, so)',
#  'bun chay - vietnamesische mienudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, so)',
#  'geräuchertes tofusteak, ratatouille, kräuter-vollkornreis, apfel',
#  'bun chay (1, 2, 4, en, glw, so) vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'tofu - bällchen, tomatensoße salzkartoffeln',
#  'begrenztes angebot: wechselde auswahl mie-nudeln mit gemüse und mariniertem tofu - chili und knoblauch',
#  'rezepte duell! - scharfe erdnuss bratnudeln mit tofu (2, en, glw, so)',
#  'ofenkartoffel tomaten- zwiebel- marmelade karotten- mango- konfit tofunese',
#  'borschtsch, weißkohl, rote beete, räuchertofu, schmand',
#  'chilli fries sin carne tofunese (6, sf, so, sl, nw)',
#  'spicy potatoes mit tomatisierten kichererbsen, rucola und tofu-dip',
#  'scharfe erdnuss reisnudeln mit tofu (1, 2, 4, en, glw, sl, so)',
#  'geräuchertes tofusteak mit ratatouille und kräuter-vollkornreis',
#  'beijing suppe - sauer-scharfe-suppe,, jackfruit [bio], geräucherter tofu (3, glw, se, so) baguettebrot (glw)',
#  'glasnudelsalat mit wakame und sesam-tofu (1, glw, se, so)',
#  'begrenztes angebot pasta bar nudeln asiatisches tofu-jackfruit ragout',
#  'chilli fries sin carne tofunese (6, sf, so)',
#  'süßsauere tofupfanne, ananas, frühlingzwiebeln',
#  'adas polo - iranisches reisgericht linsen, datteln, rosinen, mandeln (nmn)',
#  'grünes- kokos- gemüse- curry, basmatireis (so)',
#  'soja- gyrospfanne, paprika, zucchini gremolata djuvec reis',
#  'welsfilet gebraten (fi, glw) knoblauch, chili, wokgemüse, reisnudeln (2, en, glw, se, sl, so)',
#  'putenschnitzel paniert (glw) curry- kokos- soße (3) broccoli reis zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'grünes- kokos- gemüse- curry (so) basmatireis',
#  'tex-mex reis (glw, so) vn tomatensalsa wvt (sw)',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, so)',
#  'limited edition reispfanne süß- scharfe putenbrust pflaume erdnuss',
#  'zu jedem wechselnden tagesgericht gibt es ein sinalco-getränk zum aktionspreis von 1,00€ dazu !! wir freuen uns auf euch',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (1, 2, 4, en, glw, se, so)',
#  'reispfanne ratatouille',
#  'burger mit fritz nach wahl zum aktionspreis von 1,40 € dazu !!',
#  'adas polo - persisches reisgericht mit linsen, datteln, rosinen',
#  'begrenztes angebot: wechselnde auswahl indisches rosenkohlcurry mit tofu und duftreis (so, glw)',
#  'sojastreifen in rahm, champignons basmatireis',
#  'reispfanne (en, glw, se, so)',
#  'zu jedem wechselnden tagesgericht gibt es ein fritz-getränk zum aktionspreis von 1,20 € dazu !! wir freuen uns auf euch',
#  'geräuchertes tofusteak, ratatouille, kräuter-vollkornreis, weintrauben',
#  'kidneybohnen ragout, linsen, datteln, rosinen, mandeln, basmatireis (1, nmn, sf)',
#  'putensteak (sl) cherry-tomatensoße basmatireis',
#  'bun chay vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'seehecht, blattspinat, mozzarella, mandeln, tomaten-vollkornreis',
#  '" schmaler taler - teller " (glw) pasta, ratatouille jeden tag ein preiswertes gericht solange der vorat reicht',
#  'putengeschnetzeltes, currysoße, paprika, karotten, reis',
#  'rotes putencurry, kokos, karotten, koriander, erdnuss (2, en, sf) basmatireis',
#  'begrenztes angebot: wechselnde auswahl indisches kidneybohnen-curry mit vollkornreis',
#  'paella, vollkornreis, artischocken, paprika',
#  'adas polo - iranisches reisgericht mit linsen, datteln, rosinen, mandeln iranisches reisgericht linsen, datteln, rosinen, mandeln',
#  'adas polo- iranisches reisgericht linsen, datteln, rosinen, mandeln, (nmn)',
#  'hühnerfrikassee reis',
#  'tomatisiertes linsen- gemüse (sl) basmatireis',
#  'bratreis, zucchini, paprika, kreuzkümmel, mandeln sojasoße',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, reisnudeln, koriander (glw, sl) baguettebrot (glw)',
#  'begrenztes angebot adas polo - iranisches reisgericht linsen, datteln, rosinen, mandeln (nmn)',
#  'börek, spinatfüllung (glw) paprika-tomatensoße reis',
#  'knusperschnitte hong kong (glw, gld, sf, sl) zwiebel -kräutersoße reis',
#  'jackfruit bowl karotten, mango, limette, reis',
#  'sojastreifen in rahm, champignons, erbsen, karotten, spargel reis',
#  'zu jedem wechselnden tagesgericht gibt es ein fritz-getränk zum aktionspreis von 1,20€ dazu !! wir freuen uns auf euch',
#  'chili sin carne basmatireis',
#  'adas polo - iranisches reisgericht linsen, datteln, rosinen, mandeln (nmn, sf)',
#  'zu jedem wechselnden tagesgericht gibt es ein sinalco-getränk zum aktionspreis von 1,10€ dazu !! wir freuen uns auf euch',
#  'adas polo- iranisches reisgericht linsen, datteln, rosinen, mandeln',
#  'knusperschnitzel, chili-sud, salat (glw, gld, so) reis (glw)',
#  'bun chay (1, 2, 4, en, glw, so, sw) vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'hühnersuppe, zitrone, spinat, reis baguettebrot',
#  'putenschnitzel paniert (glw) curry- kokos- soße broccoli reis',
#  'begrenztes angebot: wechselnde auswahl (2, en, giw, so) scharfe erdnuss- reisnudeln mit tofu (2, en, giw, so)',
#  'kichererbsen-gemüsepfanne curry- kokos- soße reis',
#  'entenragout, wokgemüse,pilze, reis (sw)',
#  'basmatireis rote- linsengemüse ragout (glw, sl)',
#  'bratreis, zucchini, paprika, kreuzkümmel, mandeln (nmn)',
#  'sojageschnetzeltes - thailändisch - (3, so, sw) reis',
#  'jackfruit bowl brechbohnen, mango, limette, reis',
#  'bun chay (1, 2, 4, en, glw, so, se) vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'gemüseschnitzel (glw, sf, sl) soja -gemüsesoße (glw, so) basmatireis',
#  'falafel (glw, sl) persischer reis (se) pfirsich- tomaten- marmelade (1, 2, 3, 5, sw)',
#  'begrenztes angebot sojastreifen in rahm, champignons ,erbsen, karotten, spargel reis',
#  'adas polo - persisches reisgericht mit linsen, datteln, rosinen (nmn)',
#  'bratreis, zucchini, paprika, kreuzkümmel, mandeln (nmn, sl)',
#  'grünes- kokos- gemüse- curry (so) reis',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (en, glw, so)',
#  'reis, tomaten- kichererbsen- linsenragout (se)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, so) kartoffelspalten zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'tofu in rahm, champignons ,erbsen, karotten, spargel reis',
#  'puten-piccata milanese cherry-tomatensoße gemüsereis',
#  'putengeschnetzeltes, kokos, karotte, basmatireis (1)',
#  'gemüseschnitzel (glw, sf, sl) grüne- thai- kokos- soße basmatireis',
#  'sojageschnetzeltes, waldpilzen reis',
#  'scharfe erdnuss reisnudeln mit tofu (2, en, glw, so)',
#  'protein power süß- scharfe putenbrust pflaume erdnuss basmatireis',
#  'putenschnitzel paniert (glw) cherry-tomatensoße basmatireis',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel reis',
#  'hühnersuppe, zitrone, erbsen, reis',
#  'grünes- kokos- gemüse- curry basmatireis',
#  'tofu süss scharf pfannengemüse basmatireis',
#  'bun chay - vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander (2, en, glw, so)',
#  'jackfruit bowl mango, limette, reis',
#  'putensteak curry- kokos- soße (3) broccoli reis',
#  'putensteak cherry-tomatensoße reis',
#  'chili sin carne vollkornreis',
#  'begrenztes angebot ente süß- sauer reis',
#  'putensteak tomatensoße basmatireis',
#  'sojawürfel in rahm, champignons ,erbsen, karotten, spargel reis',
#  'begrenztes angebot kidneybohnen ragout, linsen, datteln, rosinen, mandeln, basmatireis (1, nmn, sf)',
#  'chili sin carne reis',
#  'putensteak cherry-tomatensoße basmatireis',
#  'bratreis, gemüse, kreuzkümmel, mandeln',
#  'begrenztes angebot falafel (glw) persischer reis (se) pfirsich- tomaten- marmelade (1, 2, 3, 5, sw)',
#  'cubanischer schwarzer reis mit chillihänchen',
#  'sabsi - indisches rosenkohl curry mit kichererbsen und basmatireis',
#  'reispfanne, wirsing, paprika, karotten, kichererbsen, mandeln (nmn)',
#  'begrenztes angebot bun chay vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen basmatireis',
#  'pasta bar, täglich wechselndes angebot reis weisses bohnen-gulasch',
#  'adas polo iranisches reisgericht linsen, datteln, rosinen, mandeln',
#  'zu jedem wechselnden tagesgericht gibt es ein fritz-getränk zum aktionspreis von 1,40€ dazu !! wir freuen uns auf euch',
#  'adas polo- iranisches reisgericht linsen, datteln, rosinen, mandeln iranisches reisgericht linsen, datteln, rosinen, mandeln',
#  'pulled duck burger, rotkrautsalat, rucola, preiselbeer dip (3, glw, gld, se, sf, so) pommes frites',
#  'rajma dal - indisches kidneybohnen-curry (1) vollkornreis',
#  'adas polo- iranisches reisgericht linsen, datteln, rosinen, mandeln (nmn)',
#  'jackfruit bowl zuckerschoten, ananas, limette, reis',
#  'beijing suppe (3, glw, se, so, sw) sauer-scharfe-suppe, mu err pilze, jackfruit, reisbandnudeln',
#  'beijing suppe - sauer-scharfe-suppe, mu err pilze, jackfruit [bio], reis (3, glw, se, so) baguettebrot (glw)',
#  'adas polo - iranisches reisgericht linsen, datteln, rosinen, mandeln (nmn) iranisches reisgericht linsen, datteln, rosinen, mandeln',
#  'falafel (glw) persischer reis (2, 5, se) pfirsich- tomaten- marmelade (1, 2, 3, 5, sw)',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen, basmatireis',
#  'pikante sesamnudeln, asiatisches pfannengemüse (en, glw, se, so) zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'falafel (glw) persischer reis (se) pfirsich- tomaten- marmelade (1, 2, 3, 5, sw)',
#  'begrenztes angebot reisbandnudeln mit sauer-scharfe-soße, mu err pilze, jackfruit [bio] (3, glw, se, so)',
#  'reispfanne, zucchini, paprika, karotten, kichererbsen, mandeln (nmn)',
#  'gemüseschnitzel (glw, gld, sl) zwiebel -kräutersoße reis',
#  'bratreis, zucchini, paprika, kreuzkümmel, mandeln',
#  'begrenztes angebot adas polo - iranisches reisgericht linsen, datteln, rosinen, mandeln (nmn, sf)',
#  'falafel (glw) persischer reis (nmn, se) pfirsich- tomaten- marmelade (1, 2, 3, 5, sw)',
#  'falafel (glw) tomaten- minzsugo basmatireis',
#  'geräuchertes tofusteak, ratatouille, kräuter-vollkornreis, apfel',
#  'sojastreifen in rahm, champignons ,erbsen, karotten mit reis',
#  'putenschnitzel paniert (glw) curry- kokos- soße (3) broccoli reis',
#  'bun chay (1, 2, 4, en, glw, so) vietnamesische reisnudel bowl, tofu, eisbergsalat, gurke, apfel, erdnüsse, koriander',
#  'jackfruit-bowl, jackfruit, zuckerschoten, mango, limette, reis (3, glw, nc, se, so)',
#  'zu jedem wechselnden tagesgericht gibt es ein fritz-getränk zum aktionspreis dazu !! wir freuen uns auf euch',
#  'cevapcici mit tsatsiki und reis 3,50 €',
#  'scharfe erdnuss reisnudeln mit tofu (1, 2, 4, en, glw, sl, so)',
#  'geräuchertes tofusteak mit ratatouille und kräuter-vollkornreis',
#  'chili sin carne mit basmatireis und quinoa',
#  'orientalisches gemüseragout, sojastreifen (so) basmatireis',
#  'putengeschnetzeltes, kokos, karotte, basmatireis',
#  'gemüseschnitte hongkong (glw, sf, sl) curry- kokos- soße, gemüse (so) reisnudeln',
#  'putenschnitzel paniert (glw) curry- kokos- soße (3) gemüse reis',
#  'reis, ofengemüse, kreuzkümmel, mandeln',
#  'reis- bowl - spinat-hummus, brokkoli, karotten, ingwer, mandeln (nmn, nc, se)',
#  'reisnudelpfanne, gemüse, erdnuss (nmn, em, giw)',
#  'begrenztes angebot: grünes- kokos- gemüse- curry, basmatireis (so)',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel gemüsereis',
#  'adas polo (nmn) iranisches reisgericht linsen, datteln, rosinen, mandeln',
#  'jackfruit bowl zuckerschoten, mango, limette, reis',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen reis',
#  'zu jedem wechselnden tagesgericht gibt es ein fritz-getränk zum aktionspreis 1,20 € dazu !! wir freuen uns auf euch',
#  'zu jedem wechselnden tagesgericht gibt es ein mio-getränk zum aktionspreis von 1,20€ dazu !! (1) wir freuen uns auf euch',
#  'chili sin carne reisnudeln[bio] (glw)',
#  'putengeschnetzeltes mit sojasoße und gemüse (glw, so) basmatireis',
#  'süßkartoffel- kokos- soja- curry, reis',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, sl, so) kartoffelspalten',
#  'walnuss-brokkoli-wok mit orangen-soja-soße und mienudeln (glw, so, nw)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw) soja-bolognese, gemüse (glg, sl, so) curry- kokos- soße,tofu (3, so)',
#  'süßkartoffel- kokos- soja- curry, bulgur [bio] tomatisiert (glw, so)',
#  'soja- gyrospfanne, paprika, zucchini gremolata djuvec reis',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel (glh, so) risi bisi (1)',
#  'süßkartoffel- kokos- soja- curry, bulgur',
#  'soja-bolognese (glg, so) bandnudeln (glw)',
#  'begrenztes angebot süßkartoffel- kokos- soja- curry, bulgur (bio) tomatisiert',
#  'begrenztes angebot kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot (glw, glr, so)',
#  'tagesgericht falafel burger, soja-paprika-dip, tomate, gurke, salat (glw, gld, sf, sl, so)',
#  'gemüse- burger, soja- chili- dip, tomate, gurke, rucola kartoffelspalten',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrötchen',
#  'begrenztes angebot süßkartoffel- kokos- soja- curry, bulgur(bio) tomatisiert',
#  'schupfnudeln, schmorgemüse sojasoße',
#  'sojastreifen in rahm, champignons basmatireis',
#  'pasta (glw) soja-bolognese (glw, so, sl)',
#  'begrenztes angebot pasta bar nudeln soja-bolognese',
#  'begrenztes angebot pasta bar nudelauflauf mit soja-bolognese',
#  'jackfruit [bio] burger, soja-mayonnaise (3, glw, gld, sf, so) kartoffelspalten',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, so) kartoffelspalten',
#  'pasta (glw) mit soja-bolognese (glw, sl, so)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, sl, so, 3) kartoffelspalten (glw)',
#  'quinoa chilli burger mit soja-chili-dip, tomate, gurke, rucola (glw, glh, gld, sf, so)',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, mienudeln (1, 2, 4, glw, glg, so)',
#  'begrenztes angebot pasta bar nudeln soja frikassee',
#  'green hero oat burger mit soja-chili-dip, tomate, gurke, rucola (glw, glh, gld, sf, so)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat country steak frites',
#  'puten- burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, so) kartoffelspalten',
#  'bratnudeln,entemnbruststreifen, zuckerschoten, cashewkerne, basilikum sojasoße',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot (glw, glr, so)',
#  'pasta (glw) soja-bolognese (glg, so)',
#  'falafel burger mit soja-paprika-dip, tomate, gurke, salat und süßkartoffelpommes',
#  'begrenztes angebot: bratnudeln, knusprige ente, gemüse, basilikum sojasoße',
#  'bratreis, zucchini, paprika, kreuzkümmel, mandeln sojasoße',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, sl, so) country steak frites (glw)',
#  'pasta (glw) soja-bolognese "asia styl" (glw, so)',
#  'sojastreifen in rahm, champignons, erbsen, karotten, spargel reis',
#  'falafel burger mit soja-paprika-dip, tomate, gurke, salat',
#  'kartoffel- erbsen-paprikaeintopf, sojarahm, koriander, minze, brötchen (glw, glr, so)',
#  'süßkartoffel- kokos- soja- curry, bulgur(bio) tomatisiert',
#  'pasta (glw) soja-bolognese (glw, sl, so)',
#  'tagesgericht falafel burger, soja-paprika-dip, tomate, gurke, salat (glw, gld, sf, so)',
#  'falafel burger mit soja-paprika-dip, tomate, gurke, salat 3,90€',
#  'begrenztes angebot sojastreifen in rahm, champignons ,erbsen, karotten (1, glh, sf, so) couscous (glw)',
#  'begrenztes angebot pasta bar nudeln würzige thai-soja-bolognese',
#  'viertel barberie-ente gemüse, woknudeln sojasoße',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel (1, glh, sf, so) couscous (glw)',
#  'pasta (glw) soja-bolognese (glg, sl, so)',
#  'soja-bolognese (glg, sl, so) gabelspaghetti (glw)',
#  'falafel bratling, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, sl, so) kartoffelspalten',
#  'bratnudeln, zuckerschoten, cashewkerne, basilikum 3,50€ sojasoße',
#  'pasta (glw) soja-bolognese (glw, so, sw)',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot (glw, glr, sl, so)',
#  'sojageschnetzeltes - thailändisch - (3, so, sw) reis',
#  'phat krapao würzige thai-soja-bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln',
#  'gemüseschnitzel (glw, sf, sl) soja -gemüsesoße (glw, so) basmatireis',
#  'bratnudeln, zuckerschoten, cashewkerne, basilikum sojasoße',
#  'tagesgericht green hero oat burger mit soja-chili-dip, tomate, gurke, rucola (glw, glh, gld, sf, so)',
#  'soja-bolognese pasta',
#  'gebackener tofu ,gemüse-mienudeln,soja-kokossauce',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, pasta (1, 2, 4, glw, glg, so)',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (glw, glg, sl, so)',
#  'heute nur bis 13:00 uhr geöffnet pasta soja-bolognese (glw, so)',
#  'tagesgericht: green hero oat burger mit soja-chili-dip, tomate, gurke, rucola + wedges 2,00 € (glw, glh, gld, sf, so)',
#  'begrenztes angebot sojastreifen in rahm, champignons ,erbsen, karotten, spargel reis',
#  'quinoa-burger mit soja-chili-dip, tomate, gurke, rucola kartoffelspalten',
#  'tagesgericht: burger im menü mit fritz 0,33l green hero oat burger mit soja-chili-dip, tomate, gurke, rucola (glw, glh, gld, sf, so) ... mit pommes frites',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (3, glw, glr, glg, glh, gld, se, sf, sl, so) country steak frites (glw)',
#  'begrenztes angebot: würzige thai-soja-bolognese, ingwer, koriander, limettenblätter, spaghetti',
#  'begrenztes angebot pasta bar nudeln sojastreifen in rahm, champignons',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, baguettebrötchen (glw, so)',
#  'pasta bar, in selbstbedienung soja-bolognese (glw, so) spiralnudeln (glw) im menü mit mio ginger + 1,30 € zzgl. pfand',
#  'hakuna batata gelbes soja- curry tomatisierter couscous, liebe (glw, so)',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, baguettebrötchen (glw, glr, so)',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel (1, glh, sf, so) risi bisi (1)',
#  'begrenztes angebot pasta bar soja-bolognese',
#  'pikante soja-bolognese, oliven (1, 2, 6, glg, sl, so) pasta (glw)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, so) kartoffelspalten zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot (3, 5, glw, glr, so, sw)',
#  'kartoffelsuppe, erbsen, sojarahm (3, 5, sf, sl, so, sw) baguettebrot (glw)',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot (glw, glr, sf, so)',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (1, 2, 4, glw, glg, so) würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln',
#  'begrenztes angebot nudeln sojawürfel in rahm, champignons ,erbsen, karotten, spargel',
#  'soja-bolognese (sl, so) bandnudeln (glw)',
#  'letzter tag - heute nur bis 13:30 geöffnet pasta (glw) soja-bolognese (glg, so)',
#  'pasta (glw) soja-bolognese (glw, so)',
#  'sojageschnetzeltes, waldpilzen reis',
#  'begrenztes angebot nudeln sojastreifen in rahm, champignons ,erbsen, karotten, spargel',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot (glw, glr, glg, glh, se, so)',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel reis',
#  'kichererbsen-tomaten-sojastreifen pfanne, spiralnudeln',
#  'schupfnudeln, schmorgemüse, sojasoße sojasoße',
#  'falafel burger, soja-paprika-dip, tomate, gurke, salat kartoffelspalten',
#  'soja bolognese quinoa baguettebrot',
#  'schupfnudeln, schmorgemüse, sojasoße (2, glw, se, so)',
#  'spiralnudeln (glw) soja-bolognese (glg, so)',
#  'falafel burger, soja-paprika-dip, tomate, gurke, salat (glw, gld, sf, sl, so)',
#  'pasta (glw) soja-bolognese (glw, so, 6, sw)',
#  'tagesgericht: green hero oat burger mit soja-chili-dip, tomate, gurke, rucola (glw, glh, gld, sf, so) pommes frites',
#  'pasta bar, täglich wechselndes angebot penne, blumenkohl- soße, brokkoli, sojachunks',
#  'würzige thai-soja-bolognese, ingwer, koriander, limettenblätter, mienudeln (1, 2, 4, glw, so)',
#  'begrenztes angebot sojastreifen in rahm, champignons, erbsen, karotten (1, glh, sf, so) couscous (glw)',
#  'sojawürfel in rahm, champignons ,erbsen, karotten, spargel reis',
#  'pasta (glw) würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (1, 2, 4, glw, glg, so)',
#  'asia noodles mit gemüse, pilzen und gebackenem sojasteak',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat pommes frites',
#  'phat krapao - würzige thai- soja bolognese, ingwer, basilikum, koriander, nudeln (1, 2, 4, glw, glg, so)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, so) steakhouse fries',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, glr, glg, glh, gld, se, sf, sl, so) kartoffelspalten',
#  'würzige thai-soja-bolognese, ingwer, koriander, mienudeln',
#  'falafel burger, soja-paprika-dip, tomate, gurke, salat',
#  'tagesgericht: falafel burger, soja-paprika-dip, tomate, gurke, salat (glw, gld, sf, so)',
#  'begrenztes angebot falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, so) kartoffelspalten',
#  'pasta (glw) soja-bolognese (glg, sf, so, sw)',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot, (glw, glr, so)',
#  'pasta bar, in selbstbedienung chili con carne (2) soja-bolognese (glw, so) im menü mit mio ginger + 1,30 € zzgl. pfand',
#  'bratnudeln, frisches gemüse, knusprige entenstreifen sojasoße',
#  'pasta (glw, sl) mit soja-bolognese (glw, so)',
#  'phat krapao (1, 2, 4, glw, glg, so) würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln',
#  'pasta (glw, sl) soja-bolognese (glw, so)',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot, (glw, glr, glg, glh, se, so)',
#  'süßkartoffel- kokos- soja- curry, mie-nudeln',
#  'kartoffel- linseneintopf, sojarahm, koriander, minze, vollkornbrot',
#  'falafel burger, soja-paprika-dip, tomate, gurke, salat, (glw, gld, sf, sl, so)',
#  'ofenkartoffel sour creme soja- gyrospfanne, paprika, zucchini',
#  'walnuss-brokkoli-wok mit orangen-soja-soße und mienudeln',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (glw, glg, so)',
#  'pasta soja-bolognese',
#  'sojastreifen in rahm, champignons ,erbsen, karotten (1, glh, sf, so) couscous (glw)',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (1, 2, 4, glw, glg, so, se, en)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, sl, so) kartoffelspalten (glw)',
#  'pasta bar, täglich wechselndes angebot bratnudeln, gemüse (glw, nc, so) soja-chillisoße (2, glw, so) pasta, tofu-bolognese (glw, so)',
#  'pasta bar, in selbstbedienung soja-bolognese (glw, so) bunte spiralnudeln (glw) im menü mit mio ginger + 1,30 € zzgl. pfand',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrot',
#  'sojastreifen in rahm, champignons ,erbsen, karotten mit reis',
#  'quinoa-burger mit soja-chili-dip, tomate, gurke, rucola pommes frites',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat (glw, gld, sf, sl, so) gitterkartoffeln (glw)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat country steak frites, dazu eine fritz-getränke für nur 1,20 € pfand',
#  'falafel burger, soja-paprika-dip, tomate, gurke, salat (glw, gld, sf, so)',
#  'schupfnudeln, schmorgemüse, sojasoße',
#  'süßkartoffel- kokos- soja- curry, bulgur (bio) tomatisiert',
#  'falafel burger, soja-paprika-dip, tomate, gurke, salat (glw, gld, sf, sl, so) kartoffelspalten (glw)',
#  'pasta bar, täglich wechselndes angebot würzige thai soja bolognese, pasta (1, 2, 4, glw, glg, so)',
#  'orientalisches gemüseragout, sojastreifen (so) basmatireis',
#  'kartoffel- erbseneintopf, sojarahm, koriander, minze, vollkornbrötchen (glw, glr, glg, glh, se, so)',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (1, 2, 4, en, glw, glg, se, so)',
#  'kartoffel-erbseneintopf in sojarahm mit koriander und minze, dazu vollkornbrot',
#  'bunte spiralnudeln soja-bolognese',
#  'pasta (glw) soja-bolognese (1, 2, glg, so)',
#  'süßkartoffel- kokos- soja- curry mit tomatenbulgur (glw, sf, so)',
#  'falafel burger, soja- paprika- dip, tomate, gurke, salat kartoffelspalten',
#  'begrenztes angebot: kartoffel- erbseneintopf, sojarahm, koriander, minze, baguette (glw, so)',
#  'süßkartoffel- kokos- soja- curry, tomatenbulgur',
#  'phat krapao - würzige thai soja bolognese, ingwer, basilikum, koriander, limettenblätter, mienudeln (1, 2, 4, glw, glg, so)',
#  'quinoa- burger, soja- chili- dip, tomate, gurke, rucola kartoffelspalten',
#  'sojastreifen in rahm, champignons ,erbsen, karotten, spargel gemüsereis',
#  'quinoa- burger, soja- chili- dip, tomate, gurke, rucola gitterkartoffeln',
#  'pasta mit soja-gemüsesauce (glw) erbsen, mais, paprika (glw, so)',
#  'begrenztes angebot falafel burger, soja-paprika-dip, tomate, gurke, salat',
#  'würzige soja bolognese, sesam, asiagemüse (glw, glg, se, so) mie-nudeln (glw)',
#  'süßkartoffel- kokos- soja- curry, bulgur tomatisiert',
#  'würzige thai-soja-bolognese, ingwer, koriander, limettenblätter, mienudeln',
#  'pasta bar, täglich wechselndes angebot pasta (glw) soja-bolognese (glw, so)',
#  'quinoa-burger mit soja-chili-dip, tomate, gurke, salat und country steak frites',
#  'putengeschnetzeltes mit sojasoße und gemüse (glw, so) basmatireis',
#  'süßkartoffel- kokos- soja- curry, reis',
#  'bratnudeln, gemüse, basilikum sojasoße',
#  'pikante sesamnudeln, asiatisches pfannengemüse',
#  'begrenztes angebot pasta bar nudeln asiatisches entenbrustragout',
#  'pasta (glw) soja-bolognese "asia styl" (glw, so)',
#  'pikante sesamnudeln, asiatisches pfannengemüse (en, glw, se, so)',
#  'asiatische knusperschnitte soße kroketten',
#  'pikante sesamnudeln, asiatisches pfannengemüse (2, en, glw, se, so)',
#  'asia bowl, mie-nudeln, pak-choi, ingwer, koriander',
#  'asia-nudelsalat',
#  'asia noodles mit gemüse, pilzen und gebackenem sojasteak',
#  'asiasuppe " frühlingerwachen " mie-nudeln, pak choi baguettebrot',
#  'asiatischereintopf - , mu err pilze, weisskohl, jackfruit [bio], (3, glw, se, so)',
#  'pikante sesamnudeln, asiatisches pfannengemüse (en, glw, se, so) zu diesem tagesgericht gibt es ein ai:tea-getränk zum aktionspreis von 1,70€ dazu ! wir freuen uns auf euch',
#  'pikante sesamnudeln, asiatisches pfannengemüse (en, glw, nw, se, so)',
#  'asia bowl mie-nudeln, pak-choi, ingwer, koriander',
#  'begrenztes angebot pasta bar nudeln asiatisches tofu-jackfruit ragout',
#  'würzige soja bolognese, sesam, asiagemüse (glw, glg, se, so) mie-nudeln (glw)',
#  'bratnudeln, asia gemüse, cashewkerne, basilikum',
#  'pikante sesamnudeln, asiatisches pfannengemüse (1, 2, en, glw, se, so)']

# %%
print(len(nc_names))
nc_names
# Out:
# 1198
# {'frikadellen bowl',
#  'rote- linsen- suppe (sl)',
#  'begrenztes angebot pasta bar nudeln jackfruitragout',
#  'begrenztes angebot frischer stangenspargel hollandaise soße salzkartoffeln',
#  'begrenztes angebot planted.bratwurst paprika- maissoße (sl) salzkartoffeln gemüse',
#  'country- pfanne, falaffel, paprika kartoffel-rösti',
#  'puten-piccata milanese cherry-tomatensoße röstkartoffeln',
#  'grünkohleintopf mit kasseler (2, 8, 10, sf) baguettebrot (glw)',
#  'currywurst hot pot(t) (2, 3, 10, sf, sl) kartoffelspalten (glw)',
#  'tagliatelle, kürbis- ricotta- soße, walnüsse',
#  'quinoa bowl, spinat-hummus, brokkoli, karotten, ingwer, casshewkerne (nc, se)',
#  'italienischer nudelauflauf, champignons, mozzarella',
#  'curryhuhnsuppe, mandeln baguettebrot',
#  'quinoa [bio]- bowl (nc, se, sw) spinat-hummus, brokkoli, karotten, ingwer, casshewkerne',
#  'gebratener seehecht,eihülle, balsamicolinsen, kartoffelpüree',
#  'curry bowl',
#  'grünkohleintopf, kochwurst (1, 2, 3, 4, 8, 10, sf, sl) baguettebrot (glw)',
#  'grüner bohneneintopf baguettebrot',
#  'achtung! wegen umbauarbeiten bieten wir euch heute warme cafeteria angebote in der mensa . wir freuen uns auf euch',
#  'currywurst (10, sf)',
#  'begrenztes angebot rote- linsen- suppe (sl) baguettebrot (glw)',
#  'tortelloni spinat- quinoa mit cherrytomaten, rucola, sonnenblumenkernen (1, 2, glw)',
#  'bohnen- tomaten- suppe baguettebrot (glw)',
#  'bunte osteuropäische linsensuppe, baguettebrot (sl, sw, sf, giw)',
#  'tortellini, petersilienpesto',
#  'wurst zur suppe (2, 3, 4, 10)',
#  'spaghetti, tomaten- mango- linsenragout (glw)',
#  'weizenteigfladen, avocado, weißen bohnen, kürbis, mais (2, glw, so)',
#  'gemüsewrap (2, glw, sl) pommes frites',
#  'pasta, tomaten- mango- linsenragout (glw)',
#  'beijing suppe - sauer-scharfe-suppe, mu err pilze, jackfruit [bio] (3, glw, se, so) baguettebrot (glw)',
#  'avocado- pasta, kirschtomaten, pinienkerne (3, glw, sf, so)',
#  'zwiebel- bratling zum grünkohl',
#  'balila - libanesisches kichererbsengericht (se) naan brot (glw, so)',
#  'grünkohlpesto - pasta, kirschtomaten, pinienkerne, cashewnüsse (3, glw)',
#  'kartoffel-weiße bohnen ragout, rosmarin, kapern (8, sf, sl) baguettebrot (glw)',
#  'pimp my food: sauer-vleisch wrap, jackfruit, eisbergsalat, cocktailsauce, röstkartoffeln (2, 3, 8, glw, sf, so)',
#  'gnocchi, grünkohlpesto (glw)',
#  'currywurst, (10, sf), currysoße, (2, 3, sf, sl), pommes frites',
#  'chili sin carne bulgur',
#  'rajma dal - indisches bohnen-curry (1)',
#  'weizenteigfladen,brokkoli, weißen bohnen, kürbis, mais, (2, glw), tomatensalsa, (sw)',
#  'kartoffel-weiße bohnen eintopf (sl) baguettebrot (glw)',
#  'makkaroni- tomaten- auflauf, basilikumsoße',
#  'planted kebap (sl) ginger ale bbq sauce (sl) krautsalat pommes frites',
#  'kartoffel-rösti ratatouille',
#  'currywurst pommes und mehr findet ihr in der heißen ecke pommes frites und vieles mehr gibt es bei uns in der heissen ecke',
#  'currywurst, (10, sf), currysoße, (3, sl), pommes frites',
#  'bunte spiralnudeln bolognese soße',
#  'linseneintopf (sl, sw, 3, 5) baguettebrot (glw)',
#  'beijing suppe (3, glw, se, so) baguettebrot (glw) sauer-scharfe-suppe, mu err pilze, jackfruit, glasnudeln',
#  'ofenkartoffel sour creme',
#  'frikadelle jus kartoffelgratin',
#  'begrenztes angebot frikadelle überbacken pommes frites',
#  'kürbissuppe, ingwer, croutons baguettebrot',
#  'grünkohleintopf (1, glw, sf, so) baguettebrot (glw)',
#  'begrenztes angebot pasta bar nudeln paprika- oliven- soße',
#  'begrenztes angebot afrikanischer gemüseeintopf, erdnuss, weißkohl, mango (en, sf) baguettebrot (glw, glr)',
#  'kale pumpkin-bowl, grünkohl, kürbis, bulgur [bio], sonnenblumenkerne (glw)',
#  'curryhuhnsuppe, mandeln, pinienkerne baguettebrot',
#  'offenkartoffel mit sour creme 2,80€',
#  'begrenztes angebot chili sin carne baguettebrot (glw)',
#  'gemüsesuppentopf chinesische art (glw, se, sl, so) baguettebrot (glw)',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, glass-nudeln, koriander (glw, sl) baguettebrot (glw)',
#  'kichererbsen-tomaten-eintopf, pinienkerne baguettebrot',
#  'balila - libanesisches kichererbsengericht naan brot (glw, so)',
#  'steckrübeneintopf holsteiner art (sf, sl) baguettebrot (glw)',
#  'begrenztes angebot: kabeljau, blattspinat, tomatentagliatelle',
#  'chili con quinoa (2, glw, glr) roggenbrötchen (glw, glr)',
#  'phat thai - thailändisches nudelgericht mit spinat und tahin (en, glw, nc, se, so)',
#  'arabische kichererbsensuppe',
#  'afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf) baguettebrot (glw)',
#  'quinoa bowl mit spinat-hummus',
#  'mediterrane gemüse-suppe baguettebrot',
#  'winterminestrone, grünkohl, grana padano, quinoa (bio)',
#  'begrenztes angebot winterminestrone, grünkohl , quinoa',
#  'begrenztes angebot: wechselnde auswahl weizenteigfladen mit tomatensalsa (sw, 2, glw)',
#  'italienische pasta bowl mit salami, rauke, kirschtomaten, burrata',
#  'chili con couscous (2, giw)',
#  'steckrübeneintopf holsteiner art',
#  'gefülltes baguette pulled turkey mit spitzkohlsalat',
#  'würziger kaiserschmarrn, gemüse, emmentaler, schnittlauch-dip',
#  'pasta (glw) mangoldpesto (1, 2, sf)',
#  'rote- linsen- bolognese, mie-nudeln (en, sl)',
#  'pulled turkey burger (glw, gld) ...mit potatoe wedges + 2,00€',
#  'lauwarmer beluga linsen one pot, balsamico, rote beete, hokkaido (1, 3, 5, se, sf, sl, sw)',
#  'currywurst pommes frites currysoße',
#  'pasta al arrabiata (1, 2, 6, glw, sl)',
#  'wurst zum rübemus (2, 3, 4, 8, 10, sf, sl)',
#  'karotten- süßkartoffel- eintopf baguettebrot (glw)',
#  'pasta bar, täglich wechselndes angebot, paella, artischocken, paprika',
#  'country- pfanne, falaffel, paprika (glw, sl) kartoffelspalten paprika- maissoße (sl)',
#  'planted.pulled bbq burger, smoked remoulade (8, glw, glh, gld, sf, so) steakhouse fries',
#  'falfelbratling süßkartoffel- popcorn- stampf tomatensalsa rote- bete- hummus',
#  'limetten-pasta, champignons, erbsen- cashewkern- pesto',
#  'ofenkartoffel mit sour creme 2,80€',
#  'miso mienudeln, champignons, erdnüsse, pak choi, koriander (1, 2, 4, en, glw, sl, so)',
#  'bruderhahn bockwurst zum eintopf',
#  'steckrübeneintopf holsteiner art baguettebrot',
#  'goldbrauner brezelauflauf',
#  'kichererbsen-ananas-spinat-curry, kartoffel',
#  'limettenpasta, champignons, erbsen- cashewkern- pesto (glw, nw, nc)',
#  'tortellini tomatenbärlauchpesto rote- bete- hummus',
#  'chrunchy chick`n burger (glw, gld, sf, so) pommes',
#  'süßkartoffelpfanne, ingwer, cashewkerne (nc)',
#  'börek, spinatfüllung couscous tomaten- minzsugo',
#  'erbsen cashew curry',
#  'pasta (nc) grünkohlpesto',
#  'country- pfanne, falaffel, paprika kartoffelspalten',
#  'weizenteigfladen, avocado, weißen bohnen, kürbis, mais (2, 3, glw)',
#  'nudel- gemüse- suppe, petersilien gremolata (glw) baguettebrot (glw)',
#  'begrenztes angebot : chili con carne',
#  'ofenkartoffel tomaten- zwiebel- marmelade',
#  'campus welcome aktion: currywurst hot pot(t)',
#  'vollkornspaghetti (bio) rote- linsen- bolognese (glw, sl)',
#  'chrunchy chick`n burger, (glw, gld, so) pommes frites',
#  'hokkaido gebraten, gnocchi, kürbiskernöl feldsalatpesto',
#  'begrenztes angebot linseneintopf baguettebrot',
#  'nudelauflauf, brokkoli, champignons (1, 2, glw, glh)',
#  'limettenspaghetti (bio) champignons, erbsen- cashewkern- pesto (glw, nw, nc)',
#  'lahmacun türkische pizza (glw, so) tomatensalsa (sw)',
#  'vn jackfruit-bowl',
#  'kürbissuppe, ingwer, croutons (glw, sl) baguettebrot (glw)',
#  'begrenztes angebot pasta bar nudel - tomaten - auflauf',
#  'tortelloni spinat- quinoa mit cherrytomaten, rucola, sonnenblumenkernen',
#  'falafel-burger, spinatsalat, shitake-pilze, tomaten senf-walnuss-sauce pommes frites',
#  'paella, artischocken, paprika kürbispesto',
#  'würziger kaiserschmarrn, gemüse, emmentaler dip',
#  'unsere cafeteria hat ab 9:00 uhr mit brötchen, heissen getränken und vieles mehr für euch geöffnet.',
#  'begrenztes angebot: karotten- süßkartoffel- eintopf baguettebrot',
#  'bockwurst zum eintopf (2, 3, 4, 8, 10, sl)',
#  'bandnudeln in cherry-tomatensoße 2,30 € ... mit puten- piccata milanese 4,90 €',
#  'kartoffel-rösti gemüsepfanne',
#  'unsere cafeteria bietet ab 09:30 uhr belegte brötchen an.',
#  'pulled duck burger (glw, gld) kartoffelspalten',
#  'süßkartoffel-amaranth-burger senf-walnuss-dip pommes frites',
#  'currywurst hot pot(t) karamellisierte balsamico zwiebeln ofenkartoffeln',
#  'auberginenauflauf, cashew creme überbacken (glw, nc)',
#  'spiralnudeln (glw) rucolapesto',
#  'bohnen- tomaten- suppe (sw) baguettebrot (glw)',
#  'grünkohleintopf, kochwurst',
#  'chili con carne (giw)',
#  'weizenteigfladen, avocado, weißen bohnen, karotten, mais (2, 3, glw) tomatensalsa (sw)',
#  'bunte gnocchi, süßkartoffel, roter beete, spinat,',
#  'pasta mit rote- linsen- bolognese (glw, sl)',
#  'begrenztes angebot: holsteiner kartoffelsuppe (sl)',
#  'pulled turkey burger (glw, gld)',
#  'grünkohl (1, 2, 3, 4, sf) röstkartoffeln',
#  'loaded hummus mit gemüse, kernen, kresse',
#  'bratnudeln, cashewkerne, basilikum',
#  'linsen bolognese farfalle',
#  'rajma dal indisches kidneybohnen-curry',
#  'schupfnudelpfanne, karotten, brokkoli, pilze (glw) pesto (nw, nc)',
#  'begrenztes angebot: pasta, pesto, marinierte tomaten (1, 3, 5, glw, nw, sw)',
#  'jackfruit ragout süßkartoffelpüree',
#  'quinoa (bio)- bowl grünkohl-hummus, brokkoli, karotten, ingwer, casshewkerne',
#  'steckrübeneintopf holsteiner art (sf) baguettebrot (glw)',
#  'grünkohl (1, sf) salzkartoffeln',
#  'currywurst hot pot(t) karamellisierte balsamico zwiebeln gebackenen kartoffeln',
#  'pasta bar, täglich wechselndes angebot pasta (glw) chili con carne (2)',
#  'kasselernackenbraten rotweinsoße kartoffelklöße',
#  'kartoffel-rösti (6) ratatouille',
#  'limettenspaghetti, champignons, erbsen- cashewkern- pesto,erdnussöl',
#  'kichererbsen-tomaten-eintopf, sonnenblumenkerne baguettebrot (glw)',
#  'tortellini, kicherbsen, spitzkohl, cashewkerne und rosmarin',
#  'nudeln al arrabiata (1, 2, 6, glw, sl)',
#  'tagliatelle, spinat- ricotta- soße, cashewkerne',
#  'rote- linsen- suppe (sl, sw) baguettebrot (glw)',
#  'kartoffelgratin mit gemüse',
#  'karotten- süßkartoffel- eintopf (3, 5, sw) baguettebrot (glw)',
#  'begrenztes angebot pasta bar nudeln kräutersoße',
#  'avocado- pasta, kirschtomaten, pinienkerne (3, 6, 8, en, glw, nmn, nc)',
#  'bulgur- broccoli- karottenpfanne paprika- oliven- soße',
#  'kartoffel-weiße bohnen ragout, rosmarin, kapern (sl) baguettebrot (glw)',
#  'limettenspaghetti, champignons, erbsen- cashewkern- pesto',
#  'kochwurst zum grünkohl',
#  'kichererbsensuppe (2, 3, so, se, sl) baguettebrot (glw)',
#  'obstsalat',
#  'nudel- hühner- suppe baguettebrot',
#  'putengeschnetzeltes, currysoße, paprika, karotten, bandnudeln',
#  'jackfruit ragout kroketten',
#  'kartoffel-paprika ragout',
#  'grünkohl (1, glw, sf, so) kochwurst (2, 3, 4, 8, 10, sf, sl) röstkartoffeln',
#  'pulled turkey burger (glw, gld) potatoe wedges',
#  'bietet unsere cafeteria täglich ab 08:30 uhr belegte brötchen an.',
#  'begrenztes angebot: tortelloni spinat- quinoa mit cherrytomaten, rucola, sonnenblumenkernen (1, 2, glw)',
#  'begrenztes angebot börek, spinatfüllung (glw) couscous (glw) tomaten- minzsugo',
#  'gebratene spinat-knödel',
#  'lahmacun mit rotkraut, weißkraut, kräuter (glw, so) tomatensalsa (sw)',
#  'paniertes schollenfilet remouladensoße gurkensalat salzkartoffeln',
#  'pasta, marinierte tomaten (sl)',
#  'puten-piccata milanese cherry-tomatensoße polentaschnitte',
#  'pasta bar, in selbstbedienung',
#  'überbackenes moussaka tsatsiki',
#  'bockwurst zum eintopf (2, 3, 10, sf)',
#  'bulgur paprikasoße',
#  'bandnudeln bolognese soße',
#  'chili sin carne bulgur [bio] (glw)',
#  'gemüse-linseneintopf (sf, sl, sw) baguettebrot (glw)',
#  'grünkohl-kürbis bowl',
#  'pasta, blattspinat- tomatensoße (glw)',
#  'rote- linsen- bolognese vollkornspaghetti',
#  'bietet unsere cafeteria täglich ab 09:30 uhr belegte brötchen an.',
#  'rote beete-,süßkartoffel-,spinatgnocchi, rotkraut, weißkraut, kräuter kirschtomaten-konfit, rucola',
#  'begrenztes angebot kartoffel-weiße bohnen ragout, rosmarin, kapern (8, sf, sl) baguettebrot (glw)',
#  'grünkohl (2, 3, 4, sf) kochwurst (2, 3, 4, 8, 10, sf, sl) röstkartoffeln',
#  'vollkornspaghetti (bio), rote- linsen- bolognese (glw, sl)',
#  'geschmorte barberie-ente orangensoße rosenkohl kartoffelklöße',
#  'begrenztes angebot tortellini, kichererbsen, spitzkohl, cashewkerne und rosmarin (glw, nc)',
#  'spicy onion burger, limetten-dip, eisbergsalat, süß-saure gurken, (1, 2, 3, 5, 8, glw, glr, glg, glh, gld, se, sf, so, sw), kartoffelspalten',
#  'tomaten- kokos- suppe baguettebrot (glw)',
#  'afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander baguettebrot',
#  'gemüsenudeln, erbsen- cashewkern- pesto (glw, nw, nc, sl)',
#  'mecklen turkey (bio) burger, mozzarella, rucola, eisbergsalat tomaten- zwiebel- marmelade pommes frites',
#  'kartoffel- kürbiskern- rösti, pilzragout (3, 5, glw, sl, sw)',
#  'börekstange spinat ratatouille bulgur (bio)',
#  'holsteiner kartoffelsuppe mit kochwurst baguettebrot',
#  'begrenztes angebot: quinoa (bio)- bowl spinat-hummus, brokkoli, karotten, ingwer, cashewkerne',
#  'kasselernackenbraten rotweinsoße kartoffelpüree',
#  'kartoffel-grünkohl auflauf, kochwurst',
#  'orientalische gemüsepfanne mit dinkel und geröstetem sesam (glw, gld, so, se)',
#  'gnocchi gemüse tomatensoße',
#  'holsteiner kartoffelsuppe (sf, sl) baguettebrot (glw)',
#  'bunte bohnensuppe,',
#  'currysoße currywurst pommes frites',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen (so)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln oder kartoffelsalat',
#  'quinoa bowl, spinat-hummus, brokkoli, karotten, ingwer, casshewkerne',
#  'süßkartoffelpfanne, ingwer, cashewkerne',
#  'holsteiner grünkohl röstkartoffeln kasseler',
#  'gebackene polenta mit parmesan gratiniert dazu kirschtomaten-konfit und rucola',
#  'chrunchy chick`n burger, (glw, gld, sf, so) wedges (glw)',
#  'falafel teller mit salat, (3, 5, glw, sl, sw) tomaten- zwiebel- marmelade (sf, sw) pommes frites',
#  'chili con carne, bulgur (2)',
#  'tagesgericht: tortelloni spinat- quinoa mit cherrytomaten, rucola, sonnenblumenkernen (glw)',
#  'unsere cafeteria hat ab 10:00 uhr mit brötchen, heissen getränken und vieles mehr für euch geöffnet. mehr für euch geöffnet.',
#  'begrenztes angebot wiener würstchen zum eintopf (2, 3, 10, sf)',
#  'bandnudeln (glw) mangoldpesto (1, 2)',
#  'kichererbsen-tomaten-eintopf, sonnenblumenkerne (3) baguettebrot (glw)',
#  'pasta, pesto, marinierte tomaten (glw, nw)',
#  'kartoffel-rösti apfelmus (3)',
#  'begrenztes angebot indisches gemüse- curry mit kichererbsen couscous',
#  'kartoffel-gulasch, weiße bohnen, rosmarin baguettebrot',
#  'grünkohl (2, 3, 4, sf) röstkartoffeln kochwurst (2, 3, 4, 8, 10, sf, sl)',
#  'chili sin carne bulgur (glw)',
#  'begrenztes angebot pasta bar nudel- mangold- karotten- gratin',
#  'falafel burger, avocado- dip, rotkohlkraut, mango, salat (glw, gld, sf, sl, so) kartoffelspalten (glw)',
#  'pfannkuchen, zimtzucker mango-apfeltopping',
#  'arabische kichererbsensuppe baguettebrot',
#  'bibimbap bowl',
#  'pimp my food: sauer-vleisch wrap, jackfruit, eisbergsalat, remoulade, bratkartoffeln (2, 3, 8, glw, sf)',
#  'chili sin carne fladenbrot',
#  'rosenkohl- curry mit kichererbsen',
#  'gemüseeintopf, dinkel, kirschtomaten, paprika, pasta (glw, gld, sl) fladenbrot (glw, glg, se)',
#  'miso mienudeln, champignons, erdnüsse, spinat, koriander (1, 2, 4, en, glw, sl, so)',
#  'balila libanesisches kichererbsengericht weizenfladen',
#  'begrenztes angebot süßkartoffelpfanne, ingwer, pinienkerne',
#  'weihnachtessen bowl, barbarie ente',
#  'erbseneintopf, kassler baguettebrot',
#  'kartoffelsalat',
#  'kochwurst (2, 3, 4, 8, 10, sf, sl)',
#  'bandnudeln in cherry-tomatensoße',
#  'kichererbsensuppe (2, se, sl) baguettebrot (glw)',
#  'börek, spinatfüllung kichererbsen - couscous tomaten - minzsugo',
#  'ofenkartoffel tomaten- zwiebel- marmelade (sf, sw)',
#  'begrenztes angebot pasta bar nudeln currywurstragout',
#  'börek, spinatfüllung (glw) bulgur [bio] (glw) tomaten- minzsugo',
#  'graupenrisotto, frischen cahmpignons, gerösteten mandeln (1, 2, 3, 5, en, glw, glg, glh, nmn, sl, so, sw)',
#  'erbseneintopf, baguettebrot',
#  'spargelcremesuppe spargelfond für spargelsuppe baguettebrot',
#  'beijing suppe (glw, se, so) baguettebrot (glw) sauer-scharfe-suppe, mu err pilze,glasnudeln',
#  'super! food! - hirse- walnuss- porridge blaubeerenkonfit',
#  'currywurst 2,20€ pommes frites 1,60€',
#  'tagliatelle, kürbis- feta - soße, walnüsse',
#  'unsere cafeteria hat ab 08:00 uhr mit brötchen, heissen getränken und vieles mehr für euch geöffnet. mehr für euch geöffnet.',
#  'ofenkartoffel mit sour creme',
#  'bulgur - broccolipfanne, karottensalat (glw) paprikasoße (1, 2, 4, glw, so)',
#  'begrenztes angebot nudel- gemüse- suppe, petersilien gremolata baguettebrot',
#  '... und potatoe wedges',
#  'tortellini, kicherbsen, spitzkohl, kürbiskerne und rosmarin (glw, nc)',
#  'süßkartoffel-amaranth-burger, senf-walnuss-dip (glw, gld) senf-walnuss-dip (nw, sf, so) kartoffelspalten',
#  'paella, artischocken, paprika (so)',
#  'bio- vollkornspaghetti, rote- linsen- bolognese (glw, sl, sw)',
#  'begrenztes angebot pasta bar nudeln hühnerragout',
#  'täglich ab 9 :00 uhr bietet unsere cafeteria frische brötchen und vieles mehr.',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen (sw)',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander (glw, sl) baguettebrot (glw)',
#  'green hero oat burger, cocktailsoße, tomate, rucola, eisbergsalat (glw, glh, gld, sf, so) kartoffelspalten',
#  'tortellini, kichererbsen, spitzkohl, cashewkerne und rosmarin (glw, nc)',
#  'begrenztes angebot: wechselnde auswahl (3, giw) avocado pasta, cocktailtomaten, pinienkerne',
#  'begrenztes angebot rote bohnen eintopf (1, sl) baguettebrot (glw)',
#  'schnweinenackensteak (sl) ginger ale bbq sauce (sl) krautsalat pommes frites',
#  'burrito mit tomatensalsa und guacamole',
#  'kartoffel-rösti tomaten-gemüse-soße',
#  'begrenztes angebot: currywurst hot pot(t) karamellisierte balsamico zwiebeln kartoffelspalten',
#  'begrenztes angebot: barberie-entenbrustfilet orangensoße rotkohl (1, 2, 3, 4, 5, 8, glw, so, sw) kroketten (glw)',
#  'börek, spinatfüllung chinakohl- mango- salat tomaten- minzsugo',
#  'apfelpfannkuchen, zimtzucker',
#  'chili sin carne couscous (glw)',
#  'kürbissuppe, ingwer, croutons (glw) baguettebrot (glw, glg)',
#  'tortelloni spinat- quinoa mit tomatensauce (1, 2, glw)',
#  'entenbrust ernuss-kokossoße mie-nudeln',
#  'pulled turkey burger 3,90 € ... mit pommes 5,50 €',
#  'kasselernackenbraten rotweinsoße salzkartoffeln',
#  'hummus, brokkoli, blumenkohl, kürbiskerne, sesam fladenbrot',
#  'nudeln gemüseragout, tomaten, weißkohl, kichererbsen,',
#  'süße polenta, sauerkischkompott (glh) mit kirschsoße',
#  'erbseneintopf, baguettbrot (glw, sl)',
#  'steckrübeneintopf holsteiner art (sf, so) baguettebrot (glw)',
#  'country- pfanne, falafel, paprika (glw, sl) paprika- maissoße (sl) kartoffelspalten',
#  'pasta, bohnencurry baguettebrot',
#  'currywurst 2,20€ currysoße pommes frites 1,60€',
#  'kürbissuppe, ingwer, croutons (glw, se, gid) baguettebrot (glw)',
#  'pasta, pesto, marinierte tomaten',
#  'paella, artischocken, paprika',
#  'erbseneintopf, kasseler baguettebrot',
#  'rezepte duell! - rotes linsen dal (3, sf, so) naan brot (glw, so)',
#  'currywurst hot pot(t) (3, 10, sf, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) pommes frites',
#  'kichererbsen-tomaten-eintopf, pinienkerne (3) baguettebrot (glw)',
#  'chili con quinoa kartoffel-rösti ratatouille oder',
#  'kartoffel-rösti tomaten-gemüseragout',
#  'limettenspaghetti, champignons, erbsen- cashewkern- pesto (glw, nw, nc)',
#  'kichererbsen-tomaten-eintopf, (3) baguettebrot (glw)',
#  'kasselernackenbraten, (2, 8, 10), bratenssauce, rosenkohl, kroketten, (glw)',
#  'bohnen- tomaten- suppe (so) baguettebrot (glw)',
#  'penne, kürbis- linsen- gemüse (glw)',
#  'begrenztes angebot pasta bar nudeln grünkohlpesto',
#  'quinoa bowl mit spinat-hummus, brokkoli, karotten, ingwer, casshewkerne',
#  'kabeljau, blattspinat, tomatentagliatelle',
#  'chili sin carne bulgur (bio)',
#  'süßkartoffelpfanne, ingwer, sonnenblumenkerne, pinienkerne',
#  'pasta (glw) süßkartoffelragout, mandeln (nmn)',
#  'täglich ab11:30 uhr bietet unsere cafeteria',
#  'erbsen cashew curry (nc)',
#  'nudel- gemüse- suppe, petersilien gremolata (glw, sl) baguettebrot (glw)',
#  'kartoffelgratin, aubergine, zucchini, emmentaler',
#  'begrenztes angebot: geschöpfte currywurst, baguette',
#  'lahmacun, türkische "pizza",salat, kräuter kirschtomaten-konfit, rucola',
#  'bandnudeln (glw) feldsalatpesto (1, 2, sf)',
#  'gebratenes kabeljaufilet (fi, glw) spitzkohl salzkartoffeln',
#  'pasta (glw) linsen- bolognese, gemüse (glw)',
#  'begrenztes angebot pasta bar makkaroni- tomaten- auflauf',
#  'quinoa (bio)- bowl spinat-hummus, brokkoli, karotten, ingwer, cashewkerne',
#  'rote linsensuppe, sucuk, kreuzkümmel baguettebrot',
#  'bruderhahn bockwurst',
#  'frikadelle sauerkraut stampfkartoffeln',
#  'pasta, kidneybohnencurry (3) baguettebrot (glw)',
#  'kichererbsen-rosenkohleintopf (2, se, sl) baguettebrot (glw)',
#  'gebratener seehecht, balsamicolinsen, kartoffeln',
#  'kichererbsen-tomaten-eintopf, sonnenblumenkerne (3)',
#  'country- pfanne, falaffel (glw, sl) kartoffelspalten paprika- maissoße (sl)',
#  'kasselernackenbraten kroketten rotweinsoße',
#  'bohnen- tomaten- suppe (3) baguettebrot (glw)',
#  'kale pumpkin-bowl grünkohl kürbis bulgur sonnenblumenkerne',
#  'nudelauflauf, brokkoli, champignons, kräuterkruste (1, 2, glw, glh)',
#  'weizenteigfladen, avocado, weißen bohnen, kürbis, mais (2, glw) tomatensalsa (sw)',
#  'putengeschnetzeltes, currysoße, paprika, karotten, mie-nudeln',
#  'miso rahmen, champignons, erdnüsse, pak choi, koriander (1, 2, 4, en, glw, sl, so)',
#  'penne, grünkohlpesto, basilikum (glw, nmn, nc)',
#  'seehechtfilet, kräutereihülle, dijon- senf- soße, karotten, kräuterkartoffeln',
#  'bohnen- tomaten- suppe baguettebrot',
#  'nudeln mit rote- linsen- bolognese (glw, sl)',
#  'puten-piccata cherry-tomatensoße pommes frites',
#  'chili con carne (glw)',
#  'nudel- gemüse- suppe, baguettebrot',
#  'bagel mit grillgemüse und pesto mit rucolapesto',
#  'begrenztes angebot börek, spinatfüllung (glw) couscous (glw) cherry-tomatensoße',
#  'gebratene mie-nudeln, frisches gemüse, (glw, nc, so)',
#  'begrenztes angebot pasta bar nudeln al arrabiata',
#  'falafel bowl',
#  'kichererbsensuppe (2, se) baguettebrot (glw)',
#  'beijing suppe - sauer-scharfe-suppe, mu err pilze, jackfruit [bio], glasnudeln (3, glw, se, so)',
#  'grünkern bolognese farfalle',
#  'kürbissuppe, ingwer, croutons (1, glw) baguettebrot (glw)',
#  'rotes linsen dal naan brot (glw, so)',
#  'chili sin carne baguettebrot',
#  '"your favorites" afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf) baguettebrot (glw)',
#  'ofenkartoffel, tomaten- zwiebel- marmelade, (sf, sw)',
#  'begrenztes angebot spaghetti carbonara',
#  'country- pfanne, falaffel, paprika kroketten paprika- maissoße',
#  'kichererbsen-tomaten-eintopf, sonnenblumenkerne (sl) baguettebrot (glw)',
#  'pasta, pesto, marinierte tomaten (1, 3, 5, glw, nw, nc, sw)',
#  'mit falafel',
#  'grünkohleintopf mit planted. wurst (sf) baguettebrot (glw)',
#  'chili con quinoa',
#  'vollkornspaghetti oder pasta , rote- linsen- bolognese',
#  'nutzt auch gerne unser cafeteriaangebot kartoffelgratin, mit gemüse',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander',
#  'weizenteigfladen, weißen bohnen, kürbis, mais (2, glw) tomatensalsa (sw)',
#  'geschöpfte currywurst, baguette',
#  'begrenztes angebot pasta bar spätzleauflauf',
#  'erbseneintopf (3, 5, sl, sw) baguettebrot (glw)',
#  'planted.bratwurst',
#  'kichererbsen -tomaten-eintopf, sonnenblumenkerne (3) baguettebrot (glw)',
#  'blumenkohl-kartoffel-curry mit rucola und tomaten',
#  'rotes linsen dal (3, sf, so) naan brot (glw, so)',
#  'tagesgericht: ofenkartoffel tomaten- zwiebel- marmelade (sf, sw)',
#  'mash ki dal (1, so, sl) indisches belugalinsen-curry',
#  'grünkohl (1, 2, 3, 4, sf) kochwurst (2, 3, 4, 8, 10, sf, sl) röstkartoffeln',
#  'tortellini, kichererbsen, weißkohl, cashewkerne und rosmarin (glw, nc)',
#  'beluga linsen, senfsoße, rote beete, hokaido (1, 3, 5, 8, sf, sl, sw)',
#  '...mit falafel (glw, sl)',
#  'kale pumpkin-bowl spinat kürbis bulgur',
#  'begrenztes angebot pasta bar ravioli bolognese soße',
#  '"your favorites" afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf, so) baguettebrot (glw)',
#  'elvis - burger, sauerkraut, bbq-sauce,salat, tomaten, zwiebeln, gurke (2, 8, glw, gld, sf, sl) kartoffelspalten',
#  'süßkartoffel-amaranth-burger, (glw, gld) senf-walnuss-dip (nw, sf, so) pommes frites',
#  'tortellin ricotta spinat, tomaten, rucola',
#  'begrenztes angebot pasta bar nudeln wurstgulasch',
#  'putenschnitzel paniert (glw) paprikasoße kartoffelspalten',
#  'pav bhaji - indisches gemüse-püree mit kartoffeln, naan brot',
#  'würziger kaiserschmarrn mit gemüse, emmentaler und schnittlauch-dip',
#  'wiener würstchen zur kartoffelsuppe',
#  'süßkartoffel-amaranth-burger, senf-walnuss-dip (glw, gld) senf-walnuss-dip (nw, sf, so) pommes frites',
#  'süßkartoffel-amaranth-burger, senf-walnuss-dip (glw, glr, glg, glh, gld, se) senf-walnuss-dip (nw, sf, so) pommes frites',
#  'begrenztes angebot kichererbsen-tomaten-eintopf, sonnenblumenkerne (3, sl) baguettebrot (glw)',
#  'streetfood aktion: hokkaido, gebraten, mit kartoffel-gnocchi und feldsalat-pesto',
#  'pasta bar, in selbstbedienung tortelloni spinat- quinoa (1, 2, glw) in tomatensoße',
#  'lahmacun, türkische "pizza", rotkraut, weißkraut, kräuter',
#  'quinoa [bio]- bowl (nc, se) spinat-hummus, brokkoli, karotten, ingwer, casshewkerne',
#  '"begrenztes angebot"chili sin carne (glw, so)',
#  'miso mienudeln, champignons, erdnüsse, pak choi, koriander (en, glw, sl, so)',
#  'spaghetti bolognese soße',
#  'tortellini quinoa-spinat mit cherrytomaten, rucola, sonnenblumenkernen',
#  'begrenztes angebot: rote- linsen- suppe (sl) vollkornbrot (glw, glr)',
#  'kirschtomaten- kokos- suppe baguettebrot',
#  'weizenteigfladen, avocado, weißen bohnen, kürbis, mais (2, glw)',
#  'country- pfanne, falaffel, paprika (glw, sl) kartoffelspalten pikante paprika- olivensoße (sl)',
#  'tortellini verdura curry- kokos- soße',
#  'kohlroulade zwiebelsoße karotten salzkartoffeln',
#  'tagliatelle, bärlauch- ricotta- soße, walnüsse',
#  'bohnen- bulgur- ragout, champignons, walnüsse',
#  'süßkartoffelpfanne, ingwer (sf, sl, so)',
#  'nudel- mangold- karotten- gratin, bärlauchdip',
#  'spiralnudeln bolognese soße',
#  'kichererbsen-ananas-spinat-curry, erdnuss, kartoffel',
#  'holsteiner kartoffelsuppe (3, 5, sf, sl, sw) baguettebrot (glw)',
#  'chili con carne baguettebrot (glw)',
#  'beijing suppe - sauer-scharfe-suppe, mu err pilze, jackfruit [bio], glasnudeln (2, 3, glw, se, so) baguettebrot (glw)',
#  'kochwurst',
#  'avocado- pasta, kirschtomaten, pinienkerne (3, glw)',
#  'nacho bowl',
#  'tagesgericht bulgur [bio]-salat (2, glw) mit falafel (glw, sl)',
#  'spaghetti , rote- linsen- bolognese',
#  'begrenztes angebot; wechselnde auswahl labskaus burger winter sale spiegelei, kartoffelspalten, matjes',
#  'grünkohl röstkartoffeln',
#  'begrenztes angebot tortelloni spinat- quinoa, rucola cherry-tomatensoße',
#  'begrenztes angebot grüner bohneneintopf (sl) baguettebrot (glw)',
#  'steckrübenmus (1)',
#  'holsteiner kartoffelsuppe (sl) baguettebrot (glw)',
#  'tortellin ricotta spinat tomaten- basilikum- soße',
#  'tagesgericht bulgur-salat (2, glw) mit falafel (glw, sl)',
#  'begrenztes angebot rote- linsen- suppe baguettebrot',
#  'gebratener seehecht, balsamicolinsen, meerrettich-stampf-kartoffeln',
#  'bulgur-salat (2, glw) mit falafel (glw, sl)',
#  'mecklen turkey (bio) burger, mozzarella, tomaten-zwiebel-marmelade, rucola, eisbergsalat tomaten- zwiebel- marmelade',
#  'begrenztes angebot kichererbsensuppe (2, se) baguettebrot (glw)',
#  'bratnudeln, zuckerschoten, basilikum',
#  'pasta mit grünem spargel, kirschtomaten und rucolapesto',
#  'tagesgericht: chili con carne (2, glw)',
#  'tagesgericht: chili sin carne (glg, so)',
#  'weihnachtessen bowl, barbarie ente, kroketten rosenkohl',
#  'protein power falfelbratling tomatensalsa rote- bete- hummus süßkartoffel- popcorn- stampf',
#  'putengeschnetzeltes, currysoße, paprika, karotten, bratnudeln',
#  'kartoffel-weiße bohnen-eintopf, rosmarin, kapern (sl) baguettebrot (glw)',
#  'schupfnudelpfanne, karotten, brokkoli, pilze (glw) dip',
#  'süße polenta, sauerkischkompott mit kirschsoße',
#  'erbseneintopf, kassler (2, 3, 4, 5, 8, 10, sl, sw)',
#  'begrenztes angebot lahmacun mit rotkraut, weißkraut, kräuter (glw, so) tomatensalsa (1, 3, sw)',
#  'kartoffel-taler ratatouille',
#  'bohnen-süßkartoffeleintopf (2, se, sl, sf) baguettebrot (glw)',
#  'beijing suppe - sauer-scharfe-suppe, jackfruit [bio], glasnudeln (3, glw, se, so)',
#  'tagesgericht: wiener würstchen (2, 3)',
#  'kasselernackenbraten, (2, 8, 10), rotweinsoße, (sw), rosenkohl, kroketten, (glw)',
#  've falafel bowl',
#  'chili sin carne (se) bulgur [bio] (glw)',
#  'penne, grünkohlpesto, pinienkerne, basilikum',
#  'putensteak cherry-tomatensoße bandnudeln',
#  'street style: miso rahmen, champignons, erdnüsse, pak choi, koriander (1, 2, 4, en, glw, sl, so)',
#  'holsteiner kartoffelsuppe, kasseler, muskat (2, 3, 4, 5, 8, 10, sf, sl, sw) baguettebrot (glw)',
#  'kasselernackenbraten rotweinsoße kartoffelgratin',
#  'tagesgericht: burger im menü mit fritz 0,33l pulled turkey burger (glw, gld) ... mit pommes frites',
#  'weihnachtsessen: barberie-entenbrustfilet rotkohl (1, 3, 5, 8, sw) kroketten (glw) entenjus (sl, sf, so, giw, sw)',
#  'kartoffelgratin, grillgemüse, emmentaler',
#  'geschöpfte currywurst, baguette karamellisierte balsamico zwiebeln',
#  'balila naan brot (glw, so) libanesisches kichererbsengericht',
#  'chili sin carne naan brot',
#  'begrenztes angebot gemüsecremesuppe, meerrettich baguettebrot',
#  'begrenztes angebot: bulgur [bio]- broccoli- karottenpfanne (glw) paprikasoße',
#  'karottensüßkartoffeleintopf mit baguettebrot',
#  'rezepte duell! - rotes linsen dal (3, sf, so) fladenbrot (glw, so, se)',
#  'lauwarme pasta bowl mit salami, rauke, kirschtomaten, burrata',
#  'nudel-tomaten-auflauf, basilikumsoße',
#  'begrenztes angebot pasta bar nudeln chili sin carne',
#  'schwentine original: handgedrehte königsberger klopse, kartoffeln, rote bete, kapernsoße (8, glw, sf)',
#  'kichererbsen-tomaten-eintopf, sonnenblumenkerne (3) baguettebrot (glw, glr)',
#  'überbackene pasta mit gemüse 3,10 €',
#  'nudel- broccoli- karottenpfanne (glw, se) paprikasoße (1, 2, 4, glw, so)',
#  'hokaido gebraten, gnocchi, kürbiskerne',
#  'pasta, kürbis- linsen- gemüse (glw)',
#  'kochwurst zum rübenmus (2, 3, 4, 8, 10, sf, sl)',
#  'tagesgericht: erbsen- quinoa- frikadelle (sl) mit kartoffel-gurkensalat (sf)',
#  'bratnudeln, gemüse, cashewkerne, basilikum',
#  'vollkornspaghetti , rote- linsen- bolognese',
#  'kichererbsensuppe (2, se) naan brot (glw, so)',
#  'scharfes kürbis-linsen-gemüse',
#  'begrenztes angebot pasta bar nudelauflauf',
#  'bulgur [bio]- broccoli- karottenpfanne (glw) paprikasoße (1, 2, 4, glw, so)',
#  'erbseneintopf, kassler (2, 3, 4, 5, 8, 10, sl, sw) baguettebrot (glw)',
#  'chili con carne',
#  'kartoffel-kürbisgratin',
#  'bockwurst',
#  'afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf, sl) baguettebrot (glw)',
#  'spaghetti mit kürbispesto (glw)',
#  'kürbis- süßkartoffel- suppe baguettebrot (glw)',
#  'langosch',
#  'süß- saure gemüse- suppe, (3, glw, se, so) chinesische aromen, glasnudeln, mu-err',
#  'rainbow pasta, kürbis, rote beete, oliven, kräuter, blumenkohl (6, 8, en, glw)',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, nudeln, koriander (glw) baguettebrot (glw)',
#  'currywurst hot pot(t) (3, 10, sf, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten',
#  'ravioli pomodoro feldsalatpesto',
#  'wir haben unsere cafeteria heute ab 8:30 uhr geöffnet!! wir freuen uns auf euch',
#  'nudel- gemüse- suppe, petersilien gremolata (glw, sw) baguettebrot (glw)',
#  'grünkohl (1, sf) röstkartoffeln',
#  'tagesgericht chili con carne (2, glw)',
#  'tortellini, kicherbsen, spitzkohl, brokkoli, rosmarin (glw, nc) tomatensoße',
#  'penne al arrabiata (1, 2, glw, sl)',
#  'penne al arrabiata (1, 2, 6, glw, sl, sw)',
#  'süßkartoffelsuppe, ingwer, kokos, gemüse',
#  'erbseneintopf (1, sl) baguettebrot (glw)',
#  'winterlicher gemüseeintopf',
#  'würziger kaiserschmarrn, gemüse, emmentaler,kräuter-dip',
#  'avocado- pasta, kirschtomaten, pinienkerne',
#  'tagesgericht couscous-salat (2, glw) mit falafel (glw, sl)',
#  'mediterrane tomatencremesuppe, baguettebrot',
#  'begrenztes angebot kichererbsen-tomaten-eintopf, sonnenblumenkerne (3) baguettebrot (glw)',
#  'putengeschnetzeltes, currysoße, pfannengemüse, bandnudeln',
#  'süßkartoffelpfanne, ingwer, cashewkerne, sonnenblumenkerne (nc)',
#  'penne, grünkohlpesto (glw, nmn, nc)',
#  'weihnachtessen bowl mit entenbrust',
#  'begrenztes angebot kartoffel-weiße bohnen ragout, rosmarin, kapern (3, sl) baguettebrot (glw)',
#  'spaghetti, rote- linsen- bolognese',
#  'erbseneintopf, kassler (2, 3, 4, 5, 8, 10, sf, sl, sw) baguettebrot (glw)',
#  'pasta, jackfruit-bolognaise',
#  'currywurst, (10, sf), pommes frites',
#  'onion burger, limetten-dip, eisbergsalat, süß-saure gurken (1, 2, 3, 5, 8, glw, glr, glg, glh, gld, se, sf, so, sw) pommes frites',
#  'begrenztes angebot: penne al arrabiata',
#  'super! food! - gnocchi bowl rote-bete- spinat- gnocchis, karotten, champignons, bärlauch, rauke',
#  'ofenkartoffel mit sour creme (bio)',
#  'mecklen turkey tomaten- zwiebel- marmelade',
#  'gebratenes kabeljaufilet auf spitzkohl mit petersilienkartoffeln',
#  'unsere cafeteria bietet täglich ab 08:30 uhr belegte brötchen an.',
#  'pasta bar, täglich wechselndes angebot (glw)',
#  'rajma dal - indisches kidneybohnen-curry',
#  'putengeschnetzeltes, currysoße, paprika, karotten, pasta',
#  'chili con carne, fladenbrot als menü mit fritz + 1,00 €',
#  'unsere cafeteria bietet täglich ab 10:00uhr belegte brötchen an.',
#  'chili con quinoa (2) baguettebrot (glw)',
#  'sizilianische pasta alla norma - gemüse , tomate, basilikum (1, 2, glw)',
#  'rote beete sesam bratling, gemüse, schnittlauchdip, kartoffelspalten',
#  'falafel burger, basilikumcreme, rotkohlkraut, mango, salat (glw, gld, sf, sl, so) kartoffelspalten',
#  'tagesgericht chili sin carne (glg, so)',
#  '... und gitterkartoffeln',
#  'pommes frites',
#  'currywurst (10, sf) pommes frites',
#  'kartoffel-rösti (glw) ratatouille',
#  'begrenztes angebot balila - libanesisches kichererbsengericht (se) naan brot (glw, so)',
#  'penne, kürbis- linsen- gemüse',
#  'begrenztes angebot: hummus, brokkoli, kürbiskerne, sesam fladenbrot',
#  'planted.bratwurst (sf)',
#  'country- pfanne, falafel, paprika kartoffelspalten paprika- maissoße',
#  'begrenztes angebot puten wiener (2, 3, 4, 10, sf) kartoffelsalat (sf)',
#  'maultaschen-bowl',
#  'bratnudeln, cashewkerne, basilikum, kräuter',
#  'chili con couscous (glw)',
#  'begrenztes angebot rote- linsen- suppe (sl) roggenbrötchen (glw, glr)',
#  'grünkohleintopf (sf) baguettebrot (glw)',
#  'chili sin carne (glw, so) fladenbrot (glw, glg, se)',
#  'begrenztes angebot linseneintopf (1, 3, 5, sl, sw) baguettebrot (glw)',
#  'kasseler zum rübenmus',
#  'falafel taler (glw) couscous (glw) tomaten- minzsugo',
#  'königsbergerklopse kapernsoße salzkartoffeln',
#  'limited edition gnocchi gemüse tomatensoße',
#  'gemüsenudeln, pilzfond (1, 2, 4, en, glw, sl, so)',
#  'currywurst (10, sf) currysoße (2, 3, sf, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) gitterkartoffeln (glw)',
#  'bulgur - broccoli- karottenpfanne paprika- oliven- soße',
#  'tagesgericht tortelloni spinat- quinoa mit cherrytomaten, rucola, sonnenblumenkernen (glw)',
#  'holsteiner kartoffelsuppe (1, 2, 3, 4, 5, glw, sf, sl, so, sw) baguettebrot (glw)',
#  'ravioli pomodoro, grillgemüse, basilikum, olivenöl, parmesan',
#  'begrenztes angebot: erbseneintopf, kassler (2, 3, 4, 5, 8, 10, sl, sw) baguettebrot (glw)',
#  'country- pfanne, falaffel, paprika (glw, sl) kartoffelspalten paprika- maissoße',
#  'rote linsensuppe (1, 3, 5, sf, sl, sw) baguettebrot (glw)',
#  'rotes linsen dal (3, sf, so) brot (glw, glg, se, so)',
#  'rote-linsen-bolognese mit pasta',
#  'mercimek çorbasi - türkische linsensuppe (1, glw, glg, se)',
#  'kidneybohnen -frikadelle (glw) kräutersoße (glh) salzkartoffeln blumenkohl',
#  'pasta, kokos, kürbis, kichererbsen, karotte',
#  'rezepte-duell rotes linsen dal (3, sf, so) naan brot (glw, so)',
#  'gnocchi, kicherbsen, spitzkohl, cashewkerne und rosmarin (glw, nc)',
#  'nudel-gemüse gratin',
#  'chili sin carne (glw, so)',
#  'mediterranes gemüse, kartoffel',
#  'pimp my food: sauer-vleisch wrap, jackfruit, eisbergsalat, remoulade, bratkartoffeln (2, 3, 8, glw, sf, sl)',
#  'zero waste teller mensa',
#  'joggingsandwich mit geramont und putenbrust',
#  'kartoffelrösti-ecken ratatouille, oliven',
#  'currywurst bowl karamellisierte balsamico zwiebeln baguettebrot',
#  'begrenztes angebot putenschnitzel paniert (glw)',
#  'begrenztes angebot süßkartoffel-amaranth-burger (glw, gld) senf-walnuss-dip (nw, sf, so) kartoffelspalten',
#  'begrenztes angebot grünkohleintopf, kochwurst baguettebrot',
#  'la pasta con pesto di zucca pasta mit kürbispesto',
#  'frikadelle petersiliensoße wurzel- kartoffelstampf',
#  'nudelauflauf, brokkoli, champignons, kräuterkruste (1, 2, glw, glh) ratatouille',
#  'begrenztes angebot süßkartoffel-amaranth-burger, senf-walnuss-dip (glw, glr, glg, glh, gld, se) senf-walnuss-dip (nw, sf, so) kartoffelspalten',
#  'kaiserschmarrn apfelkompott',
#  'pasta, linsen- gemüse, champignons, sellerie (glw, sl, sw)',
#  'rajma dal - indisches kidneybohnen-curry (1, 3)',
#  'begrenztes angebot: süßkartoffelpfanne, ingwer, cashewkerne',
#  'currywurst hot pot(t) (2, 3, 10, sf, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten (glw)',
#  'begrenztes angebot kartoffel- erbseneintopf',
#  'begrenztes angebot grünkohl bratkartoffeln',
#  'lahmacun, türkische "pizza", rotkraut, weißkraut, kräuter kirschtomaten-konfit, rucola',
#  'begrenztes angebot bohnen- tomaten- suppe baguettebrot',
#  'kartoffel-reibekuchen apfelmus',
#  'grünkohl (2, 3, 4, sf) röstkartoffeln',
#  'bruderhahn bockwurst (bio)',
#  'kartoffel- erbseneintopf, kasseler und baguette (2, 3, 4, glw, glr, sl, so)',
#  'bandnudeln (glw) mangoldpesto (1, 2, sf)',
#  'pasta carbonara',
#  'süßkartoffelpfanne, ingwer, cashewkerne (nc, sw)',
#  'country- pfanne, paprika (glw, sl) kartoffelspalten paprika- maissoße (sl)',
#  'chili sin carne (glg, so)',
#  'putenschnitzel paniert (glw) curry- kokos- soße (3) broccoli salzkartoffeln',
#  'lübecker karottenmus, kasseler (2, 3, 4, 5, 8, 10, sw)',
#  'begrenztes angebot tomaten-linsenragout (nmn) fladenbrot (glw, glg, se)',
#  'karotten- süßkartoffel- eintopf baguettebrot (glw, glg)',
#  'begrenztes angebot pasta bar nudeln gemüse-spargelragout',
#  'begrenztes angebot kürbissuppe, ingwer, croutons (glw) baguettebrot (glw)',
#  'pasta (glw) in cherry-tomatensoße',
#  'hokaido gebraten, gnocchi, kürbiskerne (glw)',
#  'beijing suppe, (3, glw, se, so) sauer-scharf-suppe, mu err pilze, jackfruit, mie-nudeln',
#  'begrenztes angebot: burrito, vunasauce, (2, glw) salat (1, sf, so)',
#  'linsensalat mit antipasti von (sl, sw) champignons (1, 3, 5, sw) paprika (1, 3, 5, sw) kirschtomaten (sw)',
#  'steckrübeneintopf, croutons (glw, sf) baguettebrot (glw)',
#  'erbseneintopf, minzdip, roggenbrot',
#  'kartoffel-rösti tomaten- gemüse- soße (6.sl)',
#  'paella, artischocken, paprika, kräuterdip',
#  'grünkohleintopf, kochwurst baguettebrot',
#  'pasta rote- linsen- bolognese (glw, sl)',
#  'campus welcome aktion: currywurst hot pot(t) karamellisierte balsamico zwiebeln gebackenen kartoffeln',
#  'gebratener seehecht kirschtomaten-konfit, rucola kartoffelpüree',
#  'börek, spinatfüllung (glw, so) couscous (glw) tomaten- minzsugo',
#  'tagesgericht chili con carne (glw)',
#  'indischer dinkel pilaw (2, 5, gld, nc)',
#  'thüringer bratwurst sauerkraut kartoffelpüree',
#  'kale pumpkin-bowl grünkohl, kürbis, bulgur (bio), sonnenblumenkerne',
#  'weihnachtsessen: barberie-entenbrustfilet rotkohl (1, 3, 5, sw) kroketten (glw) orangensoße',
#  'kichererbsensuppe (2, se, sf) baguettebrot (glw)',
#  'gnocchi (glw) ratatouille',
#  'kürbissuppe, ingwer, orange baguettebrot',
#  'currywurst currysoße pommes frites',
#  'burrito (2, glw, glg, so)',
#  'pasta, kürbis- ricotta- soße,',
#  'ofenkartoffel kalte tomatensoße',
#  'kasselernackenbraten (2, 8, 10) rotweinsoße (glw, glg, sl, so) kroketten (glw)',
#  'currywurst hot pot(t) karamellisierte balsamico zwiebeln steakhouse fries',
#  'pasta, spargel, tomaten, pinienkerne',
#  'limited edition',
#  'seehechtfilet, dijon- senf- soße, karotten, kartoffelstampf',
#  'ofenkartoffel',
#  'pasta bar, täglich wechselndes angebot vollkornspaghetti [bio],tomaten - linsensoße (glw)',
#  'begrenztes angebot grünkohl (1, sf) röstkartoffeln',
#  'bohnen- tomaten- suppe avocado- topping baguettebrot (glw)',
#  'afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, se) baguettebrot (glw)',
#  'steckrübenmus (sf)',
#  'bulgur- salat (2, glw) falafel (glw, sl)',
#  'afrikanischer gemüseeintopf, erdnuss, weißkohl, mango, koriander (en, sf)',
#  'begrenztes angebot pasta bar nudeln geschöpfte currywurst',
#  'begrenztes angebot - hokaido, gnocchi, kürbiskerne (glw)',
#  'putenschnitzel paniert (glw) ratatouille kartoffel-rösti',
#  'überbackene pasta mit mediterranem gemüse',
#  'pulled turkey burger, bbq-sauce, rotkohl, röstzwiebeln (glw, gld, sf, so, sw) kartoffelspalten',
#  'beluga linsen, senfsoße, rote beete, hokaido',
#  'grünkohleintopf (sf)',
#  'dal makhani - indisches linsen-bohnen-curry',
#  'tortellini ricotta spinat gremolata',
#  'rajma dal - indisches kidneybohnen-curry (sf)',
#  'süßkartoffel- paprika- suppe, mandel- kräuter- mix baguettebrot',
#  'vollkornspaghetti (bio) rote- linsen- bolognese (glw, sl, so)',
#  'gemüsecremesuppe, meerrettich baguettebrot',
#  'gabelspaghetti, tomaten- mango- linsenragout (glw, se)',
#  'rainbow pasta, kürbis, rote bete, oliven, kräuter, blumenkohl (6, 8, en, glw)',
#  'nudel- gemüse- suppe, petersilien gremolata baguettebrot',
#  'holsteiner kartoffelsuppe (3, 5, sf, sl, sw) brot (glw, glr)',
#  'kartoffel-weiße bohnen ragout, rosmarin, kapern (3, sl) brot (glw, so)',
#  'täglich ab 11:30 uhr bietet unsere cafeteria',
#  'begrenztes angebot pasta bar nudeln chili con carne',
#  'chili sin carne',
#  'linseneintopf (sf, sl, sw) baguettebrot (glw)',
#  'currywurst mit pommes frites',
#  'gnocchipfanne (sf) tomatensoße',
#  'lauwarmer beluga linsen one pot, balsamico, rote beete, hokkaido (1, 3, 5, sf, sl, sw)',
#  'tagesessen',
#  'beijing suppe, (3, glw, se, so) sauer-scharf-suppe, mu err pilze, jackfruit, glasnudeln',
#  'begrenztes angebot kartoffel-rösti ratatouille',
#  'unsere cafeteria bietet täglich ab10:00 uhr belegte brötchen an.',
#  'begrenztes angebot linseneintopf (1, 3, 5, sf, sl, sw) baguettebrot (glw)',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen',
#  'chili con carne baguettebrot',
#  'weihnachtsessen mock duck',
#  'naan brot balila libanesisches kichererbsengericht',
#  'nudelhörnchen, favabohnen, paprika, pinienkerne',
#  'pasta, rote- linsen- bolognese (glw, sl)',
#  'penne, kürbis- linsen- gemüse (glw, sl)',
#  'kartoffel- tomaten- suppe baguettebrot (glw)',
#  'currywurst pommes frites currysoße karamellisierte balsamico zwiebeln',
#  'karotten- orangen- ingwer- eintopf (so) baguettebrot (glw)',
#  'karotteneintopf, kasseler baguettebrot',
#  'tortellini verdi verdura, gemüse, tomate, rosmarin und kichererbsen (glw, nc, sl)',
#  'mit falafel (glw)',
#  'begrenztes angebot pasta (glw) tomaten-gemüsesoße',
#  'tagesgericht: erbsen- quinoa- frikadelle, (sl), ...mit potatoe wedges 4,50 €',
#  'begrenztes angebot pasta bar nudeln gemüse- curry',
#  'chili con quinoa baguettebrot (glw)',
#  'pasta bar, täglich wechselndes angebot sabsi - indisches rosenkohl- curry mit kichererbsen',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander (glw, sl, so) baguettebrot (glw)',
#  'holsteiner kartoffelsuppe mit bruderhahn bockwurst (bio)',
#  'country- pfanne, falaffel, paprika (glw) paprika- maissoße (sl) kartoffelspalten',
#  'unsere cafeteria hat ab 10:00 uhr mit brötchen, heissen getränken und vieles mehr für euch geöffnet.',
#  'kürbissuppe, ingwer, croutons (glw, so) baguettebrot (glw)',
#  'bio vitalbrezel (glw, glr, se)',
#  'hirse- walnuss- porridge (glh, nw) blaubeerenkonfit',
#  'begrenztes angebot: kartoffel-weiße bohnen ragout, rosmarin, kapern, pasta (sl) baguettebrot (glw)',
#  'täglich ab11:30uhr bietet unsere cafeteria',
#  'rote- linsen- suppe baguettebrot',
#  'chili sin carne pasta',
#  'makkaroni- brokkoli- auflauf (1, glw, glh) tomaten- basilikum- soße (sw)',
#  'currybratwurst sauerkraut stampfkartoffeln',
#  'arabische kichererbsensuppe fladenbrot',
#  'gebratener seehecht auf spitzkohl mit petersilienkartoffeln',
#  'lauwarmer linsen one pot, balsamico, rote beete, hokkaido (1, 3, 5, sf, sl, sw)',
#  'gebratener seehecht,eihülle, balsamicolinsen, meerrettich-stampf-kartoffeln',
#  'begrenztes angebot pasta bar nudeln bohnen- tomaten- ragout',
#  'nudel- gemüse- suppe, petersilien gremolata (glw) baguettebrot (glw, glr)',
#  'limettenspaghetti, champignons, erbsenpesto',
#  'quinoa [bio]- bowl - spinat-hummus, brokkoli, karotten, ingwer, casshewkerne (nmn, nc, se)',
#  'geschöpfte currywurst, pommes frites',
#  'ravioli, wurzel- gemüse- ragout',
#  'hänchenschnitzel',
#  'kichererbsen-tomaten-eintopf, kürbiskerne (3) baguettebrot (glw)',
#  'kartoffel-kürbiskern-rösti',
#  'linseneintopf, kasseler',
#  'kartoffelgratin, tomate-mozzarella',
#  'kartoffel-gulasch, grüne bohnen, rosmarin, kapern baguettebrot',
#  'bulgur, zucchini, paprika, kreuzkümmel, mandeln',
#  'pasta mit kürbispesto (glw)',
#  'pasta, grünkohlpesto (glw, nmn, nc)',
#  'rajma dal - indisches kidneybohnen-curry (1) bulgur [bio] (glw)',
#  'kartoffel- gemüse- eintopf, weiße bohnen, kichererbsen, tomate (sl) baguettebrot (glw)',
#  'begrenztes angebot gemüseeintopf, dinkel, kirschtomaten, paprika, pasta (glw, gld, sl)',
#  'planted kebap paprika- oliven- soße (6) gitterkartoffeln (glw)',
#  'pasta gorgonzolasoße broccoli',
#  'rotes linsen dal (sf, so) naan brot (glw, so)',
#  'beluga linsen, senf, rote beete, hokaido (1, 3, 5, sf, sl, sw)',
#  'currywurst gitterkartoffeln currysoße karamellisierte balsamico zwiebeln',
#  'paella, champignons, paprika (sf, sl)',
#  'sabsi rosenkohl- curry mit kichererbsen',
#  'erbseneintopf, gemüse, kartoffeln',
#  'vollkornspaghetti',
#  'kale pumpkin-bowl (glw) grünkohl, kürbis, couscous, sonnenblumenkerne',
#  'jackfruit- gulasch',
#  'country- pfanne, falaffel, paprika paprika- maissoße kartoffelspalten',
#  'hummus, brokkoli, blumenkohl, kürbiskerne, sesam baguettebrot',
#  'begrenztes angebot pasta bar nudeln carbonara soße',
#  'makkaroni, fruchtiger hokaido mit kernen satesoße',
#  'balila libanesisches kichererbsengericht naan brot (glw, so)',
#  'putensteak cherry-tomatensoße kroketten',
#  'miso mienudeln, champignons, erdnüsse, erbsen, eisberg, koriander (1, 2, 4, en, glw, sl, so)',
#  'süßkartoffelpfanne (glw, sl) kartoffelspalten t.-gerichte (glw) vn paprika-maissoße (sl)',
#  'pasta (glw) pasta, paprika- oliven- soße (6)',
#  'wiener würstchen zum eintopf (2, 3, 10, sf)',
#  'gebackene ofenkartoffel mit guacomole und chili con carne',
#  'erbseneintopf, (3, 5, sl, sw) baguettebrot (glw)',
#  'broccoli-möhrenpfanne mit weißkohlsalat erbsenpürree bulgur',
#  'süßkartoffel-amaranth-burger (glw, gld) senf-walnuss-dip (3, nw, sf, so) pommes frites',
#  'hokaido gebraten, gnocchi, kürbiskerne (glw) rucolapesto (nc)',
#  'pasta, pesto, marinierte tomaten (glw)',
#  'tagesgericht pulled turkey burger (glw, gld)',
#  'pasta bar, täglich wechselndes angebot pasta (glw) tomaten - gemüsesoße',
#  'linseneintopf (sl, sw) baguettebrot (glw)',
#  'begrenztes angebot curryhuhnsuppe brot',
#  'begrenztes angebot: kürbissuppe, ingwer, orange baguettebrot',
#  'currywurst hot pot(t) (2, 3, 10, sf, sl) karamellisierte balsamico zwiebeln (1, 3, 5, sw) kartoffelspalten',
#  'begrenztes angebot pasta bar nudeln chilli sin carne',
#  'grüner bohneneintopf (sl) baguettebrot (glw)',
#  'mulligatawny curryhuhnsuppe, mandeln',
#  'lecker bratnudeln! leider ausverkauft - waren zu lecker :-(',
#  'begrenztes angebot pasta bar pasta, pesto, marinierte tomaten',
#  'chili sin carne (glg, so) bulgur [bio] (glw)',
#  'kartoffelsuppe (sl, sw) baguettebrot (glw)',
#  'graupenrisotto, frischen cahmpignons, gerösteten mandeln',
#  'begrenztes angebot grünkohleintopf (sf) baguettebrot (glw)',
#  'vollkornspaghetti, rote- linsen- bolognese',
#  'begrenztes angebot grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander baguettebrot',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander (en, glw, so) baguettebrot (glw)',
#  'putenschnitzel paniert (glw) curry- kokos- soße (3) broccoli süßkartoffel-mais-pürre',
#  'kale pumpkin-bowl grünkohl kürbis bulgur (bio) sonnenblumenkerne',
#  'mecklen turkey burger, cole slaw , rucola, tomaten- zwiebel- marmelade steakhouse fries',
#  'limettenspaghetti, champignons, erbsen- cashewkern- pesto (glw, nc)',
#  'grünkern bolognese farfalle, weintrauben',
#  'tortellini, kicherbsen, spitzkohl, cashewkerne und rosmarin (3, glw, nc)',
#  'chili con quinoa baguettebrot',
#  'spaghetti carbonara',
#  'gnocchi, kürbisragout',
#  'hummus, brokkoli, blumenkohl, kürbiskerne, sesam (se) naan brot (glw, so)',
#  'holsteiner kartoffelsuppe baguettebrot',
#  'kartoffelgratin mit gemüse 3,10€',
#  'begrenztes angebot: makkaroni- tomaten- auflauf, basilikumsoße',
#  'erbseneintopf (3, 5, sl, sw)',
#  'currywurst currysoße',
#  'begrenztes angebot curryhuhnsuppe, mandeln, vollkornbrot',
#  'indisches rosenkohl- curry mit kichererbsen',
#  'bratnudeln, zuckerschoten, erdnüsse, basilikum',
#  'pasta tricolore, salbei, sonnenblumenkerne rucolapesto',
#  'indische bohnen- linsen- suppe (sl) baguettebrot (glw)',
#  'kürbissuppe, ingwer, croutons (glw) baguettebrot (glw)',
#  'gnocchi bowl (1, 3, 5, glw, sw) rote-bete- spinat- gnocchis, karotten, champignons, bärlauch, rauke',
#  'steckrübenmus (1, sf)',
#  'linseneintopf, kasseler (2, 3, 4, 5, 8, 10, sl, sw) baguettebrot (glw)',
#  'kaiserschmarrn, rosinen, mandeln, apfelkompott',
#  'spicy onion burger, limetten-dip, eisbergsalat, süß-saure gurken (1, 2, 3, 5, 8, glw, gld, sf, so, sw) kartoffelspalten',
#  '"your favorites" lahmacun mit rotkraut, weißkraut, kräuter (glw, so) tomatensalsa (sw)',
#  'country- pfanne, falaffel, paprika kartoffelspalten paprika- maissoße',
#  'grüne- thai- kokos- gemüsesuppe, kichererbsen, koriander, minze (glw) baguettebrot (glw)',
#  'pasta chili sin carne',
#  'tortelloni spinat- quinoa mit cherrytomaten, rucola, sonnenblumenkernen (glw)',
#  'grünkohleintopf mit kassler (2, 3, 4, 8, 10) baguettebrot (glw)',
#  'süßkartoffel- paprika- suppe, pinienkerne - kräuter- mix baguettebrot',
#  'erbseneintopf baguettebrot',
#  'penne, grünkohlpesto, basilikum',
#  'afrikanischer gemüseeintopf, erdnuss, weißkohl, mango (en, sf) baguettebrot (glw, glr)',
#  'pasta, brokkoli, pinienkerne (3, glw)',
#  'kaiserschmarrn bowl mit sahne, johannisbeeren, heidelbeeren, himbeeren',
#  'bio bulgur - broccoli- karottenpfanne paprikasoße',
#  'begrenztes angebot: frikadelle rotweinsoße kartoffelgratin',
#  'elvis - burger, sauerkraut, bbq-sauce,salat, tomaten, zwiebeln, gurke kartoffelspalten',
#  'börekstange spinat mango- orangen- chutney bulgur (bio)',
#  'während der semesterferien öffnen wir die cafeteria eingeschränkt mit kaffee, kuchen, belegten brötchen, eis und to go salaten - wir freuen uns auf euch',
#  'gemüseeintopf, dinkel, kirschtomaten, paprika, pasta (glw, gld, sl) baguettebrot (glw)',
#  'pikante sesamnudeln mit erdnusssoße (en, glw, se, so)',
#  'rajma dal - indisches kidneybohnen-curry (1, glw)',
#  'gemüseeintopf (sl) baguettebrot (glw)',
#  'lauwarme pasta bowl mit salami, rauke, kirschtomaten, burrata (glw, sw)',
#  'penne mit kürbispesto (glw)',
#  'kasselernackenbraten rotweinsoße kroketten',
#  'gemüseeintopf (2, se, sl) baguettebrot (glw)',
#  'bratwurst sauerkraut stampfkartoffeln',
#  'rote- linsen- suppe (sl) baguettebrot (glw)',
#  'bockwurst zum eintopf (2, 3, 10)',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander baguettebrot',
#  'orientalische gemüsepfanne mit dinkel und geröstetem sesam',
#  'country-pfanne, falaffel, paprika kartoffelspalten paprika-maissoße',
#  'ofenkartoffel sour creme geschöpfte currywurst, baguette',
#  'tortellini, kicherbsen, spitzkohl, cashewkerne und rosmarin (glw, nc)',
#  'sabsi indisches rosenkohl- curry mit kichererbsen',
#  'süßkartoffel-amaranth-burger, senf-walnuss-dip senf-walnuss-dip pommes frites',
#  'kichererbsen-tomaten-eintopf, pinienkerne',
#  'hokaido gebraten, gnocchi, kürbiskerne rucolapesto',
#  'begrenztes angebot country- pfanne, falaffel, paprika (glw) paprika- maissoße (sl) kartoffelspalten',
#  'pasta bar, täglich wechselndes angebot pasta al arrabiata (1, 2, 6, glw, sl)',
#  'gnocchi, salbei, sonnenblumenkerne feldsalatpesto',
#  '"your favourites"lahmacun mit rotkraut, weißkraut, kräuter (glw, so, sw) tomatensalsa (sw)',
#  'avocado- pasta, kirschtomaten, pinienkerne, oliventapenade (3, 6, glw)',
#  'süßkartoffel-amaranth-burger, (glw, gld) vn senf-walnuss-dip (nw, sf, so) kartoffelspalten',
#  'gemüseeintopf, dinkel, tomaten, paprika, pasta (glw, gld, sl)',
#  'chili-maiseintopf, paprika, kidneybohnen, kichererbsenbulgur baguettebrot',
#  'nutzt auch gerne unser cafeteriaangebot artgerechte currywurst',
#  'pasta (glw) linsen- bolognese, gemüse (glw, glg, so)',
#  'la pasta con pesto di zucca penne mit kürbispesto',
#  'porridge mit erdnüssen und mohnzucker (en, glh) rote grütze',
#  'süßkartoffel-amaranth-burger, senf-walnuss-dip senf-walnuss-dip kartoffelspalten',
#  'bohnen- bulgur (bio)- ragout, champignons, walnüsse',
#  'pasta bar, täglich wechselndes angebot',
#  'chili sin carne (glw, so) baguettebrot (glw)',
#  'country- pfanne, nuggets, kartoffelspalten paprika- maissoße',
#  'super! food! - bandnudeln mangoldpesto',
#  'couscous-salat (2, glw)',
#  'pasta bar, täglich wechselndes angebot spiralnudeln (glw) kokos- gemüse- currysoße (so)',
#  'begrenztes angebot nudeln wurstragout, champignons',
#  'gnocchi, (glw) ratatouille',
#  'fagottini gorgonzola gremolata',
#  'paella, erbsen, champignons, paprika',
#  'begrenztes angebot: tagliatelle, bärlauch- ricotta- soße, walnüsse',
#  'makaroni, tomaten- mango- linsenragout (glw)',
#  'polenta, pilzgemüse, blattspinat',
#  'gabelspaghetti, tomaten- mango- linsenragout (glw)',
#  'tortellini, kicherbsen, spitzkohl, cashewkerne, pesto (glw, nc)',
#  'erbseneintopf, kassler baguettebrot bockwurst zum eintopf',
#  'röstkartoffeln, mediterranes gemüse, tomaten- zwiebel- marmelade',
#  'kürbissuppe, croutons (3, glw, se, so) sauer-scharfe-suppe, mu err pilze, glasnudeln',
#  'begrenztes angebot steckrübeneintopf holsteiner art baguettebrot',
#  'chili sin carne, mit viel gemüse 3,50€ 1/2 flagueline rustikal',
#  'kichererbsen-tomaten-eintopf, sonnenblumenkerne (3, sl) baguettebrot (glw, glg, se)',
#  'pasta al arrabiata',
#  'spaghetti, rote- linsen- bolognese (glw, sl)',
#  'lahmacun, türkische "pizza", bunter salat, kräuter',
#  'ceasars salad',
#  'spicy onion burger, limetten-dip, eisbergsalat, süß-saure gurken (1, 2, 3, 5, 8, glw, glr, glg, glh, gld, se, sf, so, sw) kartoffelspalten',
#  'begrenztes angebot vollkornspaghetti',
#  'kirschtomaten- kokos- suppe baguettebrot (glw)',
#  'kartoffel-gulasch, weiße bohnen, rosmarin, kapern',
#  'chili sin carne (1, 2, 4, glw, glg, so) bulgur [bio] (glw)',
#  'riesen rösti ratatouille',
#  'avocado- pasta, kirschtomaten, cashewkerne (3, glw, nc)',
#  'rotes linsen dal (3, sf, so) fladenbrot (glw, so, se)',
#  'pasta bar, täglich wechselndes angebot paella, artischocken, paprika',
#  'hummus, brokkoli, blumenkohl, kürbiskerne, sesam (se) fladenbrot (glw, glg, se)',
#  'sabsi - indisches rosenkohl- curry mit kichererbsen indisches rosenkohl- curry mit kichererbsen',
#  'makkaroni- tomaten- auflauf, kräutersoße',
#  'begrenztes angebot gnocchi- kichererbsenauflauf',
#  'beijing suppe - sauer-scharfe-suppe, mu err pilze, jackfruit, glasnudeln (3, glw, se, so) baguettebrot (glw)',
#  'börek, spinatfüllung (glw) couscous (glw) tomatensalsa (sw)',
#  'süßkartoffel-amaranth-burger, (glw, glr, glg, glh, gld, se) vn senf-walnuss-dip (nw, sf, so) pommes frites',
#  'süßkartoffel-amaranth-burger, (glw, gld) senf-walnuss-dip (nw, sf, so) kartoffelspalten',
#  'karottensüßkartoffeleintopf mit baguettebrot (glw)',
#  'tagesgericht: pasta in cherry-tomatensoße (giw)',
#  'falafel bällchen couscous tomaten- minzsugo',
#  'kartoffel-gulasch, weiße bohnen, rosmarin, kapern baguettebrot',
#  'beijing suppe (3, glw, se, so) sauer-scharfe-suppe, mu err pilze, jackfruit, glasnudeln',
#  'begrenztes angebot kartoffel-weiße bohnen ragout, rosmarin, kapern (sl) couscous (glw)',
#  'lauwarmer beluga linsen one pot, balsamico, rote beete, hokkaido (1, 3, 5, 8, sf, sl, sw)',
#  'balila - libanesisches kichererbsengericht naan brot (glw, so) libanesisches kichererbsengericht',
#  'süßkartoffel -steckrübensuppe (sf)',
#  'currywurst feuertopf (2, 3, 10, sf, sl) baguettebrot (glw)',
#  'bulgur bowl, spinat-hummus, brokkoli, karotten, ingwer, casshewkerne',
#  'penne al arrabiata (1, 2, 6, glw, sl)',
#  'chili con carne (glw, so) baguettebrot (glw)',
#  'süßkartoffelpfanne, ingwer',
#  'linseneintopf (1, 3, 5, sl, sw) baguettebrot (glw)',
#  'blumenkohl- kartoffel- curry, rucola, tomaten',
#  'limited edition buletten brötchen kartoffelspalten',
#  'begrenztes angebot kabeljaufilet überbacken cocktailsoße kartoffelspalten',
#  'holsteiner kartoffelsuppe (sf, sl) brot (glw, glr)',
#  'börek, spinatfüllung chinakohl-salat tomaten- minzsugo',
#  'chili con carne (2) fladenbrot (glw, glg, se)',
#  'börek, spinatfüllung (glw) tomaten- minzsugo bulgur [bio] (glw)',
#  'pasta, erbsen (glw) tomatensoße',
#  'linseneintopf (3, 5, sf, sl, sw) fladenbrot (glw, glg, se)',
#  'überbackene pasta mit gemüse',
#  'grünkohleintopf',
#  'kochwurst (1, 2, 10, sf)',
#  'hokaido gebraten, gnocchi, kürbiskerne (glw) rucolapesto',
#  'bulgur [bio]-salat (2, glw) mit falafel (glw, sl)',
#  'weißkohleintopf baguettebrot',
#  'lahmacun, türkische "pizza", frische salate, kräuter',
#  'protein power falafel-bratling tomatensalsa rote- bete- hummus süßkartoffel- popcorn- stampf',
#  'balila libanesisches kichererbsengericht naan brot',
#  'erbseneintopf, wursteinlage (2, 3, 4, 5, 8, 10, sl, sw)',
#  'steckrübeneintopf baguettebrot',
#  'limettenspaghetti, champignons, erbsen- cashewkern- pesto (1, glw, nw, nc)',
#  'kochwurst zum eintopf',
#  'kartoffel-weiße bohnen ragout, rosmarin, kapern baguettebrot',
#  'minestrone, spinat, weiße bohnen, nudeln (3, glw, sl) baguettebrot (glw)',
#  'grünkohl (2, 3, 4, sf) kochwurst (2, 3, 4, 8, 10, sf, sl) salzkartoffeln',
#  'börek, spinatfüllung (glw) bulgur [bio] (glw) tomaten-gurken- salat',
#  'kabeljau, blattspinat, pasta',
#  'rajma dal - indisches kidneybohnen-curry (1)',
#  'die cafeteria in der mensa bleibt bis auf weiteres krankheitsbedingt geschlossen',
#  'weihnachtsessen: barberie-entenbrustfilet rotkohl (1, 3, 5, 8, sw) kroketten (glw) orangensoße',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander brot',
#  'beluga linsen, senfsoße, rote beete, hokaido (1, 3, 5, sf, sl, sw)',
#  'grüne- thai- kokos- gemüsesuppe, ingwer, mie-nudeln, koriander (glw) baguettebrot (glw)',
#  'bratnudeln, zuckerschoten, cashewkerne, basilikum',
#  'rote linsen, senfsoße, rote beete, hokaido (1, 3, 5, sf, sl, sw)',
#  'gemüseeintopf, dinkel, kirschtomaten, paprika, pasta (glw, gld, sl)',
#  'pasta bar, täglich wechselndes angebot (1, 2, glw) arrabiata soße (1, 2, 6, glw, sl)',
#  'gewickelte tortillas mit scharfem kichererbsenmus, avocado und gemüse-salat-mix',
#  'begrenztes angebot: orientalische kichererbsensuppe baguettebrot',
#  'begrenztes angebot chili sin carne bulgur (bio)',
#  'chili con carne mit baguettebrot als menü mit fritz + 1,00 €',
#  'currywurst ..und gitterkartoffeln currysoße karamellisierte balsamico zwiebeln',
#  'bruderhahn bockwurst (bio) zur suppe',
#  'erbseneintopf, minzdip, roggenbrötchen',
#  'polentaschnitte gratiniert dazu kirschtomaten-konfit und rucola mit sonnenblumenkernen',
#  'linseneintopf, kassler baguettebrot',
#  'tortelloni spinat- quinoa, (glw) gemüse-tomatensoße',
#  'barberie-entenbrustfilet orangensoße rotkohl kroketten',
#  'pasta bolognese soße',
#  'linseneintopf (sl, sw, 1) baguettebrot (glw)',
#  'beijing suppe (3, glw, se, so) sauer-scharfe-suppe, mu err pilzen, glasnudeln',
#  'weihnachts bowl, barbarie ente',
#  'rotes linsen dal (3, glh, nmn, sf, so) naan brot (glw, so)',
#  'begrenztes angebot pasta bar nudeln kürbis- ricotta- soße',
#  'lahmacun mit rotkraut, weißkraut, kräuter (glw, so) tomatensalsa (sl, sw)',
#  'begrenztes angebot pasta bar nudeln curryhuhnragout',
#  'begrenztes angebot: falafel (glw) currysoße (3, sl) couscous (glw)',
#  'currywurst hot pot(t) karamellisierte balsamico zwiebeln kartoffelspalten',
#  'onion burger, limetten-dip, eisbergsalat, süß-saure gurken (1, 2, 3, 5, 8, glw, glr, glg, glh, gld, se, sf, so, sw) kartoffelspalten',
#  'begrenztes angebot pasta bar nudeln tomaten- sahne- soße',
#  'country- pfanne, falaffel, paprika (glw, sl) paprika- maissoße (1, 3, 5, sl, sw) kartoffelspalten',
#  ...}

# %%
vgn_veg = apply_regexs([".*vegan.*"], veg)
veg = set(veg)-set(vgn_veg)
print(len(vgn_veg))

meat_vgn_veg = apply_regexs([".*vegan.*", ".*vegetarisch.*", ".*vegetarian.*"], meat)
meat = set(meat)-set(meat_vgn_veg)
print(len(meat_vgn_veg))
# Out:
# 0
# 0

# %%
list_to_file("Data/tags/1vgn_names.txt", vgn)
list_to_file("Data/tags/1veg_names.txt", veg)
list_to_file("Data/tags/1vgn_veg_names.txt", vgn_veg)
list_to_file("Data/tags/1meat_vgn_veg_names.txt", meat_vgn_veg)
list_to_file("Data/tags/1meat_names.txt", meat)
